# %% [markdown]
# # Environment Setup and Data Loading

# %%
import scanpy as sc
import numpy as np
import pandas as pd
import os
import sys
import anndata as ad
import random
import functions_degs
import importlib

PROJECT_DIR = "D:/Github/SRF_Linda_RNA"
WORKING_DIR = os.path.join(PROJECT_DIR, "combine_data")
os.chdir(WORKING_DIR)
sys.path.insert(0, WORKING_DIR)

importlib.reload(functions_degs)

# Set seeds for all random number generators
random_seed = 0
np.random.seed(random_seed)
random.seed(random_seed)

# %%
# Set up directories

# REMOVE_DOUBLETS = True
REMOVE_DOUBLETS = False

FIX_TRESHOLD = True
# FIX_TRESHOLD = False

if FIX_TRESHOLD:
    BASE_RESULTS_DIR = os.path.join(WORKING_DIR, "results_from_raw")
else:
    if REMOVE_DOUBLETS:
        BASE_RESULTS_DIR = os.path.join(WORKING_DIR, "results_from_raw_percentile_threshold", "doublets_removed")
    else:
        BASE_RESULTS_DIR = os.path.join(WORKING_DIR, "results_from_raw_percentile_threshold")

INPUT_DIR = BASE_RESULTS_DIR
adata_path = os.path.join(INPUT_DIR, 'annotation_final.h5ad')

PARENT_OUTPUT_DIR = os.path.join(INPUT_DIR, "DEGs_mapmycells_L1")

# CUSTOM_ANALYSIS =  None
CUSTOM_ANALYSIS =  "FC_0_25"

DEG_BY = "mapmycells_first_layer"

if CUSTOM_ANALYSIS is not None:
    PARENT_OUTPUT_DIR = PARENT_OUTPUT_DIR + CUSTOM_ANALYSIS

PLOT_OUTPUT_DIR = os.path.join(PARENT_OUTPUT_DIR, 'plots')
DGE_OUTPUT_DIR = os.path.join(PARENT_OUTPUT_DIR, 'dge_res')
BIOMARKER_OUTPUT_DIR = os.path.join(PARENT_OUTPUT_DIR, 'biomarkers')

# Create output directories if they don't exist
os.makedirs(PLOT_OUTPUT_DIR, exist_ok=True)
os.makedirs(DGE_OUTPUT_DIR, exist_ok=True)
os.makedirs(BIOMARKER_OUTPUT_DIR, exist_ok=True)

print(f"Input directory: {INPUT_DIR}")
print(f"Plot output directory (Overall/Genotype): {PLOT_OUTPUT_DIR}")
print(f"DGE output directory (Overall/Genotype): {DGE_OUTPUT_DIR}")
print(f"Biomarker output directory: {BIOMARKER_OUTPUT_DIR}")

# Configure scanpy settings
sc.settings.figdir = PLOT_OUTPUT_DIR
sc.settings.set_figure_params(dpi=150, facecolor='white')
# Out:
# Input directory: D:/Github/SRF_Linda_RNA\combine_data\results_from_raw
# Plot output directory (Overall/Genotype): D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\plots
# DGE output directory (Overall/Genotype): D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res
# Biomarker output directory: D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers

# %%
# Load data
print(f"\nLoading dataset from {adata_path}")
adata = sc.read_h5ad(adata_path)
# Out:
# Loading dataset from D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\annotation_final.h5ad

# %% [markdown]
# # Data Preprocessing

# %%
# Save current settings
original_max_rows = pd.get_option('display.max_rows')

# Set to None to display all rows
pd.set_option('display.max_rows', None)

# Check original clusters:
print(f"Original {DEG_BY} clusters:")
print(adata.obs[DEG_BY].value_counts())

# Reset to original settings
pd.set_option('display.max_rows', original_max_rows)
# Out:
# Original mapmycells_first_layer clusters:
# mapmycells_first_layer
# IT-ET Glut        13439
# DG-IMN Glut        3882
# OPC-Oligo          2650
# NP-CT-L6b Glut     2188
# CTX-MGE GABA       1396
# Astro-Epen         1085
# Immune             1016
# CTX-CGE GABA        859
# Vascular            407
# OB-IMN GABA         265
# MB GABA             110
# CNU-LGE GABA         99
# OB-CR Glut           90
# MB Glut              75
# CNU-HYa Glut         70
# CNU-HYa GABA         64
# MY Glut              53
# P GABA               47
# LSX GABA             43
# OEC                  40
# CNU-MGE GABA         36
# MY GABA              24
# HY GABA              20
# MH-LH Glut           17
# HY Glut              14
# TH Glut              13
# CB Glut               9
# P Glut                5
# CB GABA               4
# Pineal Glut           3
# MB Dopa               2
# MB-HB Sero            1
# Name: count, dtype: int64

# %%
# Check adata structure
print("\nAnnData object summary:")
print(adata)
print("\nAvailable layers:", list(adata.layers.keys()))
print("Raw data available:", adata.raw is not None)
if adata.raw:
    print("Raw data shape:", adata.raw.X.shape)
# Out:
# AnnData object summary:
# AnnData object with n_obs × n_vars = 28026 × 26870
#     obs: 'sample', 'condition', 'genotype', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden_0.4', 'ISO_majority_voting', 'ISO_conf_score', 'DG_majority_voting', 'DG_conf_score', 'mapmycells_first_layer', 'mapmycells_second_layer', 'cell_type', 'highlight'
#     var: 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'mean', 'std'
#     uns: 'DG_majority_voting_colors', 'ISO_majority_voting_colors', 'cell_type_colors', 'condition_colors', 'genotype_colors', 'highlight_colors', 'hvg', 'leiden_0.4', 'leiden_0.4_colors', 'log1p', 'neighbors', 'pca', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
#
# Available layers: []
# Raw data available: True
# Raw data shape: (28026, 33685)

# %%
# Create the 'for_DEGs' layer: Normalized and log1p transformed counts
# Assuming raw counts are in adata.raw.X
print("\nCreating 'for_DEGs' layer...")
if adata.raw is not None and adata.raw.X is not None:
    # Create a temporary AnnData with raw counts to perform normalization and log1p
    adata_for_dge = ad.AnnData(adata.raw.X.copy()) # type: ignore
    adata_for_dge.obs_names = adata.obs_names # type: ignore
    adata_for_dge.var_names = adata.raw.var_names # type: ignore

    print("Normalizing total counts (target_sum=1e4)...")
    sc.pp.normalize_total(adata_for_dge, target_sum=1e4)

    print("Applying log1p transformation...")
    sc.pp.log1p(adata_for_dge)

    # Ensure the gene order matches the main adata object
    adata_for_dge = adata_for_dge[:, adata.var_names].copy() # type: ignore

    print("Storing result in adata.layers['for_DEGs']...")
    adata.layers['for_DEGs'] = adata_for_dge.X.copy() # type: ignore
    print("'for_DEGs' layer created with shape:", adata.layers['for_DEGs'].shape)
else:
    print("Warning: adata.raw.X not found. Cannot create 'for_DEGs' layer from raw counts.")
    print("DGE analysis will proceed using adata.X, which might be scaled.")
# Out:
# Creating 'for_DEGs' layer...
# Normalizing total counts (target_sum=1e4)...
# Applying log1p transformation...
# Storing result in adata.layers['for_DEGs']...
# 'for_DEGs' layer created with shape: (28026, 26870)

# %%
print("\nMetadata check:")
print("condition:", list(adata.obs.condition.unique()))
print("genotype:", list(adata.obs.genotype.unique()))
print(f"{DEG_BY}:", list(adata.obs[DEG_BY].unique()))
# Out:
# Metadata check:
# condition: ['Control', 'Mutant']
# genotype: ['Emx1', 'Nestin']
# mapmycells_first_layer: ['Astro-Epen', 'IT-ET Glut', 'Immune', 'DG-IMN Glut', 'OPC-Oligo', 'MY Glut', 'CTX-MGE GABA', 'NP-CT-L6b Glut', 'OB-CR Glut', 'CTX-CGE GABA', 'OB-IMN GABA', 'MB GABA', 'CNU-LGE GABA', 'LSX GABA', 'CNU-HYa GABA', 'Vascular', 'P Glut', 'CNU-HYa Glut', 'MY GABA', 'MB Glut', 'P GABA', 'MH-LH Glut', 'CNU-MGE GABA', 'CB Glut', 'CB GABA', 'HY GABA', 'TH Glut', 'MB Dopa', 'OEC', 'MB-HB Sero', 'HY Glut', 'Pineal Glut']

# %% [markdown]
# # Differential Gene Expression Analysis

# %%
# Overall DGE (Mutant vs Control) using the 'for_DEGs' layer, grouped by the DEG_BY
print(f"\nRunning Overall DGE (grouped by {DEG_BY})...")
dge_results = functions_degs.run_overall_dge(
    adata,
    grouping_key=DEG_BY,
    dge_output_dir=DGE_OUTPUT_DIR,
    plot_output_dir=PLOT_OUTPUT_DIR,
    layer='for_DEGs' if 'for_DEGs' in adata.layers else None
)
# Out:
# Running Overall DGE (grouped by mapmycells_first_layer)...
#
# Starting both genomes Differential Gene Expression analysis (Mutant vs Control)...
#   Running DGE for group: Astro-Epen (using key 'mapmycells_first_layer')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 109 cells (max of 3 absolute and 10.0% of 1085)...
#     Genes after filtering: 5810
#       Calculating mean expression for 5810 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_Astro-Epen_mut_vs_ctrl.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_Astro-Epen_mut_vs_ctrl.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Astro-Epen'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Astro-Epen'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Astro-Epen' is writable.
#     Saved 14 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Astro-Epen\Mutant_vs_Control_up_significant.csv
#     Saved 214 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Astro-Epen\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group Astro-Epen: ['Mir99ahg', 'Gm28175', 'Grik2', 'Gm29260', 'Nfib']
# ---
#   Running DGE for group: IT-ET Glut (using key 'mapmycells_first_layer')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 1344 cells (max of 3 absolute and 10.0% of 13439)...
#     Genes after filtering: 10098
#       Calculating mean expression for 10098 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_IT-ET_Glut_mut_vs_ctrl.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_IT-ET_Glut_mut_vs_ctrl.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\IT-ET_Glut'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\IT-ET_Glut'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\IT-ET_Glut' is writable.
#     Saved 3796 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\IT-ET_Glut\Mutant_vs_Control_up_significant.csv
#     Saved 1065 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\IT-ET_Glut\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group IT-ET Glut: ['Meg3', 'A830082K12Rik', 'Mir99ahg', 'Tenm2', 'Runx1t1']
# ---
#   Running DGE for group: Immune (using key 'mapmycells_first_layer')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 102 cells (max of 3 absolute and 10.0% of 1016)...
#     Genes after filtering: 3706
#       Calculating mean expression for 3706 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_Immune_mut_vs_ctrl.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_Immune_mut_vs_ctrl.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Immune'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Immune'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Immune' is writable.
#     Saved 87 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Immune\Mutant_vs_Control_up_significant.csv
#     Saved 288 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Immune\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group Immune: ['Naaladl2', 'Tenm2', 'Ptprd', 'Dpp10', 'Dlg2']
# ---
#   Running DGE for group: DG-IMN Glut (using key 'mapmycells_first_layer')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 389 cells (max of 3 absolute and 10.0% of 3882)...
#     Genes after filtering: 9207
#       Calculating mean expression for 9207 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_DG-IMN_Glut_mut_vs_ctrl.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_DG-IMN_Glut_mut_vs_ctrl.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\DG-IMN_Glut'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\DG-IMN_Glut'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\DG-IMN_Glut' is writable.
#     Saved 359 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\DG-IMN_Glut\Mutant_vs_Control_up_significant.csv
#     Saved 2203 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\DG-IMN_Glut\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group DG-IMN Glut: ['Tenm2', 'Frmpd4', 'Dab1', 'Grik4', 'Naaladl2']
# ---
#   Running DGE for group: OPC-Oligo (using key 'mapmycells_first_layer')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 265 cells (max of 3 absolute and 10.0% of 2650)...
#     Genes after filtering: 5350
#       Calculating mean expression for 5350 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_OPC-Oligo_mut_vs_ctrl.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_OPC-Oligo_mut_vs_ctrl.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\OPC-Oligo'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\OPC-Oligo'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\OPC-Oligo' is writable.
#     Saved 148 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\OPC-Oligo\Mutant_vs_Control_up_significant.csv
#     Saved 1860 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\OPC-Oligo\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group OPC-Oligo: ['Mir99ahg', 'Ralyl', 'Dpp10', 'Cadm2', 'Naaladl2']
# ---
#   Running DGE for group: MY Glut (using key 'mapmycells_first_layer')
#     Skipping DGE for group MY Glut: Not enough cells (< 50). Control: 34, Mutant: 19
#   Running DGE for group: CTX-MGE GABA (using key 'mapmycells_first_layer')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 140 cells (max of 3 absolute and 10.0% of 1396)...
#     Genes after filtering: 9544
#       Calculating mean expression for 9544 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_CTX-MGE_GABA_mut_vs_ctrl.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_CTX-MGE_GABA_mut_vs_ctrl.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\CTX-MGE_GABA'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\CTX-MGE_GABA'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\CTX-MGE_GABA' is writable.
#     Saved 75 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\CTX-MGE_GABA\Mutant_vs_Control_up_significant.csv
#     Saved 463 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\CTX-MGE_GABA\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group CTX-MGE GABA: ['Meg3', 'Naaladl2', 'C130071C03Rik', 'Mir99ahg', 'Frmd4a']
# ---
#   Running DGE for group: NP-CT-L6b Glut (using key 'mapmycells_first_layer')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 219 cells (max of 3 absolute and 10.0% of 2188)...
#     Genes after filtering: 10625
#       Calculating mean expression for 10625 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_NP-CT-L6b_Glut_mut_vs_ctrl.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_NP-CT-L6b_Glut_mut_vs_ctrl.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\NP-CT-L6b_Glut'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\NP-CT-L6b_Glut'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\NP-CT-L6b_Glut' is writable.
#     Saved 249 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\NP-CT-L6b_Glut\Mutant_vs_Control_up_significant.csv
#     Saved 395 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\NP-CT-L6b_Glut\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group NP-CT-L6b Glut: ['Meg3', 'C130071C03Rik', 'Naaladl2', 'A830082K12Rik', 'Tenm4']
# ---
#   Running DGE for group: OB-CR Glut (using key 'mapmycells_first_layer')
#     Skipping DGE for group OB-CR Glut: Not enough cells (< 50). Control: 45, Mutant: 45
#   Running DGE for group: CTX-CGE GABA (using key 'mapmycells_first_layer')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 86 cells (max of 3 absolute and 10.0% of 859)...
#     Genes after filtering: 8898
#       Calculating mean expression for 8898 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_CTX-CGE_GABA_mut_vs_ctrl.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_CTX-CGE_GABA_mut_vs_ctrl.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\CTX-CGE_GABA'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\CTX-CGE_GABA'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\CTX-CGE_GABA' is writable.
#     Saved 76 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\CTX-CGE_GABA\Mutant_vs_Control_up_significant.csv
#     Saved 186 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\CTX-CGE_GABA\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group CTX-CGE GABA: ['Meg3', 'Mir99ahg', 'Tcf4', 'C130071C03Rik', 'Naaladl2']
# ---
#   Running DGE for group: OB-IMN GABA (using key 'mapmycells_first_layer')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 27 cells (max of 3 absolute and 10.0% of 265)...
#     Genes after filtering: 5117
#       Calculating mean expression for 5117 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_OB-IMN_GABA_mut_vs_ctrl.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_OB-IMN_GABA_mut_vs_ctrl.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\OB-IMN_GABA'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\OB-IMN_GABA'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\OB-IMN_GABA' is writable.
#     Saved 4 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\OB-IMN_GABA\Mutant_vs_Control_up_significant.csv
#     Saved 649 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\OB-IMN_GABA\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group OB-IMN GABA: ['Ptprd', 'Tenm2', 'mt-Atp6', 'Mir99ahg', 'Lrrc4c']
# ---
#   Running DGE for group: MB GABA (using key 'mapmycells_first_layer')
#     Skipping DGE for group MB GABA: Not enough cells (< 50). Control: 49, Mutant: 61
#   Running DGE for group: CNU-LGE GABA (using key 'mapmycells_first_layer')
#     Skipping DGE for group CNU-LGE GABA: Not enough cells (< 50). Control: 50, Mutant: 49
#   Running DGE for group: LSX GABA (using key 'mapmycells_first_layer')
#     Skipping DGE for group LSX GABA: Not enough cells (< 50). Control: 19, Mutant: 24
#   Running DGE for group: CNU-HYa GABA (using key 'mapmycells_first_layer')
#     Skipping DGE for group CNU-HYa GABA: Not enough cells (< 50). Control: 37, Mutant: 27
#   Running DGE for group: Vascular (using key 'mapmycells_first_layer')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 41 cells (max of 3 absolute and 10.0% of 407)...
#     Genes after filtering: 5731
#       Calculating mean expression for 5731 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_Vascular_mut_vs_ctrl.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_Vascular_mut_vs_ctrl.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Vascular'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Vascular'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Vascular' is writable.
#     No significant UP genes found for Mutant_vs_Control. Empty CSV file with header created: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Vascular\Mutant_vs_Control_up_significant.csv
#     No significant DOWN genes found for Mutant_vs_Control. Empty CSV file with header created: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Vascular\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group Vascular: ['Rplp1', 'Rps8', 'Pcsk1n', 'Mt3', 'Rpl9']
# ---
#   Running DGE for group: P Glut (using key 'mapmycells_first_layer')
#     Skipping DGE for group P Glut: Not enough cells (< 50). Control: 4, Mutant: 1
#   Running DGE for group: CNU-HYa Glut (using key 'mapmycells_first_layer')
#     Skipping DGE for group CNU-HYa Glut: Not enough cells (< 50). Control: 38, Mutant: 32
#   Running DGE for group: MY GABA (using key 'mapmycells_first_layer')
#     Skipping DGE for group MY GABA: Not enough cells (< 50). Control: 13, Mutant: 11
#   Running DGE for group: MB Glut (using key 'mapmycells_first_layer')
#     Skipping DGE for group MB Glut: Not enough cells (< 50). Control: 36, Mutant: 39
#   Running DGE for group: P GABA (using key 'mapmycells_first_layer')
#     Skipping DGE for group P GABA: Not enough cells (< 50). Control: 30, Mutant: 17
#   Running DGE for group: MH-LH Glut (using key 'mapmycells_first_layer')
#     Skipping DGE for group MH-LH Glut: Not enough cells (< 50). Control: 2, Mutant: 15
#   Running DGE for group: CNU-MGE GABA (using key 'mapmycells_first_layer')
#     Skipping DGE for group CNU-MGE GABA: Not enough cells (< 50). Control: 14, Mutant: 22
#   Running DGE for group: CB Glut (using key 'mapmycells_first_layer')
#     Skipping DGE for group CB Glut: Not enough cells (< 50). Control: 5, Mutant: 4
#   Running DGE for group: CB GABA (using key 'mapmycells_first_layer')
#     Skipping DGE for group CB GABA: Not enough cells (< 50). Control: 3, Mutant: 1
#   Running DGE for group: HY GABA (using key 'mapmycells_first_layer')
#     Skipping DGE for group HY GABA: Not enough cells (< 50). Control: 9, Mutant: 11
#   Running DGE for group: TH Glut (using key 'mapmycells_first_layer')
#     Skipping DGE for group TH Glut: Not enough cells (< 50). Control: 2, Mutant: 11
#   Running DGE for group: MB Dopa (using key 'mapmycells_first_layer')
#     Skipping DGE for group MB Dopa: Not enough cells (< 50). Control: 1, Mutant: 1
#   Running DGE for group: OEC (using key 'mapmycells_first_layer')
#     Skipping DGE for group OEC: Not enough cells (< 50). Control: 40, Mutant: 0
#   Running DGE for group: MB-HB Sero (using key 'mapmycells_first_layer')
#     Skipping DGE for group MB-HB Sero: Not enough cells (< 50). Control: 1, Mutant: 0
#   Running DGE for group: HY Glut (using key 'mapmycells_first_layer')
#     Skipping DGE for group HY Glut: Not enough cells (< 50). Control: 7, Mutant: 7
#   Running DGE for group: Pineal Glut (using key 'mapmycells_first_layer')
#     Skipping DGE for group Pineal Glut: Not enough cells (< 50). Control: 2, Mutant: 1
#
# Summary of skipped groups (using key 'mapmycells_first_layer') saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\both_geno_cond_comp\dge_overall_skipped_mapmycells_first_layer.csv
#
# Both genomes DGE analysis finished.
#
# Generating Volcano Plots for Overall DGE results...
#   Generating volcano plot for: Both genomes - Astro-Epen (Counts: Control=665, Mutant=420) -> dge_conditions_comparison_Astro-Epen_volcano.png
# ---
#   Generating volcano plot for: Both genomes - IT-ET Glut (Counts: Control=5525, Mutant=7914) -> dge_conditions_comparison_IT-ET_Glut_volcano.png
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# ---
#   Generating volcano plot for: Both genomes - Immune (Counts: Control=459, Mutant=557) -> dge_conditions_comparison_Immune_volcano.png
# ---
#   Generating volcano plot for: Both genomes - DG-IMN Glut (Counts: Control=2516, Mutant=1366) -> dge_conditions_comparison_DG-IMN_Glut_volcano.png
# ---
#   Generating volcano plot for: Both genomes - OPC-Oligo (Counts: Control=1267, Mutant=1383) -> dge_conditions_comparison_OPC-Oligo_volcano.png
# ---
#   Skipping volcano plot for Both genomes - MY Glut: Not enough cells in one or both groups (< 50). Control=34, Mutant=19.
#   Generating volcano plot for: Both genomes - CTX-MGE GABA (Counts: Control=478, Mutant=918) -> dge_conditions_comparison_CTX-MGE_GABA_volcano.png
# ---
#   Generating volcano plot for: Both genomes - NP-CT-L6b Glut (Counts: Control=757, Mutant=1431) -> dge_conditions_comparison_NP-CT-L6b_Glut_volcano.png
# ---
#   Skipping volcano plot for Both genomes - OB-CR Glut: Not enough cells in one or both groups (< 50). Control=45, Mutant=45.
#   Generating volcano plot for: Both genomes - CTX-CGE GABA (Counts: Control=303, Mutant=556) -> dge_conditions_comparison_CTX-CGE_GABA_volcano.png
# ---
#   Generating volcano plot for: Both genomes - OB-IMN GABA (Counts: Control=187, Mutant=78) -> dge_conditions_comparison_OB-IMN_GABA_volcano.png
# ---
#   Skipping volcano plot for Both genomes - MB GABA: Not enough cells in one or both groups (< 50). Control=49, Mutant=61.
#   Skipping volcano plot for Both genomes - CNU-LGE GABA: Not enough cells in one or both groups (< 50). Control=50, Mutant=49.
#   Skipping volcano plot for Both genomes - LSX GABA: Not enough cells in one or both groups (< 50). Control=19, Mutant=24.
#   Skipping volcano plot for Both genomes - CNU-HYa GABA: Not enough cells in one or both groups (< 50). Control=37, Mutant=27.
#   Generating volcano plot for: Both genomes - Vascular (Counts: Control=221, Mutant=186) -> dge_conditions_comparison_Vascular_volcano.png
# ---
#   Skipping volcano plot for Both genomes - P Glut: Not enough cells in one or both groups (< 50). Control=4, Mutant=1.
#   Skipping volcano plot for Both genomes - CNU-HYa Glut: Not enough cells in one or both groups (< 50). Control=38, Mutant=32.
#   Skipping volcano plot for Both genomes - MY GABA: Not enough cells in one or both groups (< 50). Control=13, Mutant=11.
#   Skipping volcano plot for Both genomes - MB Glut: Not enough cells in one or both groups (< 50). Control=36, Mutant=39.
#   Skipping volcano plot for Both genomes - P GABA: Not enough cells in one or both groups (< 50). Control=30, Mutant=17.
#   Skipping volcano plot for Both genomes - MH-LH Glut: Not enough cells in one or both groups (< 50). Control=2, Mutant=15.
#   Skipping volcano plot for Both genomes - CNU-MGE GABA: Not enough cells in one or both groups (< 50). Control=14, Mutant=22.
#   Skipping volcano plot for Both genomes - CB Glut: Not enough cells in one or both groups (< 50). Control=5, Mutant=4.
#   Skipping volcano plot for Both genomes - CB GABA: Not enough cells in one or both groups (< 50). Control=3, Mutant=1.
#   Skipping volcano plot for Both genomes - HY GABA: Not enough cells in one or both groups (< 50). Control=9, Mutant=11.
#   Skipping volcano plot for Both genomes - TH Glut: Not enough cells in one or both groups (< 50). Control=2, Mutant=11.
#   Skipping volcano plot for Both genomes - MB Dopa: Not enough cells in one or both groups (< 50). Control=1, Mutant=1.
#   Skipping volcano plot for Both genomes - OEC: Not enough cells in one or both groups (< 50). Control=40, Mutant=0.
#   Skipping volcano plot for Both genomes - MB-HB Sero: Not enough cells in one or both groups (< 50). Control=1, Mutant=0.
#   Skipping volcano plot for Both genomes - HY Glut: Not enough cells in one or both groups (< 50). Control=7, Mutant=7.
#   Skipping volcano plot for Both genomes - Pineal Glut: Not enough cells in one or both groups (< 50). Control=2, Mutant=1.
#
# Both genomes DGE visualization finished.

# %%
# Genotype-Specific DGE (Mutant vs Control within each genotype) using the 'for_DEGs' layer, grouped by the DEG_BY
print(f"\nRunning Genotype-Specific DGE (grouped by {DEG_BY})...")
dge_by_genotype = functions_degs.run_genotype_specific_dge(
    adata,
    grouping_key=DEG_BY,
    dge_output_dir=DGE_OUTPUT_DIR,
    plot_output_dir=PLOT_OUTPUT_DIR,
    layer='for_DEGs' if 'for_DEGs' in adata.layers else None
)
# Out:
# Running Genotype-Specific DGE (grouped by mapmycells_first_layer)...
#
# Starting Genotype-Specific DGE analysis...
# Created 'genotype_condition' column with categories: ['Emx1_Control', 'Emx1_Mutant', 'Nestin_Control', 'Nestin_Mutant']
#
# Processing group: Astro-Epen (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Filtering genes for Emx1 (Initial: 26870)
#     Filtering genes: Requiring expression in >= 42 cells (max of 3 absolute and 10.0% of 414)...
#     Genes after filtering: 5181
#       Calculating mean expression for 5181 genes (Emx1, group Astro-Epen)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Emx1, group Astro-Epen).
#     Finished DGE for Emx1, group Astro-Epen. Found 5181 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_Astro-Epen_mut_vs_ctrl.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_Astro-Epen_mut_vs_ctrl.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Astro-Epen'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Astro-Epen'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Astro-Epen' is writable.
#     Saved 79 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Astro-Epen\Mutant_vs_Control_up_significant.csv
#     Saved 45 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Astro-Epen\Mutant_vs_Control_down_significant.csv
#   Running DGE for Nestin genotype...
#     Filtering genes for Nestin (Initial: 26870)
#     Filtering genes: Requiring expression in >= 68 cells (max of 3 absolute and 10.0% of 671)...
#     Genes after filtering: 6026
#       Calculating mean expression for 6026 genes (Nestin, group Astro-Epen)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Nestin, group Astro-Epen).
#     Finished DGE for Nestin, group Astro-Epen. Found 6026 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_Astro-Epen_mut_vs_ctrl.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_Astro-Epen_mut_vs_ctrl.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Astro-Epen'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Astro-Epen'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Astro-Epen' is writable.
#     Saved 44 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Astro-Epen\Mutant_vs_Control_up_significant.csv
#     Saved 428 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Astro-Epen\Mutant_vs_Control_down_significant.csv
#
# Processing group: IT-ET Glut (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Filtering genes for Emx1 (Initial: 26870)
#     Filtering genes: Requiring expression in >= 577 cells (max of 3 absolute and 10.0% of 5765)...
#     Genes after filtering: 10137
#       Calculating mean expression for 10137 genes (Emx1, group IT-ET Glut)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Emx1, group IT-ET Glut).
#     Finished DGE for Emx1, group IT-ET Glut. Found 10137 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_IT-ET_Glut_mut_vs_ctrl.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_IT-ET_Glut_mut_vs_ctrl.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\IT-ET_Glut'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\IT-ET_Glut'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\IT-ET_Glut' is writable.
#     Saved 2958 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\IT-ET_Glut\Mutant_vs_Control_up_significant.csv
#     Saved 1175 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\IT-ET_Glut\Mutant_vs_Control_down_significant.csv
#   Running DGE for Nestin genotype...
#     Filtering genes for Nestin (Initial: 26870)
#     Filtering genes: Requiring expression in >= 768 cells (max of 3 absolute and 10.0% of 7674)...
#     Genes after filtering: 10017
#       Calculating mean expression for 10017 genes (Nestin, group IT-ET Glut)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Nestin, group IT-ET Glut).
#     Finished DGE for Nestin, group IT-ET Glut. Found 10017 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_IT-ET_Glut_mut_vs_ctrl.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_IT-ET_Glut_mut_vs_ctrl.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\IT-ET_Glut'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\IT-ET_Glut'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\IT-ET_Glut' is writable.
#     Saved 4094 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\IT-ET_Glut\Mutant_vs_Control_up_significant.csv
#     Saved 818 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\IT-ET_Glut\Mutant_vs_Control_down_significant.csv
#
# Processing group: Immune (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group Immune: Not enough cells (< 50). Emx1_Control: 72, Emx1_Mutant: 42
#   Running DGE for Nestin genotype...
#     Filtering genes for Nestin (Initial: 26870)
#     Filtering genes: Requiring expression in >= 91 cells (max of 3 absolute and 10.0% of 902)...
#     Genes after filtering: 3733
#       Calculating mean expression for 3733 genes (Nestin, group Immune)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Nestin, group Immune).
#     Finished DGE for Nestin, group Immune. Found 3733 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_Immune_mut_vs_ctrl.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_Immune_mut_vs_ctrl.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Immune'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Immune'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Immune' is writable.
#     Saved 64 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Immune\Mutant_vs_Control_up_significant.csv
#     Saved 376 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Immune\Mutant_vs_Control_down_significant.csv
#
# Processing group: DG-IMN Glut (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Filtering genes for Emx1 (Initial: 26870)
#     Filtering genes: Requiring expression in >= 127 cells (max of 3 absolute and 10.0% of 1268)...
#     Genes after filtering: 9491
#       Calculating mean expression for 9491 genes (Emx1, group DG-IMN Glut)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Emx1, group DG-IMN Glut).
#     Finished DGE for Emx1, group DG-IMN Glut. Found 9491 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_DG-IMN_Glut_mut_vs_ctrl.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_DG-IMN_Glut_mut_vs_ctrl.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\DG-IMN_Glut'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\DG-IMN_Glut'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\DG-IMN_Glut' is writable.
#     Saved 481 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\DG-IMN_Glut\Mutant_vs_Control_up_significant.csv
#     Saved 1012 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\DG-IMN_Glut\Mutant_vs_Control_down_significant.csv
#   Running DGE for Nestin genotype...
#     Filtering genes for Nestin (Initial: 26870)
#     Filtering genes: Requiring expression in >= 262 cells (max of 3 absolute and 10.0% of 2614)...
#     Genes after filtering: 9060
#       Calculating mean expression for 9060 genes (Nestin, group DG-IMN Glut)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Nestin, group DG-IMN Glut).
#     Finished DGE for Nestin, group DG-IMN Glut. Found 9060 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_DG-IMN_Glut_mut_vs_ctrl.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_DG-IMN_Glut_mut_vs_ctrl.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\DG-IMN_Glut'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\DG-IMN_Glut'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\DG-IMN_Glut' is writable.
#     Saved 334 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\DG-IMN_Glut\Mutant_vs_Control_up_significant.csv
#     Saved 2069 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\DG-IMN_Glut\Mutant_vs_Control_down_significant.csv
#
# Processing group: OPC-Oligo (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Filtering genes for Emx1 (Initial: 26870)
#     Filtering genes: Requiring expression in >= 40 cells (max of 3 absolute and 10.0% of 399)...
#     Genes after filtering: 5052
#       Calculating mean expression for 5052 genes (Emx1, group OPC-Oligo)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Emx1, group OPC-Oligo).
#     Finished DGE for Emx1, group OPC-Oligo. Found 5052 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_OPC-Oligo_mut_vs_ctrl.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_OPC-Oligo_mut_vs_ctrl.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\OPC-Oligo'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\OPC-Oligo'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\OPC-Oligo' is writable.
#     Saved 46 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\OPC-Oligo\Mutant_vs_Control_up_significant.csv
#     Saved 16 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\OPC-Oligo\Mutant_vs_Control_down_significant.csv
#   Running DGE for Nestin genotype...
#     Filtering genes for Nestin (Initial: 26870)
#     Filtering genes: Requiring expression in >= 226 cells (max of 3 absolute and 10.0% of 2251)...
#     Genes after filtering: 5328
#       Calculating mean expression for 5328 genes (Nestin, group OPC-Oligo)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Nestin, group OPC-Oligo).
#     Finished DGE for Nestin, group OPC-Oligo. Found 5328 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_OPC-Oligo_mut_vs_ctrl.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_OPC-Oligo_mut_vs_ctrl.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\OPC-Oligo'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\OPC-Oligo'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\OPC-Oligo' is writable.
#     Saved 141 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\OPC-Oligo\Mutant_vs_Control_up_significant.csv
#     Saved 2156 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\OPC-Oligo\Mutant_vs_Control_down_significant.csv
#
# Processing group: MY Glut (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group MY Glut: Not enough cells (< 50). Emx1_Control: 10, Emx1_Mutant: 10
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group MY Glut: Not enough cells (< 50). Nestin_Control: 24, Nestin_Mutant: 9
#
# Processing group: CTX-MGE GABA (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Filtering genes for Emx1 (Initial: 26870)
#     Filtering genes: Requiring expression in >= 63 cells (max of 3 absolute and 10.0% of 625)...
#     Genes after filtering: 9532
#       Calculating mean expression for 9532 genes (Emx1, group CTX-MGE GABA)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Emx1, group CTX-MGE GABA).
#     Finished DGE for Emx1, group CTX-MGE GABA. Found 9532 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_CTX-MGE_GABA_mut_vs_ctrl.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_CTX-MGE_GABA_mut_vs_ctrl.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\CTX-MGE_GABA'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\CTX-MGE_GABA'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\CTX-MGE_GABA' is writable.
#     Saved 127 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\CTX-MGE_GABA\Mutant_vs_Control_up_significant.csv
#     Saved 170 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\CTX-MGE_GABA\Mutant_vs_Control_down_significant.csv
#   Running DGE for Nestin genotype...
#     Filtering genes for Nestin (Initial: 26870)
#     Filtering genes: Requiring expression in >= 78 cells (max of 3 absolute and 10.0% of 771)...
#     Genes after filtering: 9459
#       Calculating mean expression for 9459 genes (Nestin, group CTX-MGE GABA)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Nestin, group CTX-MGE GABA).
#     Finished DGE for Nestin, group CTX-MGE GABA. Found 9459 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_CTX-MGE_GABA_mut_vs_ctrl.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_CTX-MGE_GABA_mut_vs_ctrl.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\CTX-MGE_GABA'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\CTX-MGE_GABA'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\CTX-MGE_GABA' is writable.
#     Saved 47 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\CTX-MGE_GABA\Mutant_vs_Control_up_significant.csv
#     Saved 353 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\CTX-MGE_GABA\Mutant_vs_Control_down_significant.csv
#
# Processing group: NP-CT-L6b Glut (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Filtering genes for Emx1 (Initial: 26870)
#     Filtering genes: Requiring expression in >= 67 cells (max of 3 absolute and 10.0% of 668)...
#     Genes after filtering: 10501
#       Calculating mean expression for 10501 genes (Emx1, group NP-CT-L6b Glut)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Emx1, group NP-CT-L6b Glut).
#     Finished DGE for Emx1, group NP-CT-L6b Glut. Found 10501 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_NP-CT-L6b_Glut_mut_vs_ctrl.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_NP-CT-L6b_Glut_mut_vs_ctrl.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\NP-CT-L6b_Glut'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\NP-CT-L6b_Glut'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\NP-CT-L6b_Glut' is writable.
#     Saved 370 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\NP-CT-L6b_Glut\Mutant_vs_Control_up_significant.csv
#     Saved 155 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\NP-CT-L6b_Glut\Mutant_vs_Control_down_significant.csv
#   Running DGE for Nestin genotype...
#     Filtering genes for Nestin (Initial: 26870)
#     Filtering genes: Requiring expression in >= 152 cells (max of 3 absolute and 10.0% of 1520)...
#     Genes after filtering: 10645
#       Calculating mean expression for 10645 genes (Nestin, group NP-CT-L6b Glut)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Nestin, group NP-CT-L6b Glut).
#     Finished DGE for Nestin, group NP-CT-L6b Glut. Found 10645 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_NP-CT-L6b_Glut_mut_vs_ctrl.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_NP-CT-L6b_Glut_mut_vs_ctrl.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\NP-CT-L6b_Glut'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\NP-CT-L6b_Glut'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\NP-CT-L6b_Glut' is writable.
#     Saved 266 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\NP-CT-L6b_Glut\Mutant_vs_Control_up_significant.csv
#     Saved 537 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\NP-CT-L6b_Glut\Mutant_vs_Control_down_significant.csv
#
# Processing group: OB-CR Glut (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group OB-CR Glut: Not enough cells (< 50). Emx1_Control: 7, Emx1_Mutant: 8
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group OB-CR Glut: Not enough cells (< 50). Nestin_Control: 38, Nestin_Mutant: 37
#
# Processing group: CTX-CGE GABA (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Filtering genes for Emx1 (Initial: 26870)
#     Filtering genes: Requiring expression in >= 40 cells (max of 3 absolute and 10.0% of 399)...
#     Genes after filtering: 9146
#       Calculating mean expression for 9146 genes (Emx1, group CTX-CGE GABA)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Emx1, group CTX-CGE GABA).
#     Finished DGE for Emx1, group CTX-CGE GABA. Found 9146 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_CTX-CGE_GABA_mut_vs_ctrl.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_CTX-CGE_GABA_mut_vs_ctrl.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\CTX-CGE_GABA'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\CTX-CGE_GABA'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\CTX-CGE_GABA' is writable.
#     Saved 11 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\CTX-CGE_GABA\Mutant_vs_Control_up_significant.csv
#     Saved 29 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\CTX-CGE_GABA\Mutant_vs_Control_down_significant.csv
#   Running DGE for Nestin genotype...
#     Filtering genes for Nestin (Initial: 26870)
#     Filtering genes: Requiring expression in >= 46 cells (max of 3 absolute and 10.0% of 460)...
#     Genes after filtering: 8609
#       Calculating mean expression for 8609 genes (Nestin, group CTX-CGE GABA)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Nestin, group CTX-CGE GABA).
#     Finished DGE for Nestin, group CTX-CGE GABA. Found 8609 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_CTX-CGE_GABA_mut_vs_ctrl.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_CTX-CGE_GABA_mut_vs_ctrl.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\CTX-CGE_GABA'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\CTX-CGE_GABA'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\CTX-CGE_GABA' is writable.
#     Saved 77 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\CTX-CGE_GABA\Mutant_vs_Control_up_significant.csv
#     Saved 122 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\CTX-CGE_GABA\Mutant_vs_Control_down_significant.csv
#
# Processing group: OB-IMN GABA (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group OB-IMN GABA: Not enough cells (< 50). Emx1_Control: 35, Emx1_Mutant: 40
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group OB-IMN GABA: Not enough cells (< 50). Nestin_Control: 152, Nestin_Mutant: 38
#
# Processing group: MB GABA (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group MB GABA: Not enough cells (< 50). Emx1_Control: 13, Emx1_Mutant: 15
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group MB GABA: Not enough cells (< 50). Nestin_Control: 36, Nestin_Mutant: 46
#
# Processing group: CNU-LGE GABA (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group CNU-LGE GABA: Not enough cells (< 50). Emx1_Control: 15, Emx1_Mutant: 37
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group CNU-LGE GABA: Not enough cells (< 50). Nestin_Control: 35, Nestin_Mutant: 12
#
# Processing group: LSX GABA (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group LSX GABA: Not enough cells (< 50). Emx1_Control: 11, Emx1_Mutant: 18
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group LSX GABA: Not enough cells (< 50). Nestin_Control: 8, Nestin_Mutant: 6
#
# Processing group: CNU-HYa GABA (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group CNU-HYa GABA: Not enough cells (< 50). Emx1_Control: 9, Emx1_Mutant: 18
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group CNU-HYa GABA: Not enough cells (< 50). Nestin_Control: 28, Nestin_Mutant: 9
#
# Processing group: Vascular (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Filtering genes for Emx1 (Initial: 26870)
#     Filtering genes: Requiring expression in >= 22 cells (max of 3 absolute and 10.0% of 219)...
#     Genes after filtering: 5272
#       Calculating mean expression for 5272 genes (Emx1, group Vascular)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Emx1, group Vascular).
#     Finished DGE for Emx1, group Vascular. Found 5272 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_Vascular_mut_vs_ctrl.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_Vascular_mut_vs_ctrl.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Vascular'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Vascular'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Vascular' is writable.
#     No significant UP genes found for Mutant_vs_Control. Empty CSV file with header created: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Vascular\Mutant_vs_Control_up_significant.csv
#     No significant DOWN genes found for Mutant_vs_Control. Empty CSV file with header created: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Vascular\Mutant_vs_Control_down_significant.csv
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group Vascular: Not enough cells (< 50). Nestin_Control: 140, Nestin_Mutant: 48
#
# Processing group: P Glut (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group P Glut: Not enough cells (< 50). Emx1_Control: 2, Emx1_Mutant: 0
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group P Glut: Not enough cells (< 50). Nestin_Control: 2, Nestin_Mutant: 1
#
# Processing group: CNU-HYa Glut (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group CNU-HYa Glut: Not enough cells (< 50). Emx1_Control: 9, Emx1_Mutant: 21
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group CNU-HYa Glut: Not enough cells (< 50). Nestin_Control: 29, Nestin_Mutant: 11
#
# Processing group: MY GABA (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group MY GABA: Not enough cells (< 50). Emx1_Control: 5, Emx1_Mutant: 6
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group MY GABA: Not enough cells (< 50). Nestin_Control: 8, Nestin_Mutant: 5
#
# Processing group: MB Glut (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group MB Glut: Not enough cells (< 50). Emx1_Control: 6, Emx1_Mutant: 9
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group MB Glut: Not enough cells (< 50). Nestin_Control: 30, Nestin_Mutant: 30
#
# Processing group: P GABA (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group P GABA: Not enough cells (< 50). Emx1_Control: 5, Emx1_Mutant: 5
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group P GABA: Not enough cells (< 50). Nestin_Control: 25, Nestin_Mutant: 12
#
# Processing group: MH-LH Glut (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group MH-LH Glut: Not enough cells (< 50). Emx1_Control: 1, Emx1_Mutant: 2
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group MH-LH Glut: Not enough cells (< 50). Nestin_Control: 1, Nestin_Mutant: 13
#
# Processing group: CNU-MGE GABA (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group CNU-MGE GABA: Not enough cells (< 50). Emx1_Control: 4, Emx1_Mutant: 11
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group CNU-MGE GABA: Not enough cells (< 50). Nestin_Control: 10, Nestin_Mutant: 11
#
# Processing group: CB Glut (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group CB Glut: Not enough cells (< 50). Emx1_Control: 1, Emx1_Mutant: 2
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group CB Glut: Not enough cells (< 50). Nestin_Control: 4, Nestin_Mutant: 2
#
# Processing group: CB GABA (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group CB GABA: Not enough cells (< 50). Emx1_Control: 1, Emx1_Mutant: 0
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group CB GABA: Not enough cells (< 50). Nestin_Control: 2, Nestin_Mutant: 1
#
# Processing group: HY GABA (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group HY GABA: Not enough cells (< 50). Emx1_Control: 3, Emx1_Mutant: 4
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group HY GABA: Not enough cells (< 50). Nestin_Control: 6, Nestin_Mutant: 7
#
# Processing group: TH Glut (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group TH Glut: Not enough cells (< 50). Emx1_Control: 1, Emx1_Mutant: 10
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group TH Glut: Not enough cells (< 50). Nestin_Control: 1, Nestin_Mutant: 1
#
# Processing group: MB Dopa (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group MB Dopa: Not enough cells (< 50). Emx1_Control: 1, Emx1_Mutant: 1
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group MB Dopa: Not enough cells (< 50). Nestin_Control: 0, Nestin_Mutant: 0
#
# Processing group: OEC (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group OEC: Not enough cells (< 50). Emx1_Control: 1, Emx1_Mutant: 0
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group OEC: Not enough cells (< 50). Nestin_Control: 39, Nestin_Mutant: 0
#
# Processing group: MB-HB Sero (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group MB-HB Sero: Not enough cells (< 50). Emx1_Control: 1, Emx1_Mutant: 0
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group MB-HB Sero: Not enough cells (< 50). Nestin_Control: 0, Nestin_Mutant: 0
#
# Processing group: HY Glut (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group HY Glut: Not enough cells (< 50). Emx1_Control: 0, Emx1_Mutant: 4
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group HY Glut: Not enough cells (< 50). Nestin_Control: 7, Nestin_Mutant: 3
#
# Processing group: Pineal Glut (using key 'mapmycells_first_layer')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group Pineal Glut: Not enough cells (< 50). Emx1_Control: 0, Emx1_Mutant: 0
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group Pineal Glut: Not enough cells (< 50). Nestin_Control: 2, Nestin_Mutant: 1
#
# Summary of skipped groups (using key 'mapmycells_first_layer') for Emx1 saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_skipped_mapmycells_first_layer.csv
#
# Summary of skipped groups (using key 'mapmycells_first_layer') for Nestin saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_skipped_mapmycells_first_layer.csv
#
# Genotype-Specific DGE analysis finished.
#
# Generating Volcano Plots for Genotype-Specific DGE results...
#
# --- Visualizing for Genotype: Emx1 ---
#   Generating volcano plot for: Emx1 - Astro-Epen (Counts: Emx1_Ctrl=174, Emx1_Mut=240) -> dge_Emx1_Astro-Epen_volcano.png
# ---
#   Generating volcano plot for: Emx1 - IT-ET Glut (Counts: Emx1_Ctrl=2323, Emx1_Mut=3442) -> dge_Emx1_IT-ET_Glut_volcano.png
# ---
#   Skipping volcano plot for Emx1 - Immune: Not enough cells in one or both groups (< 50). Emx1_Ctrl=72, Emx1_Mut=42.
#   Generating volcano plot for: Emx1 - DG-IMN Glut (Counts: Emx1_Ctrl=861, Emx1_Mut=407) -> dge_Emx1_DG-IMN_Glut_volcano.png
# ---
#   Generating volcano plot for: Emx1 - OPC-Oligo (Counts: Emx1_Ctrl=173, Emx1_Mut=226) -> dge_Emx1_OPC-Oligo_volcano.png
# ---
#   Skipping volcano plot for Emx1 - MY Glut: Not enough cells in one or both groups (< 50). Emx1_Ctrl=10, Emx1_Mut=10.
#   Generating volcano plot for: Emx1 - CTX-MGE GABA (Counts: Emx1_Ctrl=216, Emx1_Mut=409) -> dge_Emx1_CTX-MGE_GABA_volcano.png
# ---
#   Generating volcano plot for: Emx1 - NP-CT-L6b Glut (Counts: Emx1_Ctrl=212, Emx1_Mut=456) -> dge_Emx1_NP-CT-L6b_Glut_volcano.png
# ---
#   Skipping volcano plot for Emx1 - OB-CR Glut: Not enough cells in one or both groups (< 50). Emx1_Ctrl=7, Emx1_Mut=8.
#   Generating volcano plot for: Emx1 - CTX-CGE GABA (Counts: Emx1_Ctrl=144, Emx1_Mut=255) -> dge_Emx1_CTX-CGE_GABA_volcano.png
# ---
#   Skipping volcano plot for Emx1 - OB-IMN GABA: Not enough cells in one or both groups (< 50). Emx1_Ctrl=35, Emx1_Mut=40.
#   Skipping volcano plot for Emx1 - MB GABA: Not enough cells in one or both groups (< 50). Emx1_Ctrl=13, Emx1_Mut=15.
#   Skipping volcano plot for Emx1 - CNU-LGE GABA: Not enough cells in one or both groups (< 50). Emx1_Ctrl=15, Emx1_Mut=37.
#   Skipping volcano plot for Emx1 - LSX GABA: Not enough cells in one or both groups (< 50). Emx1_Ctrl=11, Emx1_Mut=18.
#   Skipping volcano plot for Emx1 - CNU-HYa GABA: Not enough cells in one or both groups (< 50). Emx1_Ctrl=9, Emx1_Mut=18.
#   Generating volcano plot for: Emx1 - Vascular (Counts: Emx1_Ctrl=81, Emx1_Mut=138) -> dge_Emx1_Vascular_volcano.png
# ---
#   Skipping volcano plot for Emx1 - P Glut: Not enough cells in one or both groups (< 50). Emx1_Ctrl=2, Emx1_Mut=0.
#   Skipping volcano plot for Emx1 - CNU-HYa Glut: Not enough cells in one or both groups (< 50). Emx1_Ctrl=9, Emx1_Mut=21.
#   Skipping volcano plot for Emx1 - MY GABA: Not enough cells in one or both groups (< 50). Emx1_Ctrl=5, Emx1_Mut=6.
#   Skipping volcano plot for Emx1 - MB Glut: Not enough cells in one or both groups (< 50). Emx1_Ctrl=6, Emx1_Mut=9.
#   Skipping volcano plot for Emx1 - P GABA: Not enough cells in one or both groups (< 50). Emx1_Ctrl=5, Emx1_Mut=5.
#   Skipping volcano plot for Emx1 - MH-LH Glut: Not enough cells in one or both groups (< 50). Emx1_Ctrl=1, Emx1_Mut=2.
#   Skipping volcano plot for Emx1 - CNU-MGE GABA: Not enough cells in one or both groups (< 50). Emx1_Ctrl=4, Emx1_Mut=11.
#   Skipping volcano plot for Emx1 - CB Glut: Not enough cells in one or both groups (< 50). Emx1_Ctrl=1, Emx1_Mut=2.
#   Skipping volcano plot for Emx1 - CB GABA: Not enough cells in one or both groups (< 50). Emx1_Ctrl=1, Emx1_Mut=0.
#   Skipping volcano plot for Emx1 - HY GABA: Not enough cells in one or both groups (< 50). Emx1_Ctrl=3, Emx1_Mut=4.
#   Skipping volcano plot for Emx1 - TH Glut: Not enough cells in one or both groups (< 50). Emx1_Ctrl=1, Emx1_Mut=10.
#   Skipping volcano plot for Emx1 - MB Dopa: Not enough cells in one or both groups (< 50). Emx1_Ctrl=1, Emx1_Mut=1.
#   Skipping volcano plot for Emx1 - OEC: Not enough cells in one or both groups (< 50). Emx1_Ctrl=1, Emx1_Mut=0.
#   Skipping volcano plot for Emx1 - MB-HB Sero: Not enough cells in one or both groups (< 50). Emx1_Ctrl=1, Emx1_Mut=0.
#   Skipping volcano plot for Emx1 - HY Glut: Not enough cells in one or both groups (< 50). Emx1_Ctrl=0, Emx1_Mut=4.
#   Skipping volcano plot for Emx1 - Pineal Glut: Not enough cells in one or both groups (< 50). Emx1_Ctrl=0, Emx1_Mut=0.
#
# --- Visualizing for Genotype: Nestin ---
#   Generating volcano plot for: Nestin - Astro-Epen (Counts: Nestin_Ctrl=491, Nestin_Mut=180) -> dge_Nestin_Astro-Epen_volcano.png
# ---
#   Generating volcano plot for: Nestin - IT-ET Glut (Counts: Nestin_Ctrl=3202, Nestin_Mut=4472) -> dge_Nestin_IT-ET_Glut_volcano.png
# ---
#   Generating volcano plot for: Nestin - Immune (Counts: Nestin_Ctrl=387, Nestin_Mut=515) -> dge_Nestin_Immune_volcano.png
# ---
#   Generating volcano plot for: Nestin - DG-IMN Glut (Counts: Nestin_Ctrl=1655, Nestin_Mut=959) -> dge_Nestin_DG-IMN_Glut_volcano.png
# ---
#   Generating volcano plot for: Nestin - OPC-Oligo (Counts: Nestin_Ctrl=1094, Nestin_Mut=1157) -> dge_Nestin_OPC-Oligo_volcano.png
# ---
#   Skipping volcano plot for Nestin - MY Glut: Not enough cells in one or both groups (< 50). Nestin_Ctrl=24, Nestin_Mut=9.
#   Generating volcano plot for: Nestin - CTX-MGE GABA (Counts: Nestin_Ctrl=262, Nestin_Mut=509) -> dge_Nestin_CTX-MGE_GABA_volcano.png
# ---
#   Generating volcano plot for: Nestin - NP-CT-L6b Glut (Counts: Nestin_Ctrl=545, Nestin_Mut=975) -> dge_Nestin_NP-CT-L6b_Glut_volcano.png
# ---
#   Skipping volcano plot for Nestin - OB-CR Glut: Not enough cells in one or both groups (< 50). Nestin_Ctrl=38, Nestin_Mut=37.
#   Generating volcano plot for: Nestin - CTX-CGE GABA (Counts: Nestin_Ctrl=159, Nestin_Mut=301) -> dge_Nestin_CTX-CGE_GABA_volcano.png
# ---
#   Skipping volcano plot for Nestin - OB-IMN GABA: Not enough cells in one or both groups (< 50). Nestin_Ctrl=152, Nestin_Mut=38.
#   Skipping volcano plot for Nestin - MB GABA: Not enough cells in one or both groups (< 50). Nestin_Ctrl=36, Nestin_Mut=46.
#   Skipping volcano plot for Nestin - CNU-LGE GABA: Not enough cells in one or both groups (< 50). Nestin_Ctrl=35, Nestin_Mut=12.
#   Skipping volcano plot for Nestin - LSX GABA: Not enough cells in one or both groups (< 50). Nestin_Ctrl=8, Nestin_Mut=6.
#   Skipping volcano plot for Nestin - CNU-HYa GABA: Not enough cells in one or both groups (< 50). Nestin_Ctrl=28, Nestin_Mut=9.
#   Skipping volcano plot for Nestin - Vascular: Not enough cells in one or both groups (< 50). Nestin_Ctrl=140, Nestin_Mut=48.
#   Skipping volcano plot for Nestin - P Glut: Not enough cells in one or both groups (< 50). Nestin_Ctrl=2, Nestin_Mut=1.
#   Skipping volcano plot for Nestin - CNU-HYa Glut: Not enough cells in one or both groups (< 50). Nestin_Ctrl=29, Nestin_Mut=11.
#   Skipping volcano plot for Nestin - MY GABA: Not enough cells in one or both groups (< 50). Nestin_Ctrl=8, Nestin_Mut=5.
#   Skipping volcano plot for Nestin - MB Glut: Not enough cells in one or both groups (< 50). Nestin_Ctrl=30, Nestin_Mut=30.
#   Skipping volcano plot for Nestin - P GABA: Not enough cells in one or both groups (< 50). Nestin_Ctrl=25, Nestin_Mut=12.
#   Skipping volcano plot for Nestin - MH-LH Glut: Not enough cells in one or both groups (< 50). Nestin_Ctrl=1, Nestin_Mut=13.
#   Skipping volcano plot for Nestin - CNU-MGE GABA: Not enough cells in one or both groups (< 50). Nestin_Ctrl=10, Nestin_Mut=11.
#   Skipping volcano plot for Nestin - CB Glut: Not enough cells in one or both groups (< 50). Nestin_Ctrl=4, Nestin_Mut=2.
#   Skipping volcano plot for Nestin - CB GABA: Not enough cells in one or both groups (< 50). Nestin_Ctrl=2, Nestin_Mut=1.
#   Skipping volcano plot for Nestin - HY GABA: Not enough cells in one or both groups (< 50). Nestin_Ctrl=6, Nestin_Mut=7.
#   Skipping volcano plot for Nestin - TH Glut: Not enough cells in one or both groups (< 50). Nestin_Ctrl=1, Nestin_Mut=1.
#   Skipping volcano plot for Nestin - MB Dopa: Not enough cells in one or both groups (< 50). Nestin_Ctrl=0, Nestin_Mut=0.
#   Skipping volcano plot for Nestin - OEC: Not enough cells in one or both groups (< 50). Nestin_Ctrl=39, Nestin_Mut=0.
#   Skipping volcano plot for Nestin - MB-HB Sero: Not enough cells in one or both groups (< 50). Nestin_Ctrl=0, Nestin_Mut=0.
#   Skipping volcano plot for Nestin - HY Glut: Not enough cells in one or both groups (< 50). Nestin_Ctrl=7, Nestin_Mut=3.
#   Skipping volcano plot for Nestin - Pineal Glut: Not enough cells in one or both groups (< 50). Nestin_Ctrl=2, Nestin_Mut=1.
#
# Genotype-Specific DGE visualization finished.

# %%
# Genotype Comparison DGE (Nestin vs Emx1 within each condition) using the 'for_DEGs' layer, grouped by the DEG_BY
print(f"\nRunning Genotype Comparison DGE (grouped by {DEG_BY})...")
dge_genotype_within_condition = functions_degs.run_genotype_comparison_dge(
    adata,
    grouping_key=DEG_BY,
    dge_output_dir=DGE_OUTPUT_DIR,
    plot_output_dir=PLOT_OUTPUT_DIR,
    layer='for_DEGs' if 'for_DEGs' in adata.layers else None
)
# Out:
# Running Genotype Comparison DGE (grouped by mapmycells_first_layer)...
#
# Starting DGE analysis: Genotype comparison within conditions...
#
# Processing group: Astro-Epen (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Initial genes for Control condition: 26870
#     Filtering genes for Control: Requiring expression in >= 67 cells (max of 3 absolute and 10.0% of 665)...
#     Genes after filtering for Control: 6278
#       Calculating mean expression for 6278 genes (Control condition, group Astro-Epen)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Control condition, group Astro-Epen).
#     Finished DGE for Control, group Astro-Epen. Found 6278 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_Astro-Epen_Nestin_vs_Emx1.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_Astro-Epen_Nestin_vs_Emx1.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Astro-Epen'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Astro-Epen'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Astro-Epen' is writable.
#     Saved 1538 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Astro-Epen\Nestin_vs_Emx1_up_significant.csv
#     Saved 319 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Astro-Epen\Nestin_vs_Emx1_down_significant.csv
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Initial genes for Mutant condition: 26870
#     Filtering genes for Mutant: Requiring expression in >= 42 cells (max of 3 absolute and 10.0% of 420)...
#     Genes after filtering for Mutant: 4975
#       Calculating mean expression for 4975 genes (Mutant condition, group Astro-Epen)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Mutant condition, group Astro-Epen).
#     Finished DGE for Mutant, group Astro-Epen. Found 4975 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_Astro-Epen_Nestin_vs_Emx1.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_Astro-Epen_Nestin_vs_Emx1.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\Astro-Epen'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\Astro-Epen'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\Astro-Epen' is writable.
#     Saved 231 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\Astro-Epen\Nestin_vs_Emx1_up_significant.csv
#     Saved 302 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\Astro-Epen\Nestin_vs_Emx1_down_significant.csv
#
# Processing group: IT-ET Glut (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Initial genes for Control condition: 26870
#     Filtering genes for Control: Requiring expression in >= 553 cells (max of 3 absolute and 10.0% of 5525)...
#     Genes after filtering for Control: 10174
#       Calculating mean expression for 10174 genes (Control condition, group IT-ET Glut)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Control condition, group IT-ET Glut).
#     Finished DGE for Control, group IT-ET Glut. Found 10174 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_IT-ET_Glut_Nestin_vs_Emx1.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_IT-ET_Glut_Nestin_vs_Emx1.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\IT-ET_Glut'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\IT-ET_Glut'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\IT-ET_Glut' is writable.
#     Saved 884 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\IT-ET_Glut\Nestin_vs_Emx1_up_significant.csv
#     Saved 2319 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\IT-ET_Glut\Nestin_vs_Emx1_down_significant.csv
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Initial genes for Mutant condition: 26870
#     Filtering genes for Mutant: Requiring expression in >= 792 cells (max of 3 absolute and 10.0% of 7914)...
#     Genes after filtering for Mutant: 10059
#       Calculating mean expression for 10059 genes (Mutant condition, group IT-ET Glut)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Mutant condition, group IT-ET Glut).
#     Finished DGE for Mutant, group IT-ET Glut. Found 10059 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_IT-ET_Glut_Nestin_vs_Emx1.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_IT-ET_Glut_Nestin_vs_Emx1.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\IT-ET_Glut'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\IT-ET_Glut'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\IT-ET_Glut' is writable.
#     Saved 1585 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\IT-ET_Glut\Nestin_vs_Emx1_up_significant.csv
#     Saved 2220 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\IT-ET_Glut\Nestin_vs_Emx1_down_significant.csv
#
# Processing group: Immune (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Initial genes for Control condition: 26870
#     Filtering genes for Control: Requiring expression in >= 46 cells (max of 3 absolute and 10.0% of 459)...
#     Genes after filtering for Control: 4401
#       Calculating mean expression for 4401 genes (Control condition, group Immune)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Control condition, group Immune).
#     Finished DGE for Control, group Immune. Found 4401 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_Immune_Nestin_vs_Emx1.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_Immune_Nestin_vs_Emx1.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Immune'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Immune'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Immune' is writable.
#     Saved 849 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Immune\Nestin_vs_Emx1_up_significant.csv
#     Saved 168 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Immune\Nestin_vs_Emx1_down_significant.csv
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group Immune: Not enough cells (< 50). Emx1_Mutant: 42, Nestin_Mutant: 515
#
# Processing group: DG-IMN Glut (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Initial genes for Control condition: 26870
#     Filtering genes for Control: Requiring expression in >= 252 cells (max of 3 absolute and 10.0% of 2516)...
#     Genes after filtering for Control: 9560
#       Calculating mean expression for 9560 genes (Control condition, group DG-IMN Glut)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Control condition, group DG-IMN Glut).
#     Finished DGE for Control, group DG-IMN Glut. Found 9560 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_DG-IMN_Glut_Nestin_vs_Emx1.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_DG-IMN_Glut_Nestin_vs_Emx1.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\DG-IMN_Glut'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\DG-IMN_Glut'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\DG-IMN_Glut' is writable.
#     Saved 1661 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\DG-IMN_Glut\Nestin_vs_Emx1_up_significant.csv
#     Saved 1696 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\DG-IMN_Glut\Nestin_vs_Emx1_down_significant.csv
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Initial genes for Mutant condition: 26870
#     Filtering genes for Mutant: Requiring expression in >= 137 cells (max of 3 absolute and 10.0% of 1366)...
#     Genes after filtering for Mutant: 8494
#       Calculating mean expression for 8494 genes (Mutant condition, group DG-IMN Glut)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Mutant condition, group DG-IMN Glut).
#     Finished DGE for Mutant, group DG-IMN Glut. Found 8494 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_DG-IMN_Glut_Nestin_vs_Emx1.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_DG-IMN_Glut_Nestin_vs_Emx1.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\DG-IMN_Glut'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\DG-IMN_Glut'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\DG-IMN_Glut' is writable.
#     Saved 799 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\DG-IMN_Glut\Nestin_vs_Emx1_up_significant.csv
#     Saved 1193 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\DG-IMN_Glut\Nestin_vs_Emx1_down_significant.csv
#
# Processing group: OPC-Oligo (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Initial genes for Control condition: 26870
#     Filtering genes for Control: Requiring expression in >= 127 cells (max of 3 absolute and 10.0% of 1267)...
#     Genes after filtering for Control: 6025
#       Calculating mean expression for 6025 genes (Control condition, group OPC-Oligo)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Control condition, group OPC-Oligo).
#     Finished DGE for Control, group OPC-Oligo. Found 6025 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_OPC-Oligo_Nestin_vs_Emx1.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_OPC-Oligo_Nestin_vs_Emx1.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\OPC-Oligo'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\OPC-Oligo'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\OPC-Oligo' is writable.
#     Saved 1671 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\OPC-Oligo\Nestin_vs_Emx1_up_significant.csv
#     Saved 314 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\OPC-Oligo\Nestin_vs_Emx1_down_significant.csv
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Initial genes for Mutant condition: 26870
#     Filtering genes for Mutant: Requiring expression in >= 139 cells (max of 3 absolute and 10.0% of 1383)...
#     Genes after filtering for Mutant: 4586
#       Calculating mean expression for 4586 genes (Mutant condition, group OPC-Oligo)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Mutant condition, group OPC-Oligo).
#     Finished DGE for Mutant, group OPC-Oligo. Found 4586 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_OPC-Oligo_Nestin_vs_Emx1.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_OPC-Oligo_Nestin_vs_Emx1.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\OPC-Oligo'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\OPC-Oligo'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\OPC-Oligo' is writable.
#     Saved 500 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\OPC-Oligo\Nestin_vs_Emx1_up_significant.csv
#     Saved 267 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\OPC-Oligo\Nestin_vs_Emx1_down_significant.csv
#
# Processing group: MY Glut (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group MY Glut: Not enough cells (< 50). Emx1_Control: 10, Nestin_Control: 24
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group MY Glut: Not enough cells (< 50). Emx1_Mutant: 10, Nestin_Mutant: 9
#
# Processing group: CTX-MGE GABA (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Initial genes for Control condition: 26870
#     Filtering genes for Control: Requiring expression in >= 48 cells (max of 3 absolute and 10.0% of 478)...
#     Genes after filtering for Control: 10085
#       Calculating mean expression for 10085 genes (Control condition, group CTX-MGE GABA)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Control condition, group CTX-MGE GABA).
#     Finished DGE for Control, group CTX-MGE GABA. Found 10085 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_CTX-MGE_GABA_Nestin_vs_Emx1.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_CTX-MGE_GABA_Nestin_vs_Emx1.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\CTX-MGE_GABA'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\CTX-MGE_GABA'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\CTX-MGE_GABA' is writable.
#     Saved 728 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\CTX-MGE_GABA\Nestin_vs_Emx1_up_significant.csv
#     Saved 512 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\CTX-MGE_GABA\Nestin_vs_Emx1_down_significant.csv
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Initial genes for Mutant condition: 26870
#     Filtering genes for Mutant: Requiring expression in >= 92 cells (max of 3 absolute and 10.0% of 918)...
#     Genes after filtering for Mutant: 9231
#       Calculating mean expression for 9231 genes (Mutant condition, group CTX-MGE GABA)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Mutant condition, group CTX-MGE GABA).
#     Finished DGE for Mutant, group CTX-MGE GABA. Found 9231 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_CTX-MGE_GABA_Nestin_vs_Emx1.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_CTX-MGE_GABA_Nestin_vs_Emx1.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\CTX-MGE_GABA'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\CTX-MGE_GABA'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\CTX-MGE_GABA' is writable.
#     Saved 637 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\CTX-MGE_GABA\Nestin_vs_Emx1_up_significant.csv
#     Saved 1043 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\CTX-MGE_GABA\Nestin_vs_Emx1_down_significant.csv
#
# Processing group: NP-CT-L6b Glut (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Initial genes for Control condition: 26870
#     Filtering genes for Control: Requiring expression in >= 76 cells (max of 3 absolute and 10.0% of 757)...
#     Genes after filtering for Control: 10703
#       Calculating mean expression for 10703 genes (Control condition, group NP-CT-L6b Glut)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Control condition, group NP-CT-L6b Glut).
#     Finished DGE for Control, group NP-CT-L6b Glut. Found 10703 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_NP-CT-L6b_Glut_Nestin_vs_Emx1.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_NP-CT-L6b_Glut_Nestin_vs_Emx1.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\NP-CT-L6b_Glut'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\NP-CT-L6b_Glut'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\NP-CT-L6b_Glut' is writable.
#     Saved 1204 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\NP-CT-L6b_Glut\Nestin_vs_Emx1_up_significant.csv
#     Saved 548 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\NP-CT-L6b_Glut\Nestin_vs_Emx1_down_significant.csv
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Initial genes for Mutant condition: 26870
#     Filtering genes for Mutant: Requiring expression in >= 144 cells (max of 3 absolute and 10.0% of 1431)...
#     Genes after filtering for Mutant: 10557
#       Calculating mean expression for 10557 genes (Mutant condition, group NP-CT-L6b Glut)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Mutant condition, group NP-CT-L6b Glut).
#     Finished DGE for Mutant, group NP-CT-L6b Glut. Found 10557 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_NP-CT-L6b_Glut_Nestin_vs_Emx1.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_NP-CT-L6b_Glut_Nestin_vs_Emx1.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\NP-CT-L6b_Glut'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\NP-CT-L6b_Glut'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\NP-CT-L6b_Glut' is writable.
#     Saved 1210 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\NP-CT-L6b_Glut\Nestin_vs_Emx1_up_significant.csv
#     Saved 1166 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\NP-CT-L6b_Glut\Nestin_vs_Emx1_down_significant.csv
#
# Processing group: OB-CR Glut (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group OB-CR Glut: Not enough cells (< 50). Emx1_Control: 7, Nestin_Control: 38
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group OB-CR Glut: Not enough cells (< 50). Emx1_Mutant: 8, Nestin_Mutant: 37
#
# Processing group: CTX-CGE GABA (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Initial genes for Control condition: 26870
#     Filtering genes for Control: Requiring expression in >= 31 cells (max of 3 absolute and 10.0% of 303)...
#     Genes after filtering for Control: 9398
#       Calculating mean expression for 9398 genes (Control condition, group CTX-CGE GABA)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Control condition, group CTX-CGE GABA).
#     Finished DGE for Control, group CTX-CGE GABA. Found 9398 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_CTX-CGE_GABA_Nestin_vs_Emx1.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_CTX-CGE_GABA_Nestin_vs_Emx1.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\CTX-CGE_GABA'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\CTX-CGE_GABA'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\CTX-CGE_GABA' is writable.
#     Saved 132 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\CTX-CGE_GABA\Nestin_vs_Emx1_up_significant.csv
#     Saved 274 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\CTX-CGE_GABA\Nestin_vs_Emx1_down_significant.csv
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Initial genes for Mutant condition: 26870
#     Filtering genes for Mutant: Requiring expression in >= 56 cells (max of 3 absolute and 10.0% of 556)...
#     Genes after filtering for Mutant: 8529
#       Calculating mean expression for 8529 genes (Mutant condition, group CTX-CGE GABA)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Mutant condition, group CTX-CGE GABA).
#     Finished DGE for Mutant, group CTX-CGE GABA. Found 8529 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_CTX-CGE_GABA_Nestin_vs_Emx1.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_CTX-CGE_GABA_Nestin_vs_Emx1.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\CTX-CGE_GABA'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\CTX-CGE_GABA'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\CTX-CGE_GABA' is writable.
#     Saved 492 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\CTX-CGE_GABA\Nestin_vs_Emx1_up_significant.csv
#     Saved 638 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\CTX-CGE_GABA\Nestin_vs_Emx1_down_significant.csv
#
# Processing group: OB-IMN GABA (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group OB-IMN GABA: Not enough cells (< 50). Emx1_Control: 35, Nestin_Control: 152
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group OB-IMN GABA: Not enough cells (< 50). Emx1_Mutant: 40, Nestin_Mutant: 38
#
# Processing group: MB GABA (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group MB GABA: Not enough cells (< 50). Emx1_Control: 13, Nestin_Control: 36
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group MB GABA: Not enough cells (< 50). Emx1_Mutant: 15, Nestin_Mutant: 46
#
# Processing group: CNU-LGE GABA (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group CNU-LGE GABA: Not enough cells (< 50). Emx1_Control: 15, Nestin_Control: 35
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group CNU-LGE GABA: Not enough cells (< 50). Emx1_Mutant: 37, Nestin_Mutant: 12
#
# Processing group: LSX GABA (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group LSX GABA: Not enough cells (< 50). Emx1_Control: 11, Nestin_Control: 8
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group LSX GABA: Not enough cells (< 50). Emx1_Mutant: 18, Nestin_Mutant: 6
#
# Processing group: CNU-HYa GABA (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group CNU-HYa GABA: Not enough cells (< 50). Emx1_Control: 9, Nestin_Control: 28
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group CNU-HYa GABA: Not enough cells (< 50). Emx1_Mutant: 18, Nestin_Mutant: 9
#
# Processing group: Vascular (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Initial genes for Control condition: 26870
#     Filtering genes for Control: Requiring expression in >= 23 cells (max of 3 absolute and 10.0% of 221)...
#     Genes after filtering for Control: 6288
#       Calculating mean expression for 6288 genes (Control condition, group Vascular)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Control condition, group Vascular).
#     Finished DGE for Control, group Vascular. Found 6288 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_Vascular_Nestin_vs_Emx1.csv
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_Vascular_Nestin_vs_Emx1.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Vascular'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Vascular'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Vascular' is writable.
#     Saved 457 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Vascular\Nestin_vs_Emx1_up_significant.csv
#     Saved 184 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Vascular\Nestin_vs_Emx1_down_significant.csv
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group Vascular: Not enough cells (< 50). Emx1_Mutant: 138, Nestin_Mutant: 48
#
# Processing group: P Glut (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group P Glut: Not enough cells (< 50). Emx1_Control: 2, Nestin_Control: 2
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group P Glut: Not enough cells (< 50). Emx1_Mutant: 0, Nestin_Mutant: 1
#
# Processing group: CNU-HYa Glut (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group CNU-HYa Glut: Not enough cells (< 50). Emx1_Control: 9, Nestin_Control: 29
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group CNU-HYa Glut: Not enough cells (< 50). Emx1_Mutant: 21, Nestin_Mutant: 11
#
# Processing group: MY GABA (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group MY GABA: Not enough cells (< 50). Emx1_Control: 5, Nestin_Control: 8
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group MY GABA: Not enough cells (< 50). Emx1_Mutant: 6, Nestin_Mutant: 5
#
# Processing group: MB Glut (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group MB Glut: Not enough cells (< 50). Emx1_Control: 6, Nestin_Control: 30
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group MB Glut: Not enough cells (< 50). Emx1_Mutant: 9, Nestin_Mutant: 30
#
# Processing group: P GABA (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group P GABA: Not enough cells (< 50). Emx1_Control: 5, Nestin_Control: 25
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group P GABA: Not enough cells (< 50). Emx1_Mutant: 5, Nestin_Mutant: 12
#
# Processing group: MH-LH Glut (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group MH-LH Glut: Not enough cells (< 50). Emx1_Control: 1, Nestin_Control: 1
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group MH-LH Glut: Not enough cells (< 50). Emx1_Mutant: 2, Nestin_Mutant: 13
#
# Processing group: CNU-MGE GABA (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group CNU-MGE GABA: Not enough cells (< 50). Emx1_Control: 4, Nestin_Control: 10
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group CNU-MGE GABA: Not enough cells (< 50). Emx1_Mutant: 11, Nestin_Mutant: 11
#
# Processing group: CB Glut (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group CB Glut: Not enough cells (< 50). Emx1_Control: 1, Nestin_Control: 4
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group CB Glut: Not enough cells (< 50). Emx1_Mutant: 2, Nestin_Mutant: 2
#
# Processing group: CB GABA (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group CB GABA: Not enough cells (< 50). Emx1_Control: 1, Nestin_Control: 2
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group CB GABA: Not enough cells (< 50). Emx1_Mutant: 0, Nestin_Mutant: 1
#
# Processing group: HY GABA (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group HY GABA: Not enough cells (< 50). Emx1_Control: 3, Nestin_Control: 6
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group HY GABA: Not enough cells (< 50). Emx1_Mutant: 4, Nestin_Mutant: 7
#
# Processing group: TH Glut (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group TH Glut: Not enough cells (< 50). Emx1_Control: 1, Nestin_Control: 1
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group TH Glut: Not enough cells (< 50). Emx1_Mutant: 10, Nestin_Mutant: 1
#
# Processing group: MB Dopa (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group MB Dopa: Not enough cells (< 50). Emx1_Control: 1, Nestin_Control: 0
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group MB Dopa: Not enough cells (< 50). Emx1_Mutant: 1, Nestin_Mutant: 0
#
# Processing group: OEC (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group OEC: Not enough cells (< 50). Emx1_Control: 1, Nestin_Control: 39
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group OEC: Not enough cells (< 50). Emx1_Mutant: 0, Nestin_Mutant: 0
#
# Processing group: MB-HB Sero (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group MB-HB Sero: Not enough cells (< 50). Emx1_Control: 1, Nestin_Control: 0
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group MB-HB Sero: Not enough cells (< 50). Emx1_Mutant: 0, Nestin_Mutant: 0
#
# Processing group: HY Glut (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group HY Glut: Not enough cells (< 50). Emx1_Control: 0, Nestin_Control: 7
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group HY Glut: Not enough cells (< 50). Emx1_Mutant: 4, Nestin_Mutant: 3
#
# Processing group: Pineal Glut (using key 'mapmycells_first_layer')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group Pineal Glut: Not enough cells (< 50). Emx1_Control: 0, Nestin_Control: 2
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group Pineal Glut: Not enough cells (< 50). Emx1_Mutant: 0, Nestin_Mutant: 1
#
# Summary of skipped groups (using key 'mapmycells_first_layer') for Control condition comparison saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_comparison_skipped_mapmycells_first_layer.csv
#
# Summary of skipped groups (using key 'mapmycells_first_layer') for Mutant condition comparison saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_comparison_skipped_mapmycells_first_layer.csv
#
# DGE analysis (Genotype comparison within conditions) finished.
#
# Generating Volcano Plots for Genotype comparison within conditions...
#
# --- Visualizing for Condition: Control (Nestin vs Emx1) ---
#   Generating volcano plot for: Control Cond - Astro-Epen (Counts: Emx1_Control=174, Nestin_Control=491) -> dge_Control_cond_Nestin_vs_Emx1_Astro-Epen_volcano.png
# ---
#   Generating volcano plot for: Control Cond - IT-ET Glut (Counts: Emx1_Control=2323, Nestin_Control=3202) -> dge_Control_cond_Nestin_vs_Emx1_IT-ET_Glut_volcano.png
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# ---
#   Generating volcano plot for: Control Cond - Immune (Counts: Emx1_Control=72, Nestin_Control=387) -> dge_Control_cond_Nestin_vs_Emx1_Immune_volcano.png
# ---
#   Generating volcano plot for: Control Cond - DG-IMN Glut (Counts: Emx1_Control=861, Nestin_Control=1655) -> dge_Control_cond_Nestin_vs_Emx1_DG-IMN_Glut_volcano.png
# ---
#   Generating volcano plot for: Control Cond - OPC-Oligo (Counts: Emx1_Control=173, Nestin_Control=1094) -> dge_Control_cond_Nestin_vs_Emx1_OPC-Oligo_volcano.png
# ---
#   Skipping volcano plot for Control Cond - MY Glut: Not enough cells in one or both groups (< 50). Emx1_Control=10, Nestin_Control=24.
#   Generating volcano plot for: Control Cond - CTX-MGE GABA (Counts: Emx1_Control=216, Nestin_Control=262) -> dge_Control_cond_Nestin_vs_Emx1_CTX-MGE_GABA_volcano.png
# ---
#   Generating volcano plot for: Control Cond - NP-CT-L6b Glut (Counts: Emx1_Control=212, Nestin_Control=545) -> dge_Control_cond_Nestin_vs_Emx1_NP-CT-L6b_Glut_volcano.png
# ---
#   Skipping volcano plot for Control Cond - OB-CR Glut: Not enough cells in one or both groups (< 50). Emx1_Control=7, Nestin_Control=38.
#   Generating volcano plot for: Control Cond - CTX-CGE GABA (Counts: Emx1_Control=144, Nestin_Control=159) -> dge_Control_cond_Nestin_vs_Emx1_CTX-CGE_GABA_volcano.png
# ---
#   Skipping volcano plot for Control Cond - OB-IMN GABA: Not enough cells in one or both groups (< 50). Emx1_Control=35, Nestin_Control=152.
#   Skipping volcano plot for Control Cond - MB GABA: Not enough cells in one or both groups (< 50). Emx1_Control=13, Nestin_Control=36.
#   Skipping volcano plot for Control Cond - CNU-LGE GABA: Not enough cells in one or both groups (< 50). Emx1_Control=15, Nestin_Control=35.
#   Skipping volcano plot for Control Cond - LSX GABA: Not enough cells in one or both groups (< 50). Emx1_Control=11, Nestin_Control=8.
#   Skipping volcano plot for Control Cond - CNU-HYa GABA: Not enough cells in one or both groups (< 50). Emx1_Control=9, Nestin_Control=28.
#   Generating volcano plot for: Control Cond - Vascular (Counts: Emx1_Control=81, Nestin_Control=140) -> dge_Control_cond_Nestin_vs_Emx1_Vascular_volcano.png
# ---
#   Skipping volcano plot for Control Cond - P Glut: Not enough cells in one or both groups (< 50). Emx1_Control=2, Nestin_Control=2.
#   Skipping volcano plot for Control Cond - CNU-HYa Glut: Not enough cells in one or both groups (< 50). Emx1_Control=9, Nestin_Control=29.
#   Skipping volcano plot for Control Cond - MY GABA: Not enough cells in one or both groups (< 50). Emx1_Control=5, Nestin_Control=8.
#   Skipping volcano plot for Control Cond - MB Glut: Not enough cells in one or both groups (< 50). Emx1_Control=6, Nestin_Control=30.
#   Skipping volcano plot for Control Cond - P GABA: Not enough cells in one or both groups (< 50). Emx1_Control=5, Nestin_Control=25.
#   Skipping volcano plot for Control Cond - MH-LH Glut: Not enough cells in one or both groups (< 50). Emx1_Control=1, Nestin_Control=1.
#   Skipping volcano plot for Control Cond - CNU-MGE GABA: Not enough cells in one or both groups (< 50). Emx1_Control=4, Nestin_Control=10.
#   Skipping volcano plot for Control Cond - CB Glut: Not enough cells in one or both groups (< 50). Emx1_Control=1, Nestin_Control=4.
#   Skipping volcano plot for Control Cond - CB GABA: Not enough cells in one or both groups (< 50). Emx1_Control=1, Nestin_Control=2.
#   Skipping volcano plot for Control Cond - HY GABA: Not enough cells in one or both groups (< 50). Emx1_Control=3, Nestin_Control=6.
#   Skipping volcano plot for Control Cond - TH Glut: Not enough cells in one or both groups (< 50). Emx1_Control=1, Nestin_Control=1.
#   Skipping volcano plot for Control Cond - MB Dopa: Not enough cells in one or both groups (< 50). Emx1_Control=1, Nestin_Control=0.
#   Skipping volcano plot for Control Cond - OEC: Not enough cells in one or both groups (< 50). Emx1_Control=1, Nestin_Control=39.
#   Skipping volcano plot for Control Cond - MB-HB Sero: Not enough cells in one or both groups (< 50). Emx1_Control=1, Nestin_Control=0.
#   Skipping volcano plot for Control Cond - HY Glut: Not enough cells in one or both groups (< 50). Emx1_Control=0, Nestin_Control=7.
#   Skipping volcano plot for Control Cond - Pineal Glut: Not enough cells in one or both groups (< 50). Emx1_Control=0, Nestin_Control=2.
#
# --- Visualizing for Condition: Mutant (Nestin vs Emx1) ---
#   Generating volcano plot for: Mutant Cond - Astro-Epen (Counts: Emx1_Mutant=240, Nestin_Mutant=180) -> dge_Mutant_cond_Nestin_vs_Emx1_Astro-Epen_volcano.png
# ---
#   Generating volcano plot for: Mutant Cond - IT-ET Glut (Counts: Emx1_Mutant=3442, Nestin_Mutant=4472) -> dge_Mutant_cond_Nestin_vs_Emx1_IT-ET_Glut_volcano.png
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# ---
#   Skipping volcano plot for Mutant Cond - Immune: Not enough cells in one or both groups (< 50). Emx1_Mutant=42, Nestin_Mutant=515.
#   Generating volcano plot for: Mutant Cond - DG-IMN Glut (Counts: Emx1_Mutant=407, Nestin_Mutant=959) -> dge_Mutant_cond_Nestin_vs_Emx1_DG-IMN_Glut_volcano.png
# ---
#   Generating volcano plot for: Mutant Cond - OPC-Oligo (Counts: Emx1_Mutant=226, Nestin_Mutant=1157) -> dge_Mutant_cond_Nestin_vs_Emx1_OPC-Oligo_volcano.png
# ---
#   Skipping volcano plot for Mutant Cond - MY Glut: Not enough cells in one or both groups (< 50). Emx1_Mutant=10, Nestin_Mutant=9.
#   Generating volcano plot for: Mutant Cond - CTX-MGE GABA (Counts: Emx1_Mutant=409, Nestin_Mutant=509) -> dge_Mutant_cond_Nestin_vs_Emx1_CTX-MGE_GABA_volcano.png
# ---
#   Generating volcano plot for: Mutant Cond - NP-CT-L6b Glut (Counts: Emx1_Mutant=456, Nestin_Mutant=975) -> dge_Mutant_cond_Nestin_vs_Emx1_NP-CT-L6b_Glut_volcano.png
# ---
#   Skipping volcano plot for Mutant Cond - OB-CR Glut: Not enough cells in one or both groups (< 50). Emx1_Mutant=8, Nestin_Mutant=37.
#   Generating volcano plot for: Mutant Cond - CTX-CGE GABA (Counts: Emx1_Mutant=255, Nestin_Mutant=301) -> dge_Mutant_cond_Nestin_vs_Emx1_CTX-CGE_GABA_volcano.png
# ---
#   Skipping volcano plot for Mutant Cond - OB-IMN GABA: Not enough cells in one or both groups (< 50). Emx1_Mutant=40, Nestin_Mutant=38.
#   Skipping volcano plot for Mutant Cond - MB GABA: Not enough cells in one or both groups (< 50). Emx1_Mutant=15, Nestin_Mutant=46.
#   Skipping volcano plot for Mutant Cond - CNU-LGE GABA: Not enough cells in one or both groups (< 50). Emx1_Mutant=37, Nestin_Mutant=12.
#   Skipping volcano plot for Mutant Cond - LSX GABA: Not enough cells in one or both groups (< 50). Emx1_Mutant=18, Nestin_Mutant=6.
#   Skipping volcano plot for Mutant Cond - CNU-HYa GABA: Not enough cells in one or both groups (< 50). Emx1_Mutant=18, Nestin_Mutant=9.
#   Skipping volcano plot for Mutant Cond - Vascular: Not enough cells in one or both groups (< 50). Emx1_Mutant=138, Nestin_Mutant=48.
#   Skipping volcano plot for Mutant Cond - P Glut: Not enough cells in one or both groups (< 50). Emx1_Mutant=0, Nestin_Mutant=1.
#   Skipping volcano plot for Mutant Cond - CNU-HYa Glut: Not enough cells in one or both groups (< 50). Emx1_Mutant=21, Nestin_Mutant=11.
#   Skipping volcano plot for Mutant Cond - MY GABA: Not enough cells in one or both groups (< 50). Emx1_Mutant=6, Nestin_Mutant=5.
#   Skipping volcano plot for Mutant Cond - MB Glut: Not enough cells in one or both groups (< 50). Emx1_Mutant=9, Nestin_Mutant=30.
#   Skipping volcano plot for Mutant Cond - P GABA: Not enough cells in one or both groups (< 50). Emx1_Mutant=5, Nestin_Mutant=12.
#   Skipping volcano plot for Mutant Cond - MH-LH Glut: Not enough cells in one or both groups (< 50). Emx1_Mutant=2, Nestin_Mutant=13.
#   Skipping volcano plot for Mutant Cond - CNU-MGE GABA: Not enough cells in one or both groups (< 50). Emx1_Mutant=11, Nestin_Mutant=11.
#   Skipping volcano plot for Mutant Cond - CB Glut: Not enough cells in one or both groups (< 50). Emx1_Mutant=2, Nestin_Mutant=2.
#   Skipping volcano plot for Mutant Cond - CB GABA: Not enough cells in one or both groups (< 50). Emx1_Mutant=0, Nestin_Mutant=1.
#   Skipping volcano plot for Mutant Cond - HY GABA: Not enough cells in one or both groups (< 50). Emx1_Mutant=4, Nestin_Mutant=7.
#   Skipping volcano plot for Mutant Cond - TH Glut: Not enough cells in one or both groups (< 50). Emx1_Mutant=10, Nestin_Mutant=1.
#   Skipping volcano plot for Mutant Cond - MB Dopa: Not enough cells in one or both groups (< 50). Emx1_Mutant=1, Nestin_Mutant=0.
#   Skipping volcano plot for Mutant Cond - OEC: Not enough cells in one or both groups (< 50). Emx1_Mutant=0, Nestin_Mutant=0.
#   Skipping volcano plot for Mutant Cond - MB-HB Sero: Not enough cells in one or both groups (< 50). Emx1_Mutant=0, Nestin_Mutant=0.
#   Skipping volcano plot for Mutant Cond - HY Glut: Not enough cells in one or both groups (< 50). Emx1_Mutant=4, Nestin_Mutant=3.
#   Skipping volcano plot for Mutant Cond - Pineal Glut: Not enough cells in one or both groups (< 50). Emx1_Mutant=0, Nestin_Mutant=1.
#
# DGE visualization (Genotype comparison within conditions) finished.

# %%
# Cell Type Comparison DGE (Each cell type vs Rest) using the 'for_DEGs' layer, using the DEG_BY
print(f"\nRunning Cell Type Comparison DGE (Markers for {DEG_BY})...")
dge_mapmycells_second_layer_markers = functions_degs.run_cluster_comparison_dge(
    adata,
    grouping_key=DEG_BY, 
    dge_output_dir=BIOMARKER_OUTPUT_DIR, 
    plot_output_dir=BIOMARKER_OUTPUT_DIR,
    layer='for_DEGs' if 'for_DEGs' in adata.layers else None,
    method='wilcoxon' # or 't-test'
)
# Out:
# Running Cell Type Comparison DGE (Markers for mapmycells_first_layer)...
#
# Starting Cluster Comparison DGE analysis (Markers for 'mapmycells_first_layer') into D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers...
#   Initial genes: 26870
#   Filtering genes globally: Requiring expression in >= 3 cells...
#   Genes after global filtering: 26870
#   Warning: Skipping group 'MB Dopa' from DGE as it only contains 2 cells (less than 3).
#   Warning: Skipping group 'MB-HB Sero' from DGE as it only contains 1 cells (less than 3).
#   Proceeding with DGE for 30 groups. Removed groups: ['MB Dopa', 'MB-HB Sero']
#   Running sc.tl.rank_genes_groups (groupby='mapmycells_first_layer', method='wilcoxon')...
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:456: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:458: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:461: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:471: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:482: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:456: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:458: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:461: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:471: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:482: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:456: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:458: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:461: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:471: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:482: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:456: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:458: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:461: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:471: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:482: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:456: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:458: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:461: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:471: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:482: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:456: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:458: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:461: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:471: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:482: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:456: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:458: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:461: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:471: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:482: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:456: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:458: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:461: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:471: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:482: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:456: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:458: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:461: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:471: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:482: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:456: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:458: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:461: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:471: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# d:\Programs\miniforge3\envs\bioinf\Lib\site-packages\scanpy\tools\_rank_genes_groups.py:482: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
#   rank_genes_groups finished.
#     Calculating mean expression for Cluster Astro-Epen vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster Astro-Epen.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_Astro-Epen_vs_Rest_top50.csv
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_Astro-Epen_vs_Rest_top50.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\Astro-Epen'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\Astro-Epen'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\Astro-Epen' is writable.
#     Saved 1544 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\Astro-Epen\Cluster_Astro-Epen_vs_Rest_up_significant.csv
#     Saved 6246 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\Astro-Epen\Cluster_Astro-Epen_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster CB GABA vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster CB GABA.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_CB_GABA_vs_Rest_top50.csv
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_CB_GABA_vs_Rest_top50.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CB_GABA'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CB_GABA'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CB_GABA' is writable.
#     No significant UP genes found for Cluster_CB GABA_vs_Rest. Empty CSV file with header created: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CB_GABA\Cluster_CB GABA_vs_Rest_up_significant.csv
#     No significant DOWN genes found for Cluster_CB GABA_vs_Rest. Empty CSV file with header created: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CB_GABA\Cluster_CB GABA_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster CB Glut vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster CB Glut.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_CB_Glut_vs_Rest_top50.csv
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_CB_Glut_vs_Rest_top50.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CB_Glut'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CB_Glut'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CB_Glut' is writable.
#     No significant UP genes found for Cluster_CB Glut_vs_Rest. Empty CSV file with header created: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CB_Glut\Cluster_CB Glut_vs_Rest_up_significant.csv
#     No significant DOWN genes found for Cluster_CB Glut_vs_Rest. Empty CSV file with header created: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CB_Glut\Cluster_CB Glut_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster CNU-HYa GABA vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster CNU-HYa GABA.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_CNU-HYa_GABA_vs_Rest_top50.csv
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_CNU-HYa_GABA_vs_Rest_top50.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CNU-HYa_GABA'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CNU-HYa_GABA'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CNU-HYa_GABA' is writable.
#     Saved 10 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CNU-HYa_GABA\Cluster_CNU-HYa GABA_vs_Rest_up_significant.csv
#     Saved 3281 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CNU-HYa_GABA\Cluster_CNU-HYa GABA_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster CNU-HYa Glut vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster CNU-HYa Glut.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_CNU-HYa_Glut_vs_Rest_top50.csv
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_CNU-HYa_Glut_vs_Rest_top50.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CNU-HYa_Glut'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CNU-HYa_Glut'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CNU-HYa_Glut' is writable.
#     Saved 18 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CNU-HYa_Glut\Cluster_CNU-HYa Glut_vs_Rest_up_significant.csv
#     Saved 3079 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CNU-HYa_Glut\Cluster_CNU-HYa Glut_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster CNU-LGE GABA vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster CNU-LGE GABA.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_CNU-LGE_GABA_vs_Rest_top50.csv
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_CNU-LGE_GABA_vs_Rest_top50.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CNU-LGE_GABA'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CNU-LGE_GABA'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CNU-LGE_GABA' is writable.
#     Saved 241 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CNU-LGE_GABA\Cluster_CNU-LGE GABA_vs_Rest_up_significant.csv
#     Saved 425 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CNU-LGE_GABA\Cluster_CNU-LGE GABA_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster CNU-MGE GABA vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster CNU-MGE GABA.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_CNU-MGE_GABA_vs_Rest_top50.csv
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_CNU-MGE_GABA_vs_Rest_top50.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CNU-MGE_GABA'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CNU-MGE_GABA'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CNU-MGE_GABA' is writable.
#     Saved 102 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CNU-MGE_GABA\Cluster_CNU-MGE GABA_vs_Rest_up_significant.csv
#     Saved 72 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CNU-MGE_GABA\Cluster_CNU-MGE GABA_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster CTX-CGE GABA vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster CTX-CGE GABA.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_CTX-CGE_GABA_vs_Rest_top50.csv
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_CTX-CGE_GABA_vs_Rest_top50.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CTX-CGE_GABA'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CTX-CGE_GABA'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CTX-CGE_GABA' is writable.
#     Saved 1307 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CTX-CGE_GABA\Cluster_CTX-CGE GABA_vs_Rest_up_significant.csv
#     Saved 1663 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CTX-CGE_GABA\Cluster_CTX-CGE GABA_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster CTX-MGE GABA vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster CTX-MGE GABA.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_CTX-MGE_GABA_vs_Rest_top50.csv
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_CTX-MGE_GABA_vs_Rest_top50.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CTX-MGE_GABA'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CTX-MGE_GABA'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CTX-MGE_GABA' is writable.
#     Saved 3479 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CTX-MGE_GABA\Cluster_CTX-MGE GABA_vs_Rest_up_significant.csv
#     Saved 1337 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\CTX-MGE_GABA\Cluster_CTX-MGE GABA_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster DG-IMN Glut vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster DG-IMN Glut.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_DG-IMN_Glut_vs_Rest_top50.csv
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_DG-IMN_Glut_vs_Rest_top50.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\DG-IMN_Glut'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\DG-IMN_Glut'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\DG-IMN_Glut' is writable.
#     Saved 2817 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\DG-IMN_Glut\Cluster_DG-IMN Glut_vs_Rest_up_significant.csv
#     Saved 2104 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\DG-IMN_Glut\Cluster_DG-IMN Glut_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster HY GABA vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster HY GABA.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_HY_GABA_vs_Rest_top50.csv
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_HY_GABA_vs_Rest_top50.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\HY_GABA'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\HY_GABA'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\HY_GABA' is writable.
#     Saved 3 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\HY_GABA\Cluster_HY GABA_vs_Rest_up_significant.csv
#     Saved 1058 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\HY_GABA\Cluster_HY GABA_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster HY Glut vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster HY Glut.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_HY_Glut_vs_Rest_top50.csv
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_HY_Glut_vs_Rest_top50.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\HY_Glut'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\HY_Glut'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\HY_Glut' is writable.
#     Saved 2 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\HY_Glut\Cluster_HY Glut_vs_Rest_up_significant.csv
#     Saved 76 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\HY_Glut\Cluster_HY Glut_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster IT-ET Glut vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster IT-ET Glut.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_IT-ET_Glut_vs_Rest_top50.csv
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_IT-ET_Glut_vs_Rest_top50.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\IT-ET_Glut'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\IT-ET_Glut'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\IT-ET_Glut' is writable.
#     Saved 4399 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\IT-ET_Glut\Cluster_IT-ET Glut_vs_Rest_up_significant.csv
#     Saved 1369 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\IT-ET_Glut\Cluster_IT-ET Glut_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster Immune vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster Immune.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_Immune_vs_Rest_top50.csv
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_Immune_vs_Rest_top50.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\Immune'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\Immune'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\Immune' is writable.
#     Saved 1392 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\Immune\Cluster_Immune_vs_Rest_up_significant.csv
#     Saved 8514 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\Immune\Cluster_Immune_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster LSX GABA vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster LSX GABA.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_LSX_GABA_vs_Rest_top50.csv
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_LSX_GABA_vs_Rest_top50.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\LSX_GABA'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\LSX_GABA'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\LSX_GABA' is writable.
#     Saved 19 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\LSX_GABA\Cluster_LSX GABA_vs_Rest_up_significant.csv
#     Saved 668 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\LSX_GABA\Cluster_LSX GABA_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster MB GABA vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster MB GABA.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_MB_GABA_vs_Rest_top50.csv
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_MB_GABA_vs_Rest_top50.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\MB_GABA'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\MB_GABA'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\MB_GABA' is writable.
#     Saved 67 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\MB_GABA\Cluster_MB GABA_vs_Rest_up_significant.csv
#     Saved 6029 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\MB_GABA\Cluster_MB GABA_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster MB Glut vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster MB Glut.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_MB_Glut_vs_Rest_top50.csv
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_MB_Glut_vs_Rest_top50.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\MB_Glut'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\MB_Glut'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\MB_Glut' is writable.
#     Saved 14 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\MB_Glut\Cluster_MB Glut_vs_Rest_up_significant.csv
#     Saved 5139 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\MB_Glut\Cluster_MB Glut_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster MH-LH Glut vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster MH-LH Glut.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_MH-LH_Glut_vs_Rest_top50.csv
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_MH-LH_Glut_vs_Rest_top50.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\MH-LH_Glut'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\MH-LH_Glut'
# ...
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\MY_Glut'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\MY_Glut'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\MY_Glut' is writable.
#     Saved 16 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\MY_Glut\Cluster_MY Glut_vs_Rest_up_significant.csv
#     Saved 4494 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\MY_Glut\Cluster_MY Glut_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster NP-CT-L6b Glut vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster NP-CT-L6b Glut.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_NP-CT-L6b_Glut_vs_Rest_top50.csv
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_NP-CT-L6b_Glut_vs_Rest_top50.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\NP-CT-L6b_Glut'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\NP-CT-L6b_Glut'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\NP-CT-L6b_Glut' is writable.
#     Saved 4582 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\NP-CT-L6b_Glut\Cluster_NP-CT-L6b Glut_vs_Rest_up_significant.csv
#     Saved 511 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\NP-CT-L6b_Glut\Cluster_NP-CT-L6b Glut_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster OB-CR Glut vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster OB-CR Glut.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_OB-CR_Glut_vs_Rest_top50.csv
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_OB-CR_Glut_vs_Rest_top50.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\OB-CR_Glut'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\OB-CR_Glut'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\OB-CR_Glut' is writable.
#     Saved 135 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\OB-CR_Glut\Cluster_OB-CR Glut_vs_Rest_up_significant.csv
#     Saved 3694 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\OB-CR_Glut\Cluster_OB-CR Glut_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster OB-IMN GABA vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster OB-IMN GABA.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_OB-IMN_GABA_vs_Rest_top50.csv
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_OB-IMN_GABA_vs_Rest_top50.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\OB-IMN_GABA'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\OB-IMN_GABA'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\OB-IMN_GABA' is writable.
#     Saved 153 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\OB-IMN_GABA\Cluster_OB-IMN GABA_vs_Rest_up_significant.csv
#     Saved 6300 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\OB-IMN_GABA\Cluster_OB-IMN GABA_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster OEC vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster OEC.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_OEC_vs_Rest_top50.csv
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_OEC_vs_Rest_top50.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\OEC'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\OEC'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\OEC' is writable.
#     Saved 390 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\OEC\Cluster_OEC_vs_Rest_up_significant.csv
#     Saved 1183 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\OEC\Cluster_OEC_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster OPC-Oligo vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster OPC-Oligo.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_OPC-Oligo_vs_Rest_top50.csv
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_OPC-Oligo_vs_Rest_top50.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\OPC-Oligo'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\OPC-Oligo'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\OPC-Oligo' is writable.
#     Saved 1407 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\OPC-Oligo\Cluster_OPC-Oligo_vs_Rest_up_significant.csv
#     Saved 8570 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\OPC-Oligo\Cluster_OPC-Oligo_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster P GABA vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster P GABA.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_P_GABA_vs_Rest_top50.csv
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_P_GABA_vs_Rest_top50.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\P_GABA'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\P_GABA'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\P_GABA' is writable.
#     Saved 10 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\P_GABA\Cluster_P GABA_vs_Rest_up_significant.csv
#     Saved 4425 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\P_GABA\Cluster_P GABA_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster P Glut vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster P Glut.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_P_Glut_vs_Rest_top50.csv
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_P_Glut_vs_Rest_top50.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\P_Glut'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\P_Glut'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\P_Glut' is writable.
#     No significant UP genes found for Cluster_P Glut_vs_Rest. Empty CSV file with header created: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\P_Glut\Cluster_P Glut_vs_Rest_up_significant.csv
#     No significant DOWN genes found for Cluster_P Glut_vs_Rest. Empty CSV file with header created: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\P_Glut\Cluster_P Glut_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster Pineal Glut vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster Pineal Glut.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_Pineal_Glut_vs_Rest_top50.csv
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_Pineal_Glut_vs_Rest_top50.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\Pineal_Glut'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\Pineal_Glut'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\Pineal_Glut' is writable.
#     No significant UP genes found for Cluster_Pineal Glut_vs_Rest. Empty CSV file with header created: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\Pineal_Glut\Cluster_Pineal Glut_vs_Rest_up_significant.csv
#     No significant DOWN genes found for Cluster_Pineal Glut_vs_Rest. Empty CSV file with header created: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\Pineal_Glut\Cluster_Pineal Glut_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster TH Glut vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster TH Glut.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_TH_Glut_vs_Rest_top50.csv
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_TH_Glut_vs_Rest_top50.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\TH_Glut'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\TH_Glut'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\TH_Glut' is writable.
#     Saved 36 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\TH_Glut\Cluster_TH Glut_vs_Rest_up_significant.csv
#     Saved 12 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\TH_Glut\Cluster_TH Glut_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster Vascular vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster Vascular.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_Vascular_vs_Rest_top50.csv
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\dge_cluster_comparison_Vascular_vs_Rest_top50.xlsx
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\Vascular'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\Vascular'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\Vascular' is writable.
#     Saved 1224 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\Vascular\Cluster_Vascular_vs_Rest_up_significant.csv
#     Saved 5387 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\sig_deg_lists\Vascular\Cluster_Vascular_vs_Rest_down_significant.csv
#
# Cluster Comparison DGE analysis (Marker identification) finished.
#
# Generating marker plot for 'mapmycells_first_layer' clusters...
# WARNING: saving figure to file D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\rank_genes_groups_mapmycells_first_layer_cluster_markers_mapmycells_first_layer.png
#   Marker plot saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers\rank_genes_groups_cluster_markers_mapmycells_first_layer.png

# %%
print("\nAll analysis and output generation complete.")
print(f"Overall/Genotype DGE outputs saved in: {DGE_OUTPUT_DIR}")
print(f"Biomarker DGE outputs saved in: {BIOMARKER_OUTPUT_DIR}")
# Out:
# All analysis and output generation complete.
# Overall/Genotype DGE outputs saved in: D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\dge_res
# Biomarker DGE outputs saved in: D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L1FC_0_25\biomarkers
