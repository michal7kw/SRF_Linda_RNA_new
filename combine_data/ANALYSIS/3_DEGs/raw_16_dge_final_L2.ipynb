# %% [markdown]
# # Environment Setup and Data Loading

# %%
import scanpy as sc
import numpy as np
import pandas as pd
import os
import sys
import anndata as ad
import random
import functions_degs
import importlib

PROJECT_DIR = "D:/Github/SRF_Linda_RNA"
WORKING_DIR = os.path.join(PROJECT_DIR, "combine_data")
os.chdir(WORKING_DIR)
sys.path.insert(0, WORKING_DIR)

importlib.reload(functions_degs)

# Set seeds for all random number generators
random_seed = 0
np.random.seed(random_seed)
random.seed(random_seed)

# %%
# Set up directories

# REMOVE_DOUBLETS = True
REMOVE_DOUBLETS = False

FIX_TRESHOLD = True
# FIX_TRESHOLD = False

if FIX_TRESHOLD:
    BASE_RESULTS_DIR = os.path.join(WORKING_DIR, "results_from_raw")
else:
    if REMOVE_DOUBLETS:
        BASE_RESULTS_DIR = os.path.join(WORKING_DIR, "results_from_raw_percentile_threshold", "doublets_removed")
    else:
        BASE_RESULTS_DIR = os.path.join(WORKING_DIR, "results_from_raw_percentile_threshold")

INPUT_DIR = BASE_RESULTS_DIR
adata_path = os.path.join(INPUT_DIR, 'annotation_final.h5ad')

PARENT_OUTPUT_DIR = os.path.join(INPUT_DIR, "DEGs_cell_type_L2")

# CUSTOM_ANALYSIS =  None
CUSTOM_ANALYSIS =  "FC_0_25"

DEG_BY = "cell_type_L2"

if CUSTOM_ANALYSIS is not None:
    PARENT_OUTPUT_DIR = PARENT_OUTPUT_DIR + CUSTOM_ANALYSIS

PLOT_OUTPUT_DIR = os.path.join(PARENT_OUTPUT_DIR, 'plots')
DGE_OUTPUT_DIR = os.path.join(PARENT_OUTPUT_DIR, 'dge_res')
BIOMARKER_OUTPUT_DIR = os.path.join(PARENT_OUTPUT_DIR, 'biomarkers')

# Create output directories if they don't exist
os.makedirs(PLOT_OUTPUT_DIR, exist_ok=True)
os.makedirs(DGE_OUTPUT_DIR, exist_ok=True)
os.makedirs(BIOMARKER_OUTPUT_DIR, exist_ok=True)

print(f"Input directory: {INPUT_DIR}")
print(f"Plot output directory (Overall/Genotype): {PLOT_OUTPUT_DIR}")
print(f"DGE output directory (Overall/Genotype): {DGE_OUTPUT_DIR}")
print(f"Biomarker output directory: {BIOMARKER_OUTPUT_DIR}")

# Configure scanpy settings
sc.settings.figdir = PLOT_OUTPUT_DIR
sc.settings.set_figure_params(dpi=150, facecolor='white')
# Out:
# Input directory: D:/Github/SRF_Linda_RNA\combine_data\results_from_raw
# Plot output directory (Overall/Genotype): D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\plots
# DGE output directory (Overall/Genotype): D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res
# Biomarker output directory: D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers

# %%
# Load data
print(f"\nLoading dataset from {adata_path}")
adata = sc.read_h5ad(adata_path)
# Out:
# Loading dataset from D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\annotation_final.h5ad

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 28026 × 26870
#     obs: 'sample', 'condition', 'genotype', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden_0.4', 'ISO_majority_voting', 'ISO_conf_score', 'DG_majority_voting', 'DG_conf_score', 'mapmycells_first_layer', 'mapmycells_second_layer', 'cell_type_L1', 'cell_type_L2', 'cell_type_L2_new', 'highlight'
#     var: 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'mean', 'std'
#     uns: 'DG_majority_voting_colors', 'ISO_majority_voting_colors', 'cell_type_L1_colors', 'cell_type_L2_colors', 'cell_type_L2_new_colors', 'condition_colors', 'genotype_colors', 'highlight_colors', 'hvg', 'leiden_0.4', 'leiden_0.4_colors', 'log1p', 'neighbors', 'pca', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
print(adata.obs["genotype"].unique())
print(adata.obs["condition"].unique())
# Out:
# ['Emx1', 'Nestin']
# Categories (2, object): ['Emx1', 'Nestin']
# ['Control', 'Mutant']
# Categories (2, object): ['Control', 'Mutant']

# %% [markdown]
# # Data Preprocessing

# %%
# Save current settings
original_max_rows = pd.get_option('display.max_rows')

# Set to None to display all rows
pd.set_option('display.max_rows', None)

# Check original clusters:
print(f"Original {DEG_BY} clusters:")
print(adata.obs[DEG_BY].value_counts())

# Reset to original settings
pd.set_option('display.max_rows', original_max_rows)
# Out:
# Original cell_type_L2 clusters:
# cell_type_L2
# ENT              7589
# Unknown          4100
# Mature GC        2134
# CA1              2056
# MOL              1660
# Microglia        1236
# CA3              1099
# Astrocytes        980
# PPP               862
# OPC               729
# CGE-derived       603
# MGE-derived       538
# Immature GC       503
# PV                481
# SST               444
# Subiculum         425
# ProS              367
# Lamp5             287
# Sncg              271
# Endothelial       231
# VIP               228
# NFOL              149
# VLMC              144
# Neuroblast        142
# CA2               117
# ABC               116
# Pericytes         113
# VIP (DG)           89
# Lamp5 (DG)         85
# Car3               73
# Cajal-Retzius      65
# nIPC               63
# Mossy cells        47
# Name: count, dtype: int64

# %%
# Check adata structure
print("\nAnnData object summary:")
print(adata)
print("\nAvailable layers:", list(adata.layers.keys()))
print("Raw data available:", adata.raw is not None)
if adata.raw:
    print("Raw data shape:", adata.raw.X.shape)
# Out:
# AnnData object summary:
# AnnData object with n_obs × n_vars = 28026 × 26870
#     obs: 'sample', 'condition', 'genotype', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden_0.4', 'ISO_majority_voting', 'ISO_conf_score', 'DG_majority_voting', 'DG_conf_score', 'mapmycells_first_layer', 'mapmycells_second_layer', 'cell_type_L1', 'cell_type_L2', 'highlight'
#     var: 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'mean', 'std'
#     uns: 'DG_majority_voting_colors', 'ISO_majority_voting_colors', 'cell_type_L1_colors', 'cell_type_L2_colors', 'condition_colors', 'genotype_colors', 'highlight_colors', 'hvg', 'leiden_0.4', 'leiden_0.4_colors', 'log1p', 'neighbors', 'pca', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
#
# Available layers: []
# Raw data available: True
# Raw data shape: (28026, 33685)

# %%
# Create the 'for_DEGs' layer: Normalized and log1p transformed counts
# Assuming raw counts are in adata.raw.X
print("\nCreating 'for_DEGs' layer...")
if adata.raw is not None and adata.raw.X is not None:
    # Create a temporary AnnData with raw counts to perform normalization and log1p
    adata_for_dge = ad.AnnData(adata.raw.X.copy()) # type: ignore
    adata_for_dge.obs_names = adata.obs_names # type: ignore
    adata_for_dge.var_names = adata.raw.var_names # type: ignore

    print("Normalizing total counts (target_sum=1e4)...")
    sc.pp.normalize_total(adata_for_dge, target_sum=1e4)

    print("Applying log1p transformation...")
    sc.pp.log1p(adata_for_dge)

    # Ensure the gene order matches the main adata object
    adata_for_dge = adata_for_dge[:, adata.var_names].copy() # type: ignore

    print("Storing result in adata.layers['for_DEGs']...")
    adata.layers['for_DEGs'] = adata_for_dge.X.copy() # type: ignore
    print("'for_DEGs' layer created with shape:", adata.layers['for_DEGs'].shape)
else:
    print("Warning: adata.raw.X not found. Cannot create 'for_DEGs' layer from raw counts.")
    print("DGE analysis will proceed using adata.X, which might be scaled.")
# Out:
# Creating 'for_DEGs' layer...
# Normalizing total counts (target_sum=1e4)...
# Applying log1p transformation...
# Storing result in adata.layers['for_DEGs']...
# 'for_DEGs' layer created with shape: (28026, 26870)

# %%
print("\nMetadata check:")
print("condition:", list(adata.obs.condition.unique()))
print("genotype:", list(adata.obs.genotype.unique()))
print(f"{DEG_BY}:", list(adata.obs[DEG_BY].unique()))
# Out:
# Metadata check:
# condition: ['Control', 'Mutant']
# genotype: ['Emx1', 'Nestin']
# cell_type_L2: ['Astrocytes', 'Unknown', 'CA3', 'ENT', 'PPP', 'CA1', 'MGE-derived', 'Mature GC', 'MOL', 'ProS', 'Microglia', 'Subiculum', 'CGE-derived', 'VIP', 'CA2', 'Sncg', 'OPC', 'ABC', 'NFOL', 'Lamp5', 'SST', 'PV', 'Immature GC', 'VLMC', 'Endothelial', 'Lamp5 (DG)', 'nIPC', 'Pericytes', 'Car3', 'VIP (DG)', 'Mossy cells', 'Neuroblast', 'Cajal-Retzius']

# %% [markdown]
# # Differential Gene Expression Analysis

# %%
# Overall DGE (Mutant vs Control) using the 'for_DEGs' layer, grouped by the DEG_BY
print(f"\nRunning Overall DGE (grouped by {DEG_BY})...")
dge_results = functions_degs.run_overall_dge(
    adata,
    grouping_key=DEG_BY,
    dge_output_dir=DGE_OUTPUT_DIR,
    plot_output_dir=PLOT_OUTPUT_DIR,
    layer='for_DEGs' if 'for_DEGs' in adata.layers else None
)
# Out:
# Running Overall DGE (grouped by cell_type_L2)...
#
# Starting both genomes Differential Gene Expression analysis (Mutant vs Control)...
#   Running DGE for group: Astrocytes (using key 'cell_type_L2')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 98 cells (max of 3 absolute and 10.0% of 980)...
#     Genes after filtering: 5556
#       Calculating mean expression for 5556 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_Astrocytes_mut_vs_ctrl.csv
#     Warning: 'openpyxl' not installed. Cannot save to .xlsx. Please install it (`pip install openpyxl`).
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Astrocytes'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Astrocytes'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Astrocytes' is writable.
#     Saved 14 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Astrocytes\Mutant_vs_Control_up_significant.csv
#     Saved 188 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Astrocytes\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group Astrocytes: ['Mir99ahg', 'Gm28175', 'Grik2', 'Gm29260', 'Slc7a11']
# ---
#   Running DGE for group: Unknown (using key 'cell_type_L2')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 410 cells (max of 3 absolute and 10.0% of 4100)...
#     Genes after filtering: 3151
#       Calculating mean expression for 3151 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_Unknown_mut_vs_ctrl.csv
#     Warning: 'openpyxl' not installed. Cannot save to .xlsx. Please install it (`pip install openpyxl`).
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Unknown'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Unknown'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Unknown' is writable.
#     Saved 24 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Unknown\Mutant_vs_Control_up_significant.csv
#     Saved 122 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Unknown\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group Unknown: ['Tenm2', 'Mir99ahg', 'Snhg11', 'Ptprd', 'Pcdh9']
# ---
#   Running DGE for group: CA3 (using key 'cell_type_L2')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 110 cells (max of 3 absolute and 10.0% of 1099)...
#     Genes after filtering: 10647
#       Calculating mean expression for 10647 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_CA3_mut_vs_ctrl.csv
#     Warning: 'openpyxl' not installed. Cannot save to .xlsx. Please install it (`pip install openpyxl`).
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\CA3'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\CA3'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\CA3' is writable.
#     Saved 215 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\CA3\Mutant_vs_Control_up_significant.csv
#     Saved 1992 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\CA3\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group CA3: ['Meg3', 'Tenm4', 'Runx1t1', 'A830082K12Rik', 'Frmd4a']
# ---
#   Running DGE for group: ENT (using key 'cell_type_L2')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 759 cells (max of 3 absolute and 10.0% of 7589)...
#     Genes after filtering: 11161
#       Calculating mean expression for 11161 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_ENT_mut_vs_ctrl.csv
#     Warning: 'openpyxl' not installed. Cannot save to .xlsx. Please install it (`pip install openpyxl`).
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\ENT'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\ENT'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\ENT' is writable.
#     Saved 365 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\ENT\Mutant_vs_Control_up_significant.csv
#     Saved 1886 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\ENT\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group ENT: ['Meg3', 'A830082K12Rik', 'Naaladl2', 'C130071C03Rik', 'Tenm4']
# ---
#   Running DGE for group: PPP (using key 'cell_type_L2')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 87 cells (max of 3 absolute and 10.0% of 862)...
#     Genes after filtering: 8619
#       Calculating mean expression for 8619 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_PPP_mut_vs_ctrl.csv
#     Warning: 'openpyxl' not installed. Cannot save to .xlsx. Please install it (`pip install openpyxl`).
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\PPP'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\PPP'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\PPP' is writable.
#     Saved 34 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\PPP\Mutant_vs_Control_up_significant.csv
#     Saved 177 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\PPP\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group PPP: ['A830082K12Rik', 'Phactr1', 'Tenm3', 'Auts2', 'Tbc1d30']
# ---
#   Running DGE for group: CA1 (using key 'cell_type_L2')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 206 cells (max of 3 absolute and 10.0% of 2056)...
#     Genes after filtering: 9276
#       Calculating mean expression for 9276 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_CA1_mut_vs_ctrl.csv
#     Warning: 'openpyxl' not installed. Cannot save to .xlsx. Please install it (`pip install openpyxl`).
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\CA1'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\CA1'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\CA1' is writable.
#     Saved 154 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\CA1\Mutant_vs_Control_up_significant.csv
#     Saved 1881 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\CA1\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group CA1: ['Mir99ahg', 'Naaladl2', 'Meg3', 'Anks1b', 'A830082K12Rik']
# ---
#   Running DGE for group: MGE-derived (using key 'cell_type_L2')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 54 cells (max of 3 absolute and 10.0% of 538)...
#     Genes after filtering: 11548
#       Calculating mean expression for 11548 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_MGE-derived_mut_vs_ctrl.csv
#     Warning: 'openpyxl' not installed. Cannot save to .xlsx. Please install it (`pip install openpyxl`).
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\MGE-derived'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\MGE-derived'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\MGE-derived' is writable.
#     Saved 142 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\MGE-derived\Mutant_vs_Control_up_significant.csv
#     Saved 463 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\MGE-derived\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group MGE-derived: ['Meg3', 'Naaladl2', 'Tenm4', 'A830082K12Rik', 'Csmd2']
# ---
#   Running DGE for group: Mature GC (using key 'cell_type_L2')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 214 cells (max of 3 absolute and 10.0% of 2134)...
#     Genes after filtering: 8364
#       Calculating mean expression for 8364 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_Mature_GC_mut_vs_ctrl.csv
#     Warning: 'openpyxl' not installed. Cannot save to .xlsx. Please install it (`pip install openpyxl`).
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Mature_GC'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Mature_GC'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Mature_GC' is writable.
#     Saved 180 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Mature_GC\Mutant_vs_Control_up_significant.csv
#     Saved 2235 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Mature_GC\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group Mature GC: ['Mir99ahg', 'Frmpd4', 'Tenm2', 'Grik4', 'Dab1']
# ---
#   Running DGE for group: MOL (using key 'cell_type_L2')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 166 cells (max of 3 absolute and 10.0% of 1660)...
#     Genes after filtering: 4869
#       Calculating mean expression for 4869 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_MOL_mut_vs_ctrl.csv
#     Warning: 'openpyxl' not installed. Cannot save to .xlsx. Please install it (`pip install openpyxl`).
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\MOL'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\MOL'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\MOL' is writable.
#     Saved 91 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\MOL\Mutant_vs_Control_up_significant.csv
#     Saved 733 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\MOL\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group MOL: ['Brinp3', 'Grik2', 'Pcdh9', 'Erbb4', 'Ralyl']
# ---
#   Running DGE for group: ProS (using key 'cell_type_L2')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 37 cells (max of 3 absolute and 10.0% of 367)...
#     Genes after filtering: 9730
#       Calculating mean expression for 9730 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_ProS_mut_vs_ctrl.csv
#     Warning: 'openpyxl' not installed. Cannot save to .xlsx. Please install it (`pip install openpyxl`).
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\ProS'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\ProS'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\ProS' is writable.
#     Saved 10 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\ProS\Mutant_vs_Control_up_significant.csv
#     Saved 25 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\ProS\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group ProS: ['Meg3', 'Kat6b', 'A830082K12Rik', 'Mir99ahg', 'Tcf4']
# ---
#   Running DGE for group: Microglia (using key 'cell_type_L2')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 124 cells (max of 3 absolute and 10.0% of 1236)...
#     Genes after filtering: 3783
#       Calculating mean expression for 3783 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_Microglia_mut_vs_ctrl.csv
#     Warning: 'openpyxl' not installed. Cannot save to .xlsx. Please install it (`pip install openpyxl`).
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Microglia'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Microglia'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Microglia' is writable.
#     Saved 73 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Microglia\Mutant_vs_Control_up_significant.csv
#     Saved 693 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Microglia\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group Microglia: ['Naaladl2', 'Tenm2', 'Dpp10', 'Ptprd', 'Dlg2']
# ---
#   Running DGE for group: Subiculum (using key 'cell_type_L2')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 43 cells (max of 3 absolute and 10.0% of 425)...
#     Genes after filtering: 9055
#       Calculating mean expression for 9055 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_Subiculum_mut_vs_ctrl.csv
#     Warning: 'openpyxl' not installed. Cannot save to .xlsx. Please install it (`pip install openpyxl`).
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Subiculum'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Subiculum'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Subiculum' is writable.
#     Saved 11 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Subiculum\Mutant_vs_Control_up_significant.csv
#     Saved 44 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Subiculum\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group Subiculum: ['Meg3', 'Foxp1', 'Snhg14', 'Cacnb4', 'Cdh18']
# ---
#   Running DGE for group: CGE-derived (using key 'cell_type_L2')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 61 cells (max of 3 absolute and 10.0% of 603)...
#     Genes after filtering: 12154
#       Calculating mean expression for 12154 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_CGE-derived_mut_vs_ctrl.csv
#     Warning: 'openpyxl' not installed. Cannot save to .xlsx. Please install it (`pip install openpyxl`).
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\CGE-derived'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\CGE-derived'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\CGE-derived' is writable.
#     Saved 227 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\CGE-derived\Mutant_vs_Control_up_significant.csv
#     Saved 233 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\CGE-derived\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group CGE-derived: ['Meg3', 'Naaladl2', 'Gm11867', 'A830082K12Rik', 'Mtus2']
# ---
#   Running DGE for group: VIP (using key 'cell_type_L2')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 23 cells (max of 3 absolute and 10.0% of 228)...
#     Genes after filtering: 6968
#       Calculating mean expression for 6968 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_VIP_mut_vs_ctrl.csv
#     Warning: 'openpyxl' not installed. Cannot save to .xlsx. Please install it (`pip install openpyxl`).
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\VIP'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\VIP'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\VIP' is writable.
#     Saved 3 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\VIP\Mutant_vs_Control_up_significant.csv
#     Saved 10 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\VIP\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group VIP: ['Kcnmb2', 'Mir99ahg', 'Naaladl2', 'Meg3', 'Tcf4']
# ---
#   Running DGE for group: CA2 (using key 'cell_type_L2')
#     Skipping DGE for group CA2: Not enough cells (< 50). Control: 44, Mutant: 73
#   Running DGE for group: Sncg (using key 'cell_type_L2')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 28 cells (max of 3 absolute and 10.0% of 271)...
#     Genes after filtering: 9208
#       Calculating mean expression for 9208 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_Sncg_mut_vs_ctrl.csv
#     Warning: 'openpyxl' not installed. Cannot save to .xlsx. Please install it (`pip install openpyxl`).
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Sncg'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Sncg'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Sncg' is writable.
#     Saved 4 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Sncg\Mutant_vs_Control_up_significant.csv
#     Saved 9 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Sncg\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group Sncg: ['Meg3', 'Snhg14', 'Carmil1', 'Bltp1', 'Trerf1']
# ---
#   Running DGE for group: OPC (using key 'cell_type_L2')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 73 cells (max of 3 absolute and 10.0% of 729)...
#     Genes after filtering: 5572
#       Calculating mean expression for 5572 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_OPC_mut_vs_ctrl.csv
#     Warning: 'openpyxl' not installed. Cannot save to .xlsx. Please install it (`pip install openpyxl`).
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\OPC'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\OPC'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\OPC' is writable.
#     Saved 32 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\OPC\Mutant_vs_Control_up_significant.csv
#     Saved 515 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\OPC\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group OPC: ['Mir99ahg', 'Gm29260', 'Meis2', 'Naaladl2', 'Tenm2']
# ---
#   Running DGE for group: ABC (using key 'cell_type_L2')
#     Skipping DGE for group ABC: Not enough cells (< 50). Control: 67, Mutant: 49
#   Running DGE for group: NFOL (using key 'cell_type_L2')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 15 cells (max of 3 absolute and 10.0% of 149)...
#     Genes after filtering: 6182
#       Calculating mean expression for 6182 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_NFOL_mut_vs_ctrl.csv
#     Warning: 'openpyxl' not installed. Cannot save to .xlsx. Please install it (`pip install openpyxl`).
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\NFOL'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\NFOL'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\NFOL' is writable.
#     No significant UP genes found for Mutant_vs_Control. Empty CSV file with header created: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\NFOL\Mutant_vs_Control_up_significant.csv
#     No significant DOWN genes found for Mutant_vs_Control. Empty CSV file with header created: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\NFOL\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group NFOL: ['Tcf4', 'Zfpm2', 'C130071C03Rik', 'Marcks', 'Kif13a']
# ---
#   Running DGE for group: Lamp5 (using key 'cell_type_L2')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 29 cells (max of 3 absolute and 10.0% of 287)...
#     Genes after filtering: 8814
#       Calculating mean expression for 8814 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_Lamp5_mut_vs_ctrl.csv
#     Warning: 'openpyxl' not installed. Cannot save to .xlsx. Please install it (`pip install openpyxl`).
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Lamp5'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Lamp5'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Lamp5' is writable.
#     Saved 3 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Lamp5\Mutant_vs_Control_up_significant.csv
#     Saved 4 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Lamp5\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group Lamp5: ['Mir99ahg', 'Naaladl2', 'C130071C03Rik', 'Sox2ot', 'A830082K12Rik']
# ---
#   Running DGE for group: SST (using key 'cell_type_L2')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 45 cells (max of 3 absolute and 10.0% of 444)...
#     Genes after filtering: 9064
#       Calculating mean expression for 9064 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_SST_mut_vs_ctrl.csv
#     Warning: 'openpyxl' not installed. Cannot save to .xlsx. Please install it (`pip install openpyxl`).
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\SST'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\SST'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\SST' is writable.
#     Saved 2 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\SST\Mutant_vs_Control_up_significant.csv
#     Saved 7 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\SST\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group SST: ['Meg3', 'C130071C03Rik', 'Naaladl2', 'Syne1', 'Lrch1']
# ---
#   Running DGE for group: PV (using key 'cell_type_L2')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 49 cells (max of 3 absolute and 10.0% of 481)...
#     Genes after filtering: 8927
#       Calculating mean expression for 8927 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_PV_mut_vs_ctrl.csv
#     Warning: 'openpyxl' not installed. Cannot save to .xlsx. Please install it (`pip install openpyxl`).
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\PV'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\PV'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\PV' is writable.
#     Saved 1 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\PV\Mutant_vs_Control_up_significant.csv
#     Saved 10 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\PV\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group PV: ['Naaladl2', 'Meg3', 'Grm5', 'Trio', 'Sptbn4']
# ---
#   Running DGE for group: Immature GC (using key 'cell_type_L2')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 51 cells (max of 3 absolute and 10.0% of 503)...
#     Genes after filtering: 10086
#       Calculating mean expression for 10086 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_Immature_GC_mut_vs_ctrl.csv
#     Warning: 'openpyxl' not installed. Cannot save to .xlsx. Please install it (`pip install openpyxl`).
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Immature_GC'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Immature_GC'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Immature_GC' is writable.
#     Saved 98 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Immature_GC\Mutant_vs_Control_up_significant.csv
#     Saved 450 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Immature_GC\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group Immature GC: ['Tenm2', 'Frmpd4', 'Grik4', 'Dab1', 'Shisa9']
# ---
#   Running DGE for group: VLMC (using key 'cell_type_L2')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 15 cells (max of 3 absolute and 10.0% of 144)...
#     Genes after filtering: 5765
#       Calculating mean expression for 5765 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_VLMC_mut_vs_ctrl.csv
#     Warning: 'openpyxl' not installed. Cannot save to .xlsx. Please install it (`pip install openpyxl`).
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\VLMC'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\VLMC'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\VLMC' is writable.
#     No significant UP genes found for Mutant_vs_Control. Empty CSV file with header created: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\VLMC\Mutant_vs_Control_up_significant.csv
#     No significant DOWN genes found for Mutant_vs_Control. Empty CSV file with header created: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\VLMC\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group VLMC: ['Rplp1', 'Ust', 'Sned1', 'Cox4i1', 'Cd81']
# ---
#   Running DGE for group: Endothelial (using key 'cell_type_L2')
#     Initial genes: 26870
#     Filtering genes: Requiring expression in >= 24 cells (max of 3 absolute and 10.0% of 231)...
#     Genes after filtering: 7482
#       Calculating mean expression for 7482 genes...
#       Using data from layer: for_DEGs
# Added mean expression columns.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\dge_both_genomes_Endothelial_mut_vs_ctrl.csv
#     Warning: 'openpyxl' not installed. Cannot save to .xlsx. Please install it (`pip install openpyxl`).
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Endothelial'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Endothelial'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Endothelial' is writable.
#     No significant UP genes found for Mutant_vs_Control. Empty CSV file with header created: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Endothelial\Mutant_vs_Control_up_significant.csv
#     No significant DOWN genes found for Mutant_vs_Control. Empty CSV file with header created: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\sig_deg_lists\Endothelial\Mutant_vs_Control_down_significant.csv
#     Top 5 genes upregulated in Mutant vs Control for group Endothelial: ['Wwox', 'Atp11c', 'Akap8l', 'mt-Cytb', 'Rps15']
# ---
#   Running DGE for group: Lamp5 (DG) (using key 'cell_type_L2')
#     Skipping DGE for group Lamp5 (DG): Not enough cells (< 50). Control: 46, Mutant: 39
#   Running DGE for group: nIPC (using key 'cell_type_L2')
#     Skipping DGE for group nIPC: Not enough cells (< 50). Control: 26, Mutant: 37
#   Running DGE for group: Pericytes (using key 'cell_type_L2')
#     Skipping DGE for group Pericytes: Not enough cells (< 50). Control: 82, Mutant: 31
#   Running DGE for group: Car3 (using key 'cell_type_L2')
#     Skipping DGE for group Car3: Not enough cells (< 50). Control: 44, Mutant: 29
#   Running DGE for group: VIP (DG) (using key 'cell_type_L2')
#     Skipping DGE for group VIP (DG): Not enough cells (< 50). Control: 38, Mutant: 51
#   Running DGE for group: Mossy cells (using key 'cell_type_L2')
#     Skipping DGE for group Mossy cells: Not enough cells (< 50). Control: 15, Mutant: 32
#   Running DGE for group: Neuroblast (using key 'cell_type_L2')
#     Skipping DGE for group Neuroblast: Not enough cells (< 50). Control: 105, Mutant: 37
#   Running DGE for group: Cajal-Retzius (using key 'cell_type_L2')
#     Skipping DGE for group Cajal-Retzius: Not enough cells (< 50). Control: 25, Mutant: 40
#
# Summary of skipped groups (using key 'cell_type_L2') saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\both_geno_cond_comp\dge_overall_skipped_cell_type_L2.csv
#
# Both genomes DGE analysis finished.
#
# Generating Volcano Plots for Overall DGE results...
#   Generating volcano plot for: Both genomes - Astrocytes (Counts: Control=609, Mutant=371) -> dge_conditions_comparison_Astrocytes_volcano.png
# ---
#   Generating volcano plot for: Both genomes - Unknown (Counts: Control=2701, Mutant=1399) -> dge_conditions_comparison_Unknown_volcano.png
# ---
#   Generating volcano plot for: Both genomes - CA3 (Counts: Control=426, Mutant=673) -> dge_conditions_comparison_CA3_volcano.png
# ---
#   Generating volcano plot for: Both genomes - ENT (Counts: Control=2768, Mutant=4821) -> dge_conditions_comparison_ENT_volcano.png
# ---
#   Generating volcano plot for: Both genomes - PPP (Counts: Control=154, Mutant=708) -> dge_conditions_comparison_PPP_volcano.png
# ---
#   Generating volcano plot for: Both genomes - CA1 (Counts: Control=775, Mutant=1281) -> dge_conditions_comparison_CA1_volcano.png
# ---
#   Generating volcano plot for: Both genomes - MGE-derived (Counts: Control=200, Mutant=338) -> dge_conditions_comparison_MGE-derived_volcano.png
# ---
#   Generating volcano plot for: Both genomes - Mature GC (Counts: Control=1326, Mutant=808) -> dge_conditions_comparison_Mature_GC_volcano.png
# ---
#   Generating volcano plot for: Both genomes - MOL (Counts: Control=901, Mutant=759) -> dge_conditions_comparison_MOL_volcano.png
# ---
#   Generating volcano plot for: Both genomes - ProS (Counts: Control=126, Mutant=241) -> dge_conditions_comparison_ProS_volcano.png
# ---
#   Generating volcano plot for: Both genomes - Microglia (Counts: Control=533, Mutant=703) -> dge_conditions_comparison_Microglia_volcano.png
# ---
#   Generating volcano plot for: Both genomes - Subiculum (Counts: Control=153, Mutant=272) -> dge_conditions_comparison_Subiculum_volcano.png
# ---
#   Generating volcano plot for: Both genomes - CGE-derived (Counts: Control=182, Mutant=421) -> dge_conditions_comparison_CGE-derived_volcano.png
# ---
#   Generating volcano plot for: Both genomes - VIP (Counts: Control=64, Mutant=164) -> dge_conditions_comparison_VIP_volcano.png
# ---
#   Skipping volcano plot for Both genomes - CA2: Not enough cells in one or both groups (< 50). Control=44, Mutant=73.
#   Generating volcano plot for: Both genomes - Sncg (Counts: Control=99, Mutant=172) -> dge_conditions_comparison_Sncg_volcano.png
# ---
#   Generating volcano plot for: Both genomes - OPC (Counts: Control=288, Mutant=441) -> dge_conditions_comparison_OPC_volcano.png
# ---
#   Skipping volcano plot for Both genomes - ABC: Not enough cells in one or both groups (< 50). Control=67, Mutant=49.
#   Generating volcano plot for: Both genomes - NFOL (Counts: Control=54, Mutant=95) -> dge_conditions_comparison_NFOL_volcano.png
# ---
#   Generating volcano plot for: Both genomes - Lamp5 (Counts: Control=89, Mutant=198) -> dge_conditions_comparison_Lamp5_volcano.png
# ---
#   Generating volcano plot for: Both genomes - SST (Counts: Control=140, Mutant=304) -> dge_conditions_comparison_SST_volcano.png
# ---
#   Generating volcano plot for: Both genomes - PV (Counts: Control=168, Mutant=313) -> dge_conditions_comparison_PV_volcano.png
# ---
#   Generating volcano plot for: Both genomes - Immature GC (Counts: Control=354, Mutant=149) -> dge_conditions_comparison_Immature_GC_volcano.png
# ---
#   Generating volcano plot for: Both genomes - VLMC (Counts: Control=73, Mutant=71) -> dge_conditions_comparison_VLMC_volcano.png
# ---
#   Generating volcano plot for: Both genomes - Endothelial (Counts: Control=144, Mutant=87) -> dge_conditions_comparison_Endothelial_volcano.png
# ---
#   Skipping volcano plot for Both genomes - Lamp5 (DG): Not enough cells in one or both groups (< 50). Control=46, Mutant=39.
#   Skipping volcano plot for Both genomes - nIPC: Not enough cells in one or both groups (< 50). Control=26, Mutant=37.
#   Skipping volcano plot for Both genomes - Pericytes: Not enough cells in one or both groups (< 50). Control=82, Mutant=31.
#   Skipping volcano plot for Both genomes - Car3: Not enough cells in one or both groups (< 50). Control=44, Mutant=29.
#   Skipping volcano plot for Both genomes - VIP (DG): Not enough cells in one or both groups (< 50). Control=38, Mutant=51.
#   Skipping volcano plot for Both genomes - Mossy cells: Not enough cells in one or both groups (< 50). Control=15, Mutant=32.
#   Skipping volcano plot for Both genomes - Neuroblast: Not enough cells in one or both groups (< 50). Control=105, Mutant=37.
#   Skipping volcano plot for Both genomes - Cajal-Retzius: Not enough cells in one or both groups (< 50). Control=25, Mutant=40.
#
# Both genomes DGE visualization finished.

# %%
# Genotype-Specific DGE (Mutant vs Control within each genotype) using the 'for_DEGs' layer, grouped by the DEG_BY
print(f"\nRunning Genotype-Specific DGE (grouped by {DEG_BY})...")
dge_by_genotype = functions_degs.run_genotype_specific_dge(
    adata,
    grouping_key=DEG_BY,
    dge_output_dir=DGE_OUTPUT_DIR,
    plot_output_dir=PLOT_OUTPUT_DIR,
    layer='for_DEGs' if 'for_DEGs' in adata.layers else None
)
# Out:
# Running Genotype-Specific DGE (grouped by cell_type_L2)...
#
# Starting Genotype-Specific DGE analysis...
# Created 'genotype_condition' column with categories: ['Emx1_Control', 'Emx1_Mutant', 'Nestin_Control', 'Nestin_Mutant']
#
# Processing group: Astrocytes (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Filtering genes for Emx1 (Initial: 26870)
#     Filtering genes: Requiring expression in >= 36 cells (max of 3 absolute and 10.0% of 357)...
#     Genes after filtering: 5053
#       Calculating mean expression for 5053 genes (Emx1, group Astrocytes)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Emx1, group Astrocytes).
#     Finished DGE for Emx1, group Astrocytes. Found 5053 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_Astrocytes_mut_vs_ctrl.csv
#     Warning (Emx1, group Astrocytes): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Astrocytes'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Astrocytes'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Astrocytes' is writable.
#     Saved 41 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Astrocytes\Mutant_vs_Control_up_significant.csv
#     Saved 27 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Astrocytes\Mutant_vs_Control_down_significant.csv
#   Running DGE for Nestin genotype...
#     Filtering genes for Nestin (Initial: 26870)
#     Filtering genes: Requiring expression in >= 63 cells (max of 3 absolute and 10.0% of 623)...
#     Genes after filtering: 5671
#       Calculating mean expression for 5671 genes (Nestin, group Astrocytes)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Nestin, group Astrocytes).
#     Finished DGE for Nestin, group Astrocytes. Found 5671 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_Astrocytes_mut_vs_ctrl.csv
#     Warning (Nestin, group Astrocytes): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Astrocytes'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Astrocytes'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Astrocytes' is writable.
#     Saved 40 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Astrocytes\Mutant_vs_Control_up_significant.csv
#     Saved 232 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Astrocytes\Mutant_vs_Control_down_significant.csv
#
# Processing group: Unknown (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Filtering genes for Emx1 (Initial: 26870)
#     Filtering genes: Requiring expression in >= 178 cells (max of 3 absolute and 10.0% of 1773)...
#     Genes after filtering: 2599
#       Calculating mean expression for 2599 genes (Emx1, group Unknown)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Emx1, group Unknown).
#     Finished DGE for Emx1, group Unknown. Found 2599 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_Unknown_mut_vs_ctrl.csv
#     Warning (Emx1, group Unknown): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Unknown'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Unknown'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Unknown' is writable.
#     Saved 314 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Unknown\Mutant_vs_Control_up_significant.csv
#     Saved 237 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Unknown\Mutant_vs_Control_down_significant.csv
#   Running DGE for Nestin genotype...
#     Filtering genes for Nestin (Initial: 26870)
#     Filtering genes: Requiring expression in >= 233 cells (max of 3 absolute and 10.0% of 2327)...
#     Genes after filtering: 3461
#       Calculating mean expression for 3461 genes (Nestin, group Unknown)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Nestin, group Unknown).
#     Finished DGE for Nestin, group Unknown. Found 3461 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_Unknown_mut_vs_ctrl.csv
#     Warning (Nestin, group Unknown): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Unknown'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Unknown'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Unknown' is writable.
#     Saved 200 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Unknown\Mutant_vs_Control_up_significant.csv
#     Saved 339 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Unknown\Mutant_vs_Control_down_significant.csv
#
# Processing group: CA3 (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Filtering genes for Emx1 (Initial: 26870)
#     Filtering genes: Requiring expression in >= 56 cells (max of 3 absolute and 10.0% of 553)...
#     Genes after filtering: 10589
#       Calculating mean expression for 10589 genes (Emx1, group CA3)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Emx1, group CA3).
#     Finished DGE for Emx1, group CA3. Found 10589 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_CA3_mut_vs_ctrl.csv
#     Warning (Emx1, group CA3): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\CA3'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\CA3'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\CA3' is writable.
#     Saved 488 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\CA3\Mutant_vs_Control_up_significant.csv
#     Saved 934 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\CA3\Mutant_vs_Control_down_significant.csv
#   Running DGE for Nestin genotype...
#     Filtering genes for Nestin (Initial: 26870)
#     Filtering genes: Requiring expression in >= 55 cells (max of 3 absolute and 10.0% of 546)...
#     Genes after filtering: 10599
#       Calculating mean expression for 10599 genes (Nestin, group CA3)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Nestin, group CA3).
#     Finished DGE for Nestin, group CA3. Found 10599 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_CA3_mut_vs_ctrl.csv
#     Warning (Nestin, group CA3): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\CA3'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\CA3'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\CA3' is writable.
#     Saved 168 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\CA3\Mutant_vs_Control_up_significant.csv
#     Saved 1911 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\CA3\Mutant_vs_Control_down_significant.csv
#
# Processing group: ENT (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Filtering genes for Emx1 (Initial: 26870)
#     Filtering genes: Requiring expression in >= 303 cells (max of 3 absolute and 10.0% of 3026)...
#     Genes after filtering: 11243
#       Calculating mean expression for 11243 genes (Emx1, group ENT)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Emx1, group ENT).
#     Finished DGE for Emx1, group ENT. Found 11243 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_ENT_mut_vs_ctrl.csv
#     Warning (Emx1, group ENT): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\ENT'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\ENT'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\ENT' is writable.
#     Saved 1185 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\ENT\Mutant_vs_Control_up_significant.csv
#     Saved 1542 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\ENT\Mutant_vs_Control_down_significant.csv
#   Running DGE for Nestin genotype...
#     Filtering genes for Nestin (Initial: 26870)
#     Filtering genes: Requiring expression in >= 457 cells (max of 3 absolute and 10.0% of 4563)...
#     Genes after filtering: 11116
#       Calculating mean expression for 11116 genes (Nestin, group ENT)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Nestin, group ENT).
#     Finished DGE for Nestin, group ENT. Found 11116 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_ENT_mut_vs_ctrl.csv
#     Warning (Nestin, group ENT): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\ENT'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\ENT'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\ENT' is writable.
#     Saved 288 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\ENT\Mutant_vs_Control_up_significant.csv
#     Saved 2194 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\ENT\Mutant_vs_Control_down_significant.csv
#
# Processing group: PPP (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Filtering genes for Emx1 (Initial: 26870)
#     Filtering genes: Requiring expression in >= 39 cells (max of 3 absolute and 10.0% of 382)...
#     Genes after filtering: 8874
#       Calculating mean expression for 8874 genes (Emx1, group PPP)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Emx1, group PPP).
#     Finished DGE for Emx1, group PPP. Found 8874 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_PPP_mut_vs_ctrl.csv
#     Warning (Emx1, group PPP): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\PPP'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\PPP'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\PPP' is writable.
#     Saved 37 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\PPP\Mutant_vs_Control_up_significant.csv
#     Saved 28 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\PPP\Mutant_vs_Control_down_significant.csv
#   Running DGE for Nestin genotype...
#     Filtering genes for Nestin (Initial: 26870)
#     Filtering genes: Requiring expression in >= 48 cells (max of 3 absolute and 10.0% of 480)...
#     Genes after filtering: 8386
#       Calculating mean expression for 8386 genes (Nestin, group PPP)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Nestin, group PPP).
#     Finished DGE for Nestin, group PPP. Found 8386 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_PPP_mut_vs_ctrl.csv
#     Warning (Nestin, group PPP): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\PPP'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\PPP'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\PPP' is writable.
#     Saved 35 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\PPP\Mutant_vs_Control_up_significant.csv
#     Saved 318 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\PPP\Mutant_vs_Control_down_significant.csv
#
# Processing group: CA1 (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Filtering genes for Emx1 (Initial: 26870)
#     Filtering genes: Requiring expression in >= 87 cells (max of 3 absolute and 10.0% of 863)...
#     Genes after filtering: 9151
#       Calculating mean expression for 9151 genes (Emx1, group CA1)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Emx1, group CA1).
#     Finished DGE for Emx1, group CA1. Found 9151 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_CA1_mut_vs_ctrl.csv
#     Warning (Emx1, group CA1): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\CA1'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\CA1'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\CA1' is writable.
#     Saved 330 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\CA1\Mutant_vs_Control_up_significant.csv
#     Saved 557 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\CA1\Mutant_vs_Control_down_significant.csv
#   Running DGE for Nestin genotype...
#     Filtering genes for Nestin (Initial: 26870)
#     Filtering genes: Requiring expression in >= 120 cells (max of 3 absolute and 10.0% of 1193)...
#     Genes after filtering: 9297
#       Calculating mean expression for 9297 genes (Nestin, group CA1)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Nestin, group CA1).
#     Finished DGE for Nestin, group CA1. Found 9297 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_CA1_mut_vs_ctrl.csv
#     Warning (Nestin, group CA1): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\CA1'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\CA1'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\CA1' is writable.
#     Saved 128 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\CA1\Mutant_vs_Control_up_significant.csv
#     Saved 2349 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\CA1\Mutant_vs_Control_down_significant.csv
#
# Processing group: MGE-derived (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Filtering genes for Emx1 (Initial: 26870)
#     Filtering genes: Requiring expression in >= 19 cells (max of 3 absolute and 10.0% of 189)...
#     Genes after filtering: 11918
#       Calculating mean expression for 11918 genes (Emx1, group MGE-derived)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Emx1, group MGE-derived).
#     Finished DGE for Emx1, group MGE-derived. Found 11918 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_MGE-derived_mut_vs_ctrl.csv
#     Warning (Emx1, group MGE-derived): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\MGE-derived'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\MGE-derived'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\MGE-derived' is writable.
#     Saved 151 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\MGE-derived\Mutant_vs_Control_up_significant.csv
#     Saved 221 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\MGE-derived\Mutant_vs_Control_down_significant.csv
#   Running DGE for Nestin genotype...
#     Filtering genes for Nestin (Initial: 26870)
#     Filtering genes: Requiring expression in >= 35 cells (max of 3 absolute and 10.0% of 349)...
#     Genes after filtering: 11319
#       Calculating mean expression for 11319 genes (Nestin, group MGE-derived)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Nestin, group MGE-derived).
#     Finished DGE for Nestin, group MGE-derived. Found 11319 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_MGE-derived_mut_vs_ctrl.csv
#     Warning (Nestin, group MGE-derived): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\MGE-derived'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\MGE-derived'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\MGE-derived' is writable.
#     Saved 53 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\MGE-derived\Mutant_vs_Control_up_significant.csv
#     Saved 169 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\MGE-derived\Mutant_vs_Control_down_significant.csv
#
# Processing group: Mature GC (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Filtering genes for Emx1 (Initial: 26870)
#     Filtering genes: Requiring expression in >= 75 cells (max of 3 absolute and 10.0% of 745)...
#     Genes after filtering: 8334
#       Calculating mean expression for 8334 genes (Emx1, group Mature GC)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Emx1, group Mature GC).
#     Finished DGE for Emx1, group Mature GC. Found 8334 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_Mature_GC_mut_vs_ctrl.csv
#     Warning (Emx1, group Mature GC): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Mature_GC'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Mature_GC'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Mature_GC' is writable.
#     Saved 500 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Mature_GC\Mutant_vs_Control_up_significant.csv
#     Saved 622 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Mature_GC\Mutant_vs_Control_down_significant.csv
#   Running DGE for Nestin genotype...
#     Filtering genes for Nestin (Initial: 26870)
#     Filtering genes: Requiring expression in >= 139 cells (max of 3 absolute and 10.0% of 1389)...
#     Genes after filtering: 8327
#       Calculating mean expression for 8327 genes (Nestin, group Mature GC)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Nestin, group Mature GC).
#     Finished DGE for Nestin, group Mature GC. Found 8327 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_Mature_GC_mut_vs_ctrl.csv
#     Warning (Nestin, group Mature GC): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Mature_GC'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Mature_GC'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Mature_GC' is writable.
#     Saved 148 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Mature_GC\Mutant_vs_Control_up_significant.csv
#     Saved 3028 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Mature_GC\Mutant_vs_Control_down_significant.csv
#
# Processing group: MOL (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Filtering genes for Emx1 (Initial: 26870)
#     Filtering genes: Requiring expression in >= 19 cells (max of 3 absolute and 10.0% of 189)...
#     Genes after filtering: 5047
#       Calculating mean expression for 5047 genes (Emx1, group MOL)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Emx1, group MOL).
#     Finished DGE for Emx1, group MOL. Found 5047 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_MOL_mut_vs_ctrl.csv
#     Warning (Emx1, group MOL): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\MOL'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\MOL'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\MOL' is writable.
#     Saved 6 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\MOL\Mutant_vs_Control_up_significant.csv
#     Saved 3 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\MOL\Mutant_vs_Control_down_significant.csv
#   Running DGE for Nestin genotype...
#     Filtering genes for Nestin (Initial: 26870)
#     Filtering genes: Requiring expression in >= 148 cells (max of 3 absolute and 10.0% of 1471)...
#     Genes after filtering: 4793
#       Calculating mean expression for 4793 genes (Nestin, group MOL)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Nestin, group MOL).
#     Finished DGE for Nestin, group MOL. Found 4793 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_MOL_mut_vs_ctrl.csv
#     Warning (Nestin, group MOL): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\MOL'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\MOL'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\MOL' is writable.
#     Saved 79 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\MOL\Mutant_vs_Control_up_significant.csv
#     Saved 879 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\MOL\Mutant_vs_Control_down_significant.csv
#
# Processing group: ProS (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Filtering genes for Emx1 (Initial: 26870)
#     Filtering genes: Requiring expression in >= 19 cells (max of 3 absolute and 10.0% of 187)...
#     Genes after filtering: 9700
#       Calculating mean expression for 9700 genes (Emx1, group ProS)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Emx1, group ProS).
#     Finished DGE for Emx1, group ProS. Found 9700 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_ProS_mut_vs_ctrl.csv
#     Warning (Emx1, group ProS): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\ProS'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\ProS'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\ProS' is writable.
#     Saved 51 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\ProS\Mutant_vs_Control_up_significant.csv
#     Saved 35 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\ProS\Mutant_vs_Control_down_significant.csv
#   Running DGE for Nestin genotype...
#     Filtering genes for Nestin (Initial: 26870)
#     Filtering genes: Requiring expression in >= 18 cells (max of 3 absolute and 10.0% of 180)...
#     Genes after filtering: 9782
#       Calculating mean expression for 9782 genes (Nestin, group ProS)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Nestin, group ProS).
#     Finished DGE for Nestin, group ProS. Found 9782 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_ProS_mut_vs_ctrl.csv
#     Warning (Nestin, group ProS): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\ProS'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\ProS'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\ProS' is writable.
#     Saved 3 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\ProS\Mutant_vs_Control_up_significant.csv
#     Saved 12 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\ProS\Mutant_vs_Control_down_significant.csv
#
# Processing group: Microglia (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group Microglia: Not enough cells (< 50). Emx1_Control: 50, Emx1_Mutant: 32
#   Running DGE for Nestin genotype...
#     Filtering genes for Nestin (Initial: 26870)
#     Filtering genes: Requiring expression in >= 116 cells (max of 3 absolute and 10.0% of 1154)...
#     Genes after filtering: 3777
#       Calculating mean expression for 3777 genes (Nestin, group Microglia)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Nestin, group Microglia).
#     Finished DGE for Nestin, group Microglia. Found 3777 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_Microglia_mut_vs_ctrl.csv
#     Warning (Nestin, group Microglia): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Microglia'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Microglia'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Microglia' is writable.
#     Saved 55 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Microglia\Mutant_vs_Control_up_significant.csv
#     Saved 832 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Microglia\Mutant_vs_Control_down_significant.csv
#
# Processing group: Subiculum (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group Subiculum: Not enough cells (< 50). Emx1_Control: 47, Emx1_Mutant: 102
#   Running DGE for Nestin genotype...
#     Filtering genes for Nestin (Initial: 26870)
#     Filtering genes: Requiring expression in >= 28 cells (max of 3 absolute and 10.0% of 276)...
#     Genes after filtering: 9062
#       Calculating mean expression for 9062 genes (Nestin, group Subiculum)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Nestin, group Subiculum).
#     Finished DGE for Nestin, group Subiculum. Found 9062 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_Subiculum_mut_vs_ctrl.csv
#     Warning (Nestin, group Subiculum): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Subiculum'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Subiculum'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Subiculum' is writable.
#     Saved 7 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Subiculum\Mutant_vs_Control_up_significant.csv
#     Saved 66 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Subiculum\Mutant_vs_Control_down_significant.csv
#
# Processing group: CGE-derived (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Filtering genes for Emx1 (Initial: 26870)
#     Filtering genes: Requiring expression in >= 20 cells (max of 3 absolute and 10.0% of 192)...
#     Genes after filtering: 12324
#       Calculating mean expression for 12324 genes (Emx1, group CGE-derived)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Emx1, group CGE-derived).
#     Finished DGE for Emx1, group CGE-derived. Found 12324 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_CGE-derived_mut_vs_ctrl.csv
#     Warning (Emx1, group CGE-derived): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\CGE-derived'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\CGE-derived'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\CGE-derived' is writable.
#     Saved 217 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\CGE-derived\Mutant_vs_Control_up_significant.csv
#     Saved 147 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\CGE-derived\Mutant_vs_Control_down_significant.csv
#   Running DGE for Nestin genotype...
#     Filtering genes for Nestin (Initial: 26870)
#     Filtering genes: Requiring expression in >= 42 cells (max of 3 absolute and 10.0% of 411)...
#     Genes after filtering: 11997
#       Calculating mean expression for 11997 genes (Nestin, group CGE-derived)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Nestin, group CGE-derived).
#     Finished DGE for Nestin, group CGE-derived. Found 11997 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_CGE-derived_mut_vs_ctrl.csv
#     Warning (Nestin, group CGE-derived): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\CGE-derived'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\CGE-derived'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\CGE-derived' is writable.
#     Saved 112 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\CGE-derived\Mutant_vs_Control_up_significant.csv
#     Saved 150 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\CGE-derived\Mutant_vs_Control_down_significant.csv
#
# Processing group: VIP (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group VIP: Not enough cells (< 50). Emx1_Control: 32, Emx1_Mutant: 50
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group VIP: Not enough cells (< 50). Nestin_Control: 32, Nestin_Mutant: 114
#
# Processing group: CA2 (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group CA2: Not enough cells (< 50). Emx1_Control: 23, Emx1_Mutant: 40
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group CA2: Not enough cells (< 50). Nestin_Control: 21, Nestin_Mutant: 33
#
# Processing group: Sncg (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Filtering genes for Emx1 (Initial: 26870)
#     Filtering genes: Requiring expression in >= 18 cells (max of 3 absolute and 10.0% of 176)...
#     Genes after filtering: 9317
#       Calculating mean expression for 9317 genes (Emx1, group Sncg)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Emx1, group Sncg).
#     Finished DGE for Emx1, group Sncg. Found 9317 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_Sncg_mut_vs_ctrl.csv
#     Warning (Emx1, group Sncg): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Sncg'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Sncg'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Sncg' is writable.
#     Saved 7 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Sncg\Mutant_vs_Control_up_significant.csv
#     Saved 20 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Sncg\Mutant_vs_Control_down_significant.csv
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group Sncg: Not enough cells (< 50). Nestin_Control: 38, Nestin_Mutant: 57
#
# Processing group: OPC (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group OPC: Not enough cells (< 50). Emx1_Control: 35, Emx1_Mutant: 73
#   Running DGE for Nestin genotype...
#     Filtering genes for Nestin (Initial: 26870)
#     Filtering genes: Requiring expression in >= 63 cells (max of 3 absolute and 10.0% of 621)...
#     Genes after filtering: 5474
#       Calculating mean expression for 5474 genes (Nestin, group OPC)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Nestin, group OPC).
#     Finished DGE for Nestin, group OPC. Found 5474 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_OPC_mut_vs_ctrl.csv
#     Warning (Nestin, group OPC): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\OPC'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\OPC'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\OPC' is writable.
#     Saved 37 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\OPC\Mutant_vs_Control_up_significant.csv
#     Saved 702 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\OPC\Mutant_vs_Control_down_significant.csv
#
# Processing group: ABC (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group ABC: Not enough cells (< 50). Emx1_Control: 17, Emx1_Mutant: 30
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group ABC: Not enough cells (< 50). Nestin_Control: 50, Nestin_Mutant: 19
#
# Processing group: NFOL (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group NFOL: Not enough cells (< 50). Emx1_Control: 4, Emx1_Mutant: 16
#   Running DGE for Nestin genotype...
#     Filtering genes for Nestin (Initial: 26870)
#     Filtering genes: Requiring expression in >= 13 cells (max of 3 absolute and 10.0% of 129)...
#     Genes after filtering: 6169
#       Calculating mean expression for 6169 genes (Nestin, group NFOL)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Nestin, group NFOL).
#     Finished DGE for Nestin, group NFOL. Found 6169 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_NFOL_mut_vs_ctrl.csv
#     Warning (Nestin, group NFOL): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\NFOL'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\NFOL'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\NFOL' is writable.
# ...
#     Saved 22 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\PV\Mutant_vs_Control_down_significant.csv
#
# Processing group: Immature GC (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group Immature GC: Not enough cells (< 50). Emx1_Control: 79, Emx1_Mutant: 32
#   Running DGE for Nestin genotype...
#     Filtering genes for Nestin (Initial: 26870)
#     Filtering genes: Requiring expression in >= 40 cells (max of 3 absolute and 10.0% of 392)...
#     Genes after filtering: 9860
#       Calculating mean expression for 9860 genes (Nestin, group Immature GC)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Nestin, group Immature GC).
#     Finished DGE for Nestin, group Immature GC. Found 9860 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_Immature_GC_mut_vs_ctrl.csv
#     Warning (Nestin, group Immature GC): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Immature_GC'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Immature_GC'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Immature_GC' is writable.
#     Saved 86 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Immature_GC\Mutant_vs_Control_up_significant.csv
#     Saved 468 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Nestin\Immature_GC\Mutant_vs_Control_down_significant.csv
#
# Processing group: VLMC (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group VLMC: Not enough cells (< 50). Emx1_Control: 27, Emx1_Mutant: 55
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group VLMC: Not enough cells (< 50). Nestin_Control: 46, Nestin_Mutant: 16
#
# Processing group: Endothelial (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Filtering genes for Emx1 (Initial: 26870)
#     Filtering genes: Requiring expression in >= 13 cells (max of 3 absolute and 10.0% of 121)...
#     Genes after filtering: 7367
#       Calculating mean expression for 7367 genes (Emx1, group Endothelial)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Emx1, group Endothelial).
#     Finished DGE for Emx1, group Endothelial. Found 7367 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_Endothelial_mut_vs_ctrl.csv
#     Warning (Emx1, group Endothelial): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Endothelial'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Endothelial'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Endothelial' is writable.
#     No significant UP genes found for Mutant_vs_Control. Empty CSV file with header created: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Endothelial\Mutant_vs_Control_up_significant.csv
#     No significant DOWN genes found for Mutant_vs_Control. Empty CSV file with header created: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\sig_deg_lists\Emx1\Endothelial\Mutant_vs_Control_down_significant.csv
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group Endothelial: Not enough cells (< 50). Nestin_Control: 84, Nestin_Mutant: 26
#
# Processing group: Lamp5 (DG) (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group Lamp5 (DG): Not enough cells (< 50). Emx1_Control: 19, Emx1_Mutant: 15
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group Lamp5 (DG): Not enough cells (< 50). Nestin_Control: 27, Nestin_Mutant: 24
#
# Processing group: nIPC (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group nIPC: Not enough cells (< 50). Emx1_Control: 4, Emx1_Mutant: 14
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group nIPC: Not enough cells (< 50). Nestin_Control: 22, Nestin_Mutant: 23
#
# Processing group: Pericytes (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group Pericytes: Not enough cells (< 50). Emx1_Control: 12, Emx1_Mutant: 11
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group Pericytes: Not enough cells (< 50). Nestin_Control: 70, Nestin_Mutant: 20
#
# Processing group: Car3 (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group Car3: Not enough cells (< 50). Emx1_Control: 21, Emx1_Mutant: 10
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group Car3: Not enough cells (< 50). Nestin_Control: 23, Nestin_Mutant: 19
#
# Processing group: VIP (DG) (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group VIP (DG): Not enough cells (< 50). Emx1_Control: 14, Emx1_Mutant: 19
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group VIP (DG): Not enough cells (< 50). Nestin_Control: 24, Nestin_Mutant: 32
#
# Processing group: Mossy cells (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group Mossy cells: Not enough cells (< 50). Emx1_Control: 11, Emx1_Mutant: 15
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group Mossy cells: Not enough cells (< 50). Nestin_Control: 4, Nestin_Mutant: 17
#
# Processing group: Neuroblast (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group Neuroblast: Not enough cells (< 50). Emx1_Control: 11, Emx1_Mutant: 5
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group Neuroblast: Not enough cells (< 50). Nestin_Control: 94, Nestin_Mutant: 32
#
# Processing group: Cajal-Retzius (using key 'cell_type_L2')
#   Running DGE for Emx1 genotype...
#     Skipping Emx1 DGE for group Cajal-Retzius: Not enough cells (< 50). Emx1_Control: 2, Emx1_Mutant: 4
#   Running DGE for Nestin genotype...
#     Skipping Nestin DGE for group Cajal-Retzius: Not enough cells (< 50). Nestin_Control: 23, Nestin_Mutant: 36
#
# Summary of skipped groups (using key 'cell_type_L2') for Emx1 saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Emx1_skipped_cell_type_L2.csv
#
# Summary of skipped groups (using key 'cell_type_L2') for Nestin saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\geno_spec_cond_comp\dge_Nestin_skipped_cell_type_L2.csv
#
# Genotype-Specific DGE analysis finished.
#
# Generating Volcano Plots for Genotype-Specific DGE results...
#
# --- Visualizing for Genotype: Emx1 ---
#   Generating volcano plot for: Emx1 - Astrocytes (Counts: Emx1_Ctrl=145, Emx1_Mut=212) -> dge_Emx1_Astrocytes_volcano.png
# ---
#   Generating volcano plot for: Emx1 - Unknown (Counts: Emx1_Ctrl=932, Emx1_Mut=841) -> dge_Emx1_Unknown_volcano.png
# ---
#   Generating volcano plot for: Emx1 - CA3 (Counts: Emx1_Ctrl=217, Emx1_Mut=336) -> dge_Emx1_CA3_volcano.png
# ---
#   Generating volcano plot for: Emx1 - ENT (Counts: Emx1_Ctrl=1185, Emx1_Mut=1841) -> dge_Emx1_ENT_volcano.png
# ---
#   Generating volcano plot for: Emx1 - PPP (Counts: Emx1_Ctrl=59, Emx1_Mut=323) -> dge_Emx1_PPP_volcano.png
# ---
#   Generating volcano plot for: Emx1 - CA1 (Counts: Emx1_Ctrl=370, Emx1_Mut=493) -> dge_Emx1_CA1_volcano.png
# ---
#   Generating volcano plot for: Emx1 - MGE-derived (Counts: Emx1_Ctrl=77, Emx1_Mut=112) -> dge_Emx1_MGE-derived_volcano.png
# ---
#   Generating volcano plot for: Emx1 - Mature GC (Counts: Emx1_Ctrl=477, Emx1_Mut=268) -> dge_Emx1_Mature_GC_volcano.png
# ---
#   Generating volcano plot for: Emx1 - MOL (Counts: Emx1_Ctrl=98, Emx1_Mut=91) -> dge_Emx1_MOL_volcano.png
# ---
#   Generating volcano plot for: Emx1 - ProS (Counts: Emx1_Ctrl=65, Emx1_Mut=122) -> dge_Emx1_ProS_volcano.png
# ---
#   Skipping volcano plot for Emx1 - Microglia: Not enough cells in one or both groups (< 50). Emx1_Ctrl=50, Emx1_Mut=32.
#   Skipping volcano plot for Emx1 - Subiculum: Not enough cells in one or both groups (< 50). Emx1_Ctrl=47, Emx1_Mut=102.
#   Generating volcano plot for: Emx1 - CGE-derived (Counts: Emx1_Ctrl=62, Emx1_Mut=130) -> dge_Emx1_CGE-derived_volcano.png
# ---
#   Skipping volcano plot for Emx1 - VIP: Not enough cells in one or both groups (< 50). Emx1_Ctrl=32, Emx1_Mut=50.
#   Skipping volcano plot for Emx1 - CA2: Not enough cells in one or both groups (< 50). Emx1_Ctrl=23, Emx1_Mut=40.
#   Generating volcano plot for: Emx1 - Sncg (Counts: Emx1_Ctrl=61, Emx1_Mut=115) -> dge_Emx1_Sncg_volcano.png
# ---
#   Skipping volcano plot for Emx1 - OPC: Not enough cells in one or both groups (< 50). Emx1_Ctrl=35, Emx1_Mut=73.
#   Skipping volcano plot for Emx1 - ABC: Not enough cells in one or both groups (< 50). Emx1_Ctrl=17, Emx1_Mut=30.
#   Skipping volcano plot for Emx1 - NFOL: Not enough cells in one or both groups (< 50). Emx1_Ctrl=4, Emx1_Mut=16.
#   Skipping volcano plot for Emx1 - Lamp5: Not enough cells in one or both groups (< 50). Emx1_Ctrl=34, Emx1_Mut=75.
#   Generating volcano plot for: Emx1 - SST (Counts: Emx1_Ctrl=62, Emx1_Mut=131) -> dge_Emx1_SST_volcano.png
# ---
#   Generating volcano plot for: Emx1 - PV (Counts: Emx1_Ctrl=85, Emx1_Mut=162) -> dge_Emx1_PV_volcano.png
# ---
#   Skipping volcano plot for Emx1 - Immature GC: Not enough cells in one or both groups (< 50). Emx1_Ctrl=79, Emx1_Mut=32.
#   Skipping volcano plot for Emx1 - VLMC: Not enough cells in one or both groups (< 50). Emx1_Ctrl=27, Emx1_Mut=55.
#   Generating volcano plot for: Emx1 - Endothelial (Counts: Emx1_Ctrl=60, Emx1_Mut=61) -> dge_Emx1_Endothelial_volcano.png
# ---
#   Skipping volcano plot for Emx1 - Lamp5 (DG): Not enough cells in one or both groups (< 50). Emx1_Ctrl=19, Emx1_Mut=15.
#   Skipping volcano plot for Emx1 - nIPC: Not enough cells in one or both groups (< 50). Emx1_Ctrl=4, Emx1_Mut=14.
#   Skipping volcano plot for Emx1 - Pericytes: Not enough cells in one or both groups (< 50). Emx1_Ctrl=12, Emx1_Mut=11.
#   Skipping volcano plot for Emx1 - Car3: Not enough cells in one or both groups (< 50). Emx1_Ctrl=21, Emx1_Mut=10.
#   Skipping volcano plot for Emx1 - VIP (DG): Not enough cells in one or both groups (< 50). Emx1_Ctrl=14, Emx1_Mut=19.
#   Skipping volcano plot for Emx1 - Mossy cells: Not enough cells in one or both groups (< 50). Emx1_Ctrl=11, Emx1_Mut=15.
#   Skipping volcano plot for Emx1 - Neuroblast: Not enough cells in one or both groups (< 50). Emx1_Ctrl=11, Emx1_Mut=5.
#   Skipping volcano plot for Emx1 - Cajal-Retzius: Not enough cells in one or both groups (< 50). Emx1_Ctrl=2, Emx1_Mut=4.
#
# --- Visualizing for Genotype: Nestin ---
#   Generating volcano plot for: Nestin - Astrocytes (Counts: Nestin_Ctrl=464, Nestin_Mut=159) -> dge_Nestin_Astrocytes_volcano.png
# ---
#   Generating volcano plot for: Nestin - Unknown (Counts: Nestin_Ctrl=1769, Nestin_Mut=558) -> dge_Nestin_Unknown_volcano.png
# ---
#   Generating volcano plot for: Nestin - CA3 (Counts: Nestin_Ctrl=209, Nestin_Mut=337) -> dge_Nestin_CA3_volcano.png
# ---
#   Generating volcano plot for: Nestin - ENT (Counts: Nestin_Ctrl=1583, Nestin_Mut=2980) -> dge_Nestin_ENT_volcano.png
# ---
#   Generating volcano plot for: Nestin - PPP (Counts: Nestin_Ctrl=95, Nestin_Mut=385) -> dge_Nestin_PPP_volcano.png
# ---
#   Generating volcano plot for: Nestin - CA1 (Counts: Nestin_Ctrl=405, Nestin_Mut=788) -> dge_Nestin_CA1_volcano.png
# ---
#   Generating volcano plot for: Nestin - MGE-derived (Counts: Nestin_Ctrl=123, Nestin_Mut=226) -> dge_Nestin_MGE-derived_volcano.png
# ---
#   Generating volcano plot for: Nestin - Mature GC (Counts: Nestin_Ctrl=849, Nestin_Mut=540) -> dge_Nestin_Mature_GC_volcano.png
# ---
#   Generating volcano plot for: Nestin - MOL (Counts: Nestin_Ctrl=803, Nestin_Mut=668) -> dge_Nestin_MOL_volcano.png
# ---
#   Generating volcano plot for: Nestin - ProS (Counts: Nestin_Ctrl=61, Nestin_Mut=119) -> dge_Nestin_ProS_volcano.png
# ---
#   Generating volcano plot for: Nestin - Microglia (Counts: Nestin_Ctrl=483, Nestin_Mut=671) -> dge_Nestin_Microglia_volcano.png
# ---
#   Generating volcano plot for: Nestin - Subiculum (Counts: Nestin_Ctrl=106, Nestin_Mut=170) -> dge_Nestin_Subiculum_volcano.png
# ---
#   Generating volcano plot for: Nestin - CGE-derived (Counts: Nestin_Ctrl=120, Nestin_Mut=291) -> dge_Nestin_CGE-derived_volcano.png
# ---
#   Skipping volcano plot for Nestin - VIP: Not enough cells in one or both groups (< 50). Nestin_Ctrl=32, Nestin_Mut=114.
#   Skipping volcano plot for Nestin - CA2: Not enough cells in one or both groups (< 50). Nestin_Ctrl=21, Nestin_Mut=33.
#   Skipping volcano plot for Nestin - Sncg: Not enough cells in one or both groups (< 50). Nestin_Ctrl=38, Nestin_Mut=57.
#   Generating volcano plot for: Nestin - OPC (Counts: Nestin_Ctrl=253, Nestin_Mut=368) -> dge_Nestin_OPC_volcano.png
# ---
#   Skipping volcano plot for Nestin - ABC: Not enough cells in one or both groups (< 50). Nestin_Ctrl=50, Nestin_Mut=19.
#   Generating volcano plot for: Nestin - NFOL (Counts: Nestin_Ctrl=50, Nestin_Mut=79) -> dge_Nestin_NFOL_volcano.png
# ---
#   Generating volcano plot for: Nestin - Lamp5 (Counts: Nestin_Ctrl=55, Nestin_Mut=123) -> dge_Nestin_Lamp5_volcano.png
# ---
#   Generating volcano plot for: Nestin - SST (Counts: Nestin_Ctrl=78, Nestin_Mut=173) -> dge_Nestin_SST_volcano.png
# ---
#   Generating volcano plot for: Nestin - PV (Counts: Nestin_Ctrl=83, Nestin_Mut=151) -> dge_Nestin_PV_volcano.png
# ---
#   Generating volcano plot for: Nestin - Immature GC (Counts: Nestin_Ctrl=275, Nestin_Mut=117) -> dge_Nestin_Immature_GC_volcano.png
# ---
#   Skipping volcano plot for Nestin - VLMC: Not enough cells in one or both groups (< 50). Nestin_Ctrl=46, Nestin_Mut=16.
#   Skipping volcano plot for Nestin - Endothelial: Not enough cells in one or both groups (< 50). Nestin_Ctrl=84, Nestin_Mut=26.
#   Skipping volcano plot for Nestin - Lamp5 (DG): Not enough cells in one or both groups (< 50). Nestin_Ctrl=27, Nestin_Mut=24.
#   Skipping volcano plot for Nestin - nIPC: Not enough cells in one or both groups (< 50). Nestin_Ctrl=22, Nestin_Mut=23.
#   Skipping volcano plot for Nestin - Pericytes: Not enough cells in one or both groups (< 50). Nestin_Ctrl=70, Nestin_Mut=20.
#   Skipping volcano plot for Nestin - Car3: Not enough cells in one or both groups (< 50). Nestin_Ctrl=23, Nestin_Mut=19.
#   Skipping volcano plot for Nestin - VIP (DG): Not enough cells in one or both groups (< 50). Nestin_Ctrl=24, Nestin_Mut=32.
#   Skipping volcano plot for Nestin - Mossy cells: Not enough cells in one or both groups (< 50). Nestin_Ctrl=4, Nestin_Mut=17.
#   Skipping volcano plot for Nestin - Neuroblast: Not enough cells in one or both groups (< 50). Nestin_Ctrl=94, Nestin_Mut=32.
#   Skipping volcano plot for Nestin - Cajal-Retzius: Not enough cells in one or both groups (< 50). Nestin_Ctrl=23, Nestin_Mut=36.
#
# Genotype-Specific DGE visualization finished.

# %%
# Genotype Comparison DGE (Nestin vs Emx1 within each condition) using the 'for_DEGs' layer, grouped by the DEG_BY
print(f"\nRunning Genotype Comparison DGE (grouped by {DEG_BY})...")
dge_genotype_within_condition = functions_degs.run_genotype_comparison_dge(
    adata,
    grouping_key=DEG_BY,
    dge_output_dir=DGE_OUTPUT_DIR,
    plot_output_dir=PLOT_OUTPUT_DIR,
    layer='for_DEGs' if 'for_DEGs' in adata.layers else None
)
# Out:
# Running Genotype Comparison DGE (grouped by cell_type_L2)...
#
# Starting DGE analysis: Genotype comparison within conditions...
#
# Processing group: Astrocytes (using key 'cell_type_L2')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Initial genes for Control condition: 26870
#     Filtering genes for Control: Requiring expression in >= 61 cells (max of 3 absolute and 10.0% of 609)...
#     Genes after filtering for Control: 5966
#       Calculating mean expression for 5966 genes (Control condition, group Astrocytes)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Control condition, group Astrocytes).
#     Finished DGE for Control, group Astrocytes. Found 5966 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_Astrocytes_Nestin_vs_Emx1.csv
#     Warning (Control condition, group Astrocytes): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Astrocytes'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Astrocytes'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Astrocytes' is writable.
#     Saved 851 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Astrocytes\Nestin_vs_Emx1_up_significant.csv
#     Saved 288 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Astrocytes\Nestin_vs_Emx1_down_significant.csv
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Initial genes for Mutant condition: 26870
#     Filtering genes for Mutant: Requiring expression in >= 38 cells (max of 3 absolute and 10.0% of 371)...
#     Genes after filtering for Mutant: 4676
#       Calculating mean expression for 4676 genes (Mutant condition, group Astrocytes)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Mutant condition, group Astrocytes).
#     Finished DGE for Mutant, group Astrocytes. Found 4676 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_Astrocytes_Nestin_vs_Emx1.csv
#     Warning (Mutant condition, group Astrocytes): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\Astrocytes'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\Astrocytes'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\Astrocytes' is writable.
#     Saved 198 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\Astrocytes\Nestin_vs_Emx1_up_significant.csv
#     Saved 271 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\Astrocytes\Nestin_vs_Emx1_down_significant.csv
#
# Processing group: Unknown (using key 'cell_type_L2')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Initial genes for Control condition: 26870
#     Filtering genes for Control: Requiring expression in >= 271 cells (max of 3 absolute and 10.0% of 2701)...
#     Genes after filtering for Control: 3173
#       Calculating mean expression for 3173 genes (Control condition, group Unknown)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Control condition, group Unknown).
#     Finished DGE for Control, group Unknown. Found 3173 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_Unknown_Nestin_vs_Emx1.csv
#     Warning (Control condition, group Unknown): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Unknown'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Unknown'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Unknown' is writable.
#     Saved 1784 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Unknown\Nestin_vs_Emx1_up_significant.csv
#     Saved 547 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Unknown\Nestin_vs_Emx1_down_significant.csv
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Initial genes for Mutant condition: 26870
#     Filtering genes for Mutant: Requiring expression in >= 140 cells (max of 3 absolute and 10.0% of 1399)...
#     Genes after filtering for Mutant: 3101
#       Calculating mean expression for 3101 genes (Mutant condition, group Unknown)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Mutant condition, group Unknown).
#     Finished DGE for Mutant, group Unknown. Found 3101 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_Unknown_Nestin_vs_Emx1.csv
#     Warning (Mutant condition, group Unknown): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\Unknown'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\Unknown'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\Unknown' is writable.
#     Saved 861 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\Unknown\Nestin_vs_Emx1_up_significant.csv
#     Saved 541 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\Unknown\Nestin_vs_Emx1_down_significant.csv
#
# Processing group: CA3 (using key 'cell_type_L2')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Initial genes for Control condition: 26870
#     Filtering genes for Control: Requiring expression in >= 43 cells (max of 3 absolute and 10.0% of 426)...
#     Genes after filtering for Control: 11369
#       Calculating mean expression for 11369 genes (Control condition, group CA3)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Control condition, group CA3).
#     Finished DGE for Control, group CA3. Found 11369 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_CA3_Nestin_vs_Emx1.csv
#     Warning (Control condition, group CA3): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\CA3'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\CA3'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\CA3' is writable.
#     Saved 1048 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\CA3\Nestin_vs_Emx1_up_significant.csv
#     Saved 960 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\CA3\Nestin_vs_Emx1_down_significant.csv
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Initial genes for Mutant condition: 26870
#     Filtering genes for Mutant: Requiring expression in >= 68 cells (max of 3 absolute and 10.0% of 673)...
#     Genes after filtering for Mutant: 10035
#       Calculating mean expression for 10035 genes (Mutant condition, group CA3)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Mutant condition, group CA3).
#     Finished DGE for Mutant, group CA3. Found 10035 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_CA3_Nestin_vs_Emx1.csv
#     Warning (Mutant condition, group CA3): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\CA3'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\CA3'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\CA3' is writable.
#     Saved 543 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\CA3\Nestin_vs_Emx1_up_significant.csv
#     Saved 1361 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\CA3\Nestin_vs_Emx1_down_significant.csv
#
# Processing group: ENT (using key 'cell_type_L2')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Initial genes for Control condition: 26870
#     Filtering genes for Control: Requiring expression in >= 277 cells (max of 3 absolute and 10.0% of 2768)...
#     Genes after filtering for Control: 11612
#       Calculating mean expression for 11612 genes (Control condition, group ENT)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Control condition, group ENT).
#     Finished DGE for Control, group ENT. Found 11612 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_ENT_Nestin_vs_Emx1.csv
#     Warning (Control condition, group ENT): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\ENT'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\ENT'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\ENT' is writable.
#     Saved 1753 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\ENT\Nestin_vs_Emx1_up_significant.csv
#     Saved 1643 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\ENT\Nestin_vs_Emx1_down_significant.csv
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Initial genes for Mutant condition: 26870
#     Filtering genes for Mutant: Requiring expression in >= 483 cells (max of 3 absolute and 10.0% of 4821)...
#     Genes after filtering for Mutant: 10876
#       Calculating mean expression for 10876 genes (Mutant condition, group ENT)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Mutant condition, group ENT).
#     Finished DGE for Mutant, group ENT. Found 10876 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_ENT_Nestin_vs_Emx1.csv
#     Warning (Mutant condition, group ENT): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\ENT'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\ENT'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\ENT' is writable.
#     Saved 1059 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\ENT\Nestin_vs_Emx1_up_significant.csv
#     Saved 3022 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\ENT\Nestin_vs_Emx1_down_significant.csv
#
# Processing group: PPP (using key 'cell_type_L2')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Initial genes for Control condition: 26870
#     Filtering genes for Control: Requiring expression in >= 16 cells (max of 3 absolute and 10.0% of 154)...
#     Genes after filtering for Control: 9548
#       Calculating mean expression for 9548 genes (Control condition, group PPP)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Control condition, group PPP).
#     Finished DGE for Control, group PPP. Found 9548 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_PPP_Nestin_vs_Emx1.csv
#     Warning (Control condition, group PPP): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\PPP'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\PPP'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\PPP' is writable.
#     Saved 135 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\PPP\Nestin_vs_Emx1_up_significant.csv
#     Saved 140 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\PPP\Nestin_vs_Emx1_down_significant.csv
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Initial genes for Mutant condition: 26870
#     Filtering genes for Mutant: Requiring expression in >= 71 cells (max of 3 absolute and 10.0% of 708)...
#     Genes after filtering for Mutant: 8392
#       Calculating mean expression for 8392 genes (Mutant condition, group PPP)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Mutant condition, group PPP).
#     Finished DGE for Mutant, group PPP. Found 8392 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_PPP_Nestin_vs_Emx1.csv
#     Warning (Mutant condition, group PPP): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\PPP'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\PPP'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\PPP' is writable.
#     Saved 352 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\PPP\Nestin_vs_Emx1_up_significant.csv
#     Saved 1139 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\PPP\Nestin_vs_Emx1_down_significant.csv
#
# Processing group: CA1 (using key 'cell_type_L2')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Initial genes for Control condition: 26870
#     Filtering genes for Control: Requiring expression in >= 78 cells (max of 3 absolute and 10.0% of 775)...
#     Genes after filtering for Control: 9945
#       Calculating mean expression for 9945 genes (Control condition, group CA1)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Control condition, group CA1).
#     Finished DGE for Control, group CA1. Found 9945 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_CA1_Nestin_vs_Emx1.csv
#     Warning (Control condition, group CA1): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\CA1'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\CA1'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\CA1' is writable.
#     Saved 1733 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\CA1\Nestin_vs_Emx1_up_significant.csv
#     Saved 735 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\CA1\Nestin_vs_Emx1_down_significant.csv
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Initial genes for Mutant condition: 26870
#     Filtering genes for Mutant: Requiring expression in >= 129 cells (max of 3 absolute and 10.0% of 1281)...
#     Genes after filtering for Mutant: 8715
#       Calculating mean expression for 8715 genes (Mutant condition, group CA1)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Mutant condition, group CA1).
#     Finished DGE for Mutant, group CA1. Found 8715 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_CA1_Nestin_vs_Emx1.csv
#     Warning (Mutant condition, group CA1): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\CA1'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\CA1'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\CA1' is writable.
#     Saved 728 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\CA1\Nestin_vs_Emx1_up_significant.csv
#     Saved 1210 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\CA1\Nestin_vs_Emx1_down_significant.csv
#
# Processing group: MGE-derived (using key 'cell_type_L2')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Initial genes for Control condition: 26870
#     Filtering genes for Control: Requiring expression in >= 20 cells (max of 3 absolute and 10.0% of 200)...
#     Genes after filtering for Control: 12063
#       Calculating mean expression for 12063 genes (Control condition, group MGE-derived)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Control condition, group MGE-derived).
#     Finished DGE for Control, group MGE-derived. Found 12063 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_MGE-derived_Nestin_vs_Emx1.csv
#     Warning (Control condition, group MGE-derived): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\MGE-derived'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\MGE-derived'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\MGE-derived' is writable.
#     Saved 210 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\MGE-derived\Nestin_vs_Emx1_up_significant.csv
#     Saved 739 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\MGE-derived\Nestin_vs_Emx1_down_significant.csv
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Initial genes for Mutant condition: 26870
#     Filtering genes for Mutant: Requiring expression in >= 34 cells (max of 3 absolute and 10.0% of 338)...
#     Genes after filtering for Mutant: 11219
#       Calculating mean expression for 11219 genes (Mutant condition, group MGE-derived)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Mutant condition, group MGE-derived).
#     Finished DGE for Mutant, group MGE-derived. Found 11219 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_MGE-derived_Nestin_vs_Emx1.csv
#     Warning (Mutant condition, group MGE-derived): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\MGE-derived'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\MGE-derived'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\MGE-derived' is writable.
#     Saved 224 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\MGE-derived\Nestin_vs_Emx1_up_significant.csv
#     Saved 1053 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\MGE-derived\Nestin_vs_Emx1_down_significant.csv
#
# Processing group: Mature GC (using key 'cell_type_L2')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Initial genes for Control condition: 26870
#     Filtering genes for Control: Requiring expression in >= 133 cells (max of 3 absolute and 10.0% of 1326)...
#     Genes after filtering for Control: 8790
#       Calculating mean expression for 8790 genes (Control condition, group Mature GC)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Control condition, group Mature GC).
#     Finished DGE for Control, group Mature GC. Found 8790 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_Mature_GC_Nestin_vs_Emx1.csv
#     Warning (Control condition, group Mature GC): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Mature_GC'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Mature_GC'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Mature_GC' is writable.
#     Saved 2079 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Mature_GC\Nestin_vs_Emx1_up_significant.csv
#     Saved 1113 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Mature_GC\Nestin_vs_Emx1_down_significant.csv
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Initial genes for Mutant condition: 26870
#     Filtering genes for Mutant: Requiring expression in >= 81 cells (max of 3 absolute and 10.0% of 808)...
#     Genes after filtering for Mutant: 7510
#       Calculating mean expression for 7510 genes (Mutant condition, group Mature GC)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Mutant condition, group Mature GC).
#     Finished DGE for Mutant, group Mature GC. Found 7510 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_Mature_GC_Nestin_vs_Emx1.csv
#     Warning (Mutant condition, group Mature GC): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\Mature_GC'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\Mature_GC'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\Mature_GC' is writable.
#     Saved 431 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\Mature_GC\Nestin_vs_Emx1_up_significant.csv
#     Saved 1131 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\Mature_GC\Nestin_vs_Emx1_down_significant.csv
#
# Processing group: MOL (using key 'cell_type_L2')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Initial genes for Control condition: 26870
#     Filtering genes for Control: Requiring expression in >= 91 cells (max of 3 absolute and 10.0% of 901)...
#     Genes after filtering for Control: 5346
#       Calculating mean expression for 5346 genes (Control condition, group MOL)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Control condition, group MOL).
#     Finished DGE for Control, group MOL. Found 5346 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_MOL_Nestin_vs_Emx1.csv
#     Warning (Control condition, group MOL): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\MOL'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\MOL'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\MOL' is writable.
#     Saved 531 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\MOL\Nestin_vs_Emx1_up_significant.csv
#     Saved 237 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\MOL\Nestin_vs_Emx1_down_significant.csv
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Initial genes for Mutant condition: 26870
#     Filtering genes for Mutant: Requiring expression in >= 76 cells (max of 3 absolute and 10.0% of 759)...
#     Genes after filtering for Mutant: 4210
#       Calculating mean expression for 4210 genes (Mutant condition, group MOL)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Mutant condition, group MOL).
#     Finished DGE for Mutant, group MOL. Found 4210 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_MOL_Nestin_vs_Emx1.csv
#     Warning (Mutant condition, group MOL): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\MOL'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\MOL'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\MOL' is writable.
#     Saved 175 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\MOL\Nestin_vs_Emx1_up_significant.csv
#     Saved 166 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\MOL\Nestin_vs_Emx1_down_significant.csv
#
# Processing group: ProS (using key 'cell_type_L2')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Initial genes for Control condition: 26870
#     Filtering genes for Control: Requiring expression in >= 13 cells (max of 3 absolute and 10.0% of 126)...
#     Genes after filtering for Control: 10356
#       Calculating mean expression for 10356 genes (Control condition, group ProS)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Control condition, group ProS).
#     Finished DGE for Control, group ProS. Found 10356 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_ProS_Nestin_vs_Emx1.csv
#     Warning (Control condition, group ProS): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\ProS'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\ProS'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\ProS' is writable.
#     Saved 150 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\ProS\Nestin_vs_Emx1_up_significant.csv
#     Saved 171 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\ProS\Nestin_vs_Emx1_down_significant.csv
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Initial genes for Mutant condition: 26870
#     Filtering genes for Mutant: Requiring expression in >= 25 cells (max of 3 absolute and 10.0% of 241)...
#     Genes after filtering for Mutant: 9248
#       Calculating mean expression for 9248 genes (Mutant condition, group ProS)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Mutant condition, group ProS).
#     Finished DGE for Mutant, group ProS. Found 9248 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_ProS_Nestin_vs_Emx1.csv
#     Warning (Mutant condition, group ProS): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\ProS'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\ProS'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\ProS' is writable.
#     Saved 162 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\ProS\Nestin_vs_Emx1_up_significant.csv
#     Saved 392 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\ProS\Nestin_vs_Emx1_down_significant.csv
#
# Processing group: Microglia (using key 'cell_type_L2')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Initial genes for Control condition: 26870
#     Filtering genes for Control: Requiring expression in >= 54 cells (max of 3 absolute and 10.0% of 533)...
#     Genes after filtering for Control: 4649
#       Calculating mean expression for 4649 genes (Control condition, group Microglia)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Control condition, group Microglia).
#     Finished DGE for Control, group Microglia. Found 4649 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_Microglia_Nestin_vs_Emx1.csv
#     Warning (Control condition, group Microglia): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Microglia'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Microglia'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Microglia' is writable.
#     Saved 264 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Microglia\Nestin_vs_Emx1_up_significant.csv
#     Saved 119 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Microglia\Nestin_vs_Emx1_down_significant.csv
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group Microglia: Not enough cells (< 50). Emx1_Mutant: 32, Nestin_Mutant: 671
#
# Processing group: Subiculum (using key 'cell_type_L2')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group Subiculum: Not enough cells (< 50). Emx1_Control: 47, Nestin_Control: 106
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Initial genes for Mutant condition: 26870
#     Filtering genes for Mutant: Requiring expression in >= 28 cells (max of 3 absolute and 10.0% of 272)...
#     Genes after filtering for Mutant: 8434
#       Calculating mean expression for 8434 genes (Mutant condition, group Subiculum)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Mutant condition, group Subiculum).
#     Finished DGE for Mutant, group Subiculum. Found 8434 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_Subiculum_Nestin_vs_Emx1.csv
#     Warning (Mutant condition, group Subiculum): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\Subiculum'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\Subiculum'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\Subiculum' is writable.
#     Saved 254 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\Subiculum\Nestin_vs_Emx1_up_significant.csv
#     Saved 354 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\Subiculum\Nestin_vs_Emx1_down_significant.csv
#
# Processing group: CGE-derived (using key 'cell_type_L2')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Initial genes for Control condition: 26870
#     Filtering genes for Control: Requiring expression in >= 19 cells (max of 3 absolute and 10.0% of 182)...
#     Genes after filtering for Control: 12249
#       Calculating mean expression for 12249 genes (Control condition, group CGE-derived)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Control condition, group CGE-derived).
#     Finished DGE for Control, group CGE-derived. Found 12249 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_CGE-derived_Nestin_vs_Emx1.csv
#     Warning (Control condition, group CGE-derived): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\CGE-derived'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\CGE-derived'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\CGE-derived' is writable.
#     Saved 217 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\CGE-derived\Nestin_vs_Emx1_up_significant.csv
#     Saved 559 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\CGE-derived\Nestin_vs_Emx1_down_significant.csv
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Initial genes for Mutant condition: 26870
#     Filtering genes for Mutant: Requiring expression in >= 43 cells (max of 3 absolute and 10.0% of 421)...
#     Genes after filtering for Mutant: 12054
#       Calculating mean expression for 12054 genes (Mutant condition, group CGE-derived)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Mutant condition, group CGE-derived).
#     Finished DGE for Mutant, group CGE-derived. Found 12054 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_CGE-derived_Nestin_vs_Emx1.csv
#     Warning (Mutant condition, group CGE-derived): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\CGE-derived'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\CGE-derived'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\CGE-derived' is writable.
#     Saved 400 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\CGE-derived\Nestin_vs_Emx1_up_significant.csv
#     Saved 1451 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\CGE-derived\Nestin_vs_Emx1_down_significant.csv
#
# Processing group: VIP (using key 'cell_type_L2')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group VIP: Not enough cells (< 50). Emx1_Control: 32, Nestin_Control: 32
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Initial genes for Mutant condition: 26870
#     Filtering genes for Mutant: Requiring expression in >= 17 cells (max of 3 absolute and 10.0% of 164)...
#     Genes after filtering for Mutant: 6361
#       Calculating mean expression for 6361 genes (Mutant condition, group VIP)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Mutant condition, group VIP).
#     Finished DGE for Mutant, group VIP. Found 6361 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_VIP_Nestin_vs_Emx1.csv
#     Warning (Mutant condition, group VIP): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\VIP'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\VIP'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\VIP' is writable.
#     Saved 37 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\VIP\Nestin_vs_Emx1_up_significant.csv
#     Saved 91 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\VIP\Nestin_vs_Emx1_down_significant.csv
#
# Processing group: CA2 (using key 'cell_type_L2')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group CA2: Not enough cells (< 50). Emx1_Control: 23, Nestin_Control: 21
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group CA2: Not enough cells (< 50). Emx1_Mutant: 40, Nestin_Mutant: 33
#
# Processing group: Sncg (using key 'cell_type_L2')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group Sncg: Not enough cells (< 50). Emx1_Control: 61, Nestin_Control: 38
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Initial genes for Mutant condition: 26870
#     Filtering genes for Mutant: Requiring expression in >= 18 cells (max of 3 absolute and 10.0% of 172)...
#     Genes after filtering for Mutant: 8825
#       Calculating mean expression for 8825 genes (Mutant condition, group Sncg)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Mutant condition, group Sncg).
#     Finished DGE for Mutant, group Sncg. Found 8825 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_Sncg_Nestin_vs_Emx1.csv
#     Warning (Mutant condition, group Sncg): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\Sncg'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\Sncg'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\Sncg' is writable.
#     Saved 115 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Mutant\Sncg\Nestin_vs_Emx1_up_significant.csv
# ...
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Initial genes for Control condition: 26870
#     Filtering genes for Control: Requiring expression in >= 15 cells (max of 3 absolute and 10.0% of 144)...
#     Genes after filtering for Control: 8115
#       Calculating mean expression for 8115 genes (Control condition, group Endothelial)...
#       Using data from layer: for_DEGs
#       Added mean expression columns (Control condition, group Endothelial).
#     Finished DGE for Control, group Endothelial. Found 8115 ranked genes.
#     DGE results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_Endothelial_Nestin_vs_Emx1.csv
#     Warning (Control condition, group Endothelial): 'openpyxl' not installed. Cannot save to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Endothelial'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Endothelial'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Endothelial' is writable.
#     Saved 190 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Endothelial\Nestin_vs_Emx1_up_significant.csv
#     Saved 203 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\sig_deg_lists\Control\Endothelial\Nestin_vs_Emx1_down_significant.csv
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group Endothelial: Not enough cells (< 50). Emx1_Mutant: 61, Nestin_Mutant: 26
#
# Processing group: Lamp5 (DG) (using key 'cell_type_L2')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group Lamp5 (DG): Not enough cells (< 50). Emx1_Control: 19, Nestin_Control: 27
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group Lamp5 (DG): Not enough cells (< 50). Emx1_Mutant: 15, Nestin_Mutant: 24
#
# Processing group: nIPC (using key 'cell_type_L2')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group nIPC: Not enough cells (< 50). Emx1_Control: 4, Nestin_Control: 22
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group nIPC: Not enough cells (< 50). Emx1_Mutant: 14, Nestin_Mutant: 23
#
# Processing group: Pericytes (using key 'cell_type_L2')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group Pericytes: Not enough cells (< 50). Emx1_Control: 12, Nestin_Control: 70
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group Pericytes: Not enough cells (< 50). Emx1_Mutant: 11, Nestin_Mutant: 20
#
# Processing group: Car3 (using key 'cell_type_L2')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group Car3: Not enough cells (< 50). Emx1_Control: 21, Nestin_Control: 23
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group Car3: Not enough cells (< 50). Emx1_Mutant: 10, Nestin_Mutant: 19
#
# Processing group: VIP (DG) (using key 'cell_type_L2')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group VIP (DG): Not enough cells (< 50). Emx1_Control: 14, Nestin_Control: 24
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group VIP (DG): Not enough cells (< 50). Emx1_Mutant: 19, Nestin_Mutant: 32
#
# Processing group: Mossy cells (using key 'cell_type_L2')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group Mossy cells: Not enough cells (< 50). Emx1_Control: 11, Nestin_Control: 4
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group Mossy cells: Not enough cells (< 50). Emx1_Mutant: 15, Nestin_Mutant: 17
#
# Processing group: Neuroblast (using key 'cell_type_L2')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group Neuroblast: Not enough cells (< 50). Emx1_Control: 11, Nestin_Control: 94
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group Neuroblast: Not enough cells (< 50). Emx1_Mutant: 5, Nestin_Mutant: 32
#
# Processing group: Cajal-Retzius (using key 'cell_type_L2')
#   Running DGE for Control condition (Nestin vs Emx1)...
#     Skipping DGE for Control condition, group Cajal-Retzius: Not enough cells (< 50). Emx1_Control: 2, Nestin_Control: 23
#   Running DGE for Mutant condition (Nestin vs Emx1)...
#     Skipping DGE for Mutant condition, group Cajal-Retzius: Not enough cells (< 50). Emx1_Mutant: 4, Nestin_Mutant: 36
#
# Summary of skipped groups (using key 'cell_type_L2') for Control condition comparison saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\dge_Control_cond_comparison_skipped_cell_type_L2.csv
#
# Summary of skipped groups (using key 'cell_type_L2') for Mutant condition comparison saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res\cond_spec_geno_comp\dge_Mutant_cond_comparison_skipped_cell_type_L2.csv
#
# DGE analysis (Genotype comparison within conditions) finished.
#
# Generating Volcano Plots for Genotype comparison within conditions...
#
# --- Visualizing for Condition: Control (Nestin vs Emx1) ---
#   Generating volcano plot for: Control Cond - Astrocytes (Counts: Emx1_Control=145, Nestin_Control=464) -> dge_Control_cond_Nestin_vs_Emx1_Astrocytes_volcano.png
# ---
#   Generating volcano plot for: Control Cond - Unknown (Counts: Emx1_Control=932, Nestin_Control=1769) -> dge_Control_cond_Nestin_vs_Emx1_Unknown_volcano.png
# ---
#   Generating volcano plot for: Control Cond - CA3 (Counts: Emx1_Control=217, Nestin_Control=209) -> dge_Control_cond_Nestin_vs_Emx1_CA3_volcano.png
# ---
#   Generating volcano plot for: Control Cond - ENT (Counts: Emx1_Control=1185, Nestin_Control=1583) -> dge_Control_cond_Nestin_vs_Emx1_ENT_volcano.png
# ---
#   Generating volcano plot for: Control Cond - PPP (Counts: Emx1_Control=59, Nestin_Control=95) -> dge_Control_cond_Nestin_vs_Emx1_PPP_volcano.png
# ---
#   Generating volcano plot for: Control Cond - CA1 (Counts: Emx1_Control=370, Nestin_Control=405) -> dge_Control_cond_Nestin_vs_Emx1_CA1_volcano.png
# ---
#   Generating volcano plot for: Control Cond - MGE-derived (Counts: Emx1_Control=77, Nestin_Control=123) -> dge_Control_cond_Nestin_vs_Emx1_MGE-derived_volcano.png
# ---
#   Generating volcano plot for: Control Cond - Mature GC (Counts: Emx1_Control=477, Nestin_Control=849) -> dge_Control_cond_Nestin_vs_Emx1_Mature_GC_volcano.png
# ---
#   Generating volcano plot for: Control Cond - MOL (Counts: Emx1_Control=98, Nestin_Control=803) -> dge_Control_cond_Nestin_vs_Emx1_MOL_volcano.png
# ---
#   Generating volcano plot for: Control Cond - ProS (Counts: Emx1_Control=65, Nestin_Control=61) -> dge_Control_cond_Nestin_vs_Emx1_ProS_volcano.png
# ---
#   Generating volcano plot for: Control Cond - Microglia (Counts: Emx1_Control=50, Nestin_Control=483) -> dge_Control_cond_Nestin_vs_Emx1_Microglia_volcano.png
# ---
#   Skipping volcano plot for Control Cond - Subiculum: Not enough cells in one or both groups (< 50). Emx1_Control=47, Nestin_Control=106.
#   Generating volcano plot for: Control Cond - CGE-derived (Counts: Emx1_Control=62, Nestin_Control=120) -> dge_Control_cond_Nestin_vs_Emx1_CGE-derived_volcano.png
# ---
#   Skipping volcano plot for Control Cond - VIP: Not enough cells in one or both groups (< 50). Emx1_Control=32, Nestin_Control=32.
#   Skipping volcano plot for Control Cond - CA2: Not enough cells in one or both groups (< 50). Emx1_Control=23, Nestin_Control=21.
#   Skipping volcano plot for Control Cond - Sncg: Not enough cells in one or both groups (< 50). Emx1_Control=61, Nestin_Control=38.
#   Skipping volcano plot for Control Cond - OPC: Not enough cells in one or both groups (< 50). Emx1_Control=35, Nestin_Control=253.
#   Skipping volcano plot for Control Cond - ABC: Not enough cells in one or both groups (< 50). Emx1_Control=17, Nestin_Control=50.
#   Skipping volcano plot for Control Cond - NFOL: Not enough cells in one or both groups (< 50). Emx1_Control=4, Nestin_Control=50.
#   Skipping volcano plot for Control Cond - Lamp5: Not enough cells in one or both groups (< 50). Emx1_Control=34, Nestin_Control=55.
#   Generating volcano plot for: Control Cond - SST (Counts: Emx1_Control=62, Nestin_Control=78) -> dge_Control_cond_Nestin_vs_Emx1_SST_volcano.png
# ---
#   Generating volcano plot for: Control Cond - PV (Counts: Emx1_Control=85, Nestin_Control=83) -> dge_Control_cond_Nestin_vs_Emx1_PV_volcano.png
# ---
#   Generating volcano plot for: Control Cond - Immature GC (Counts: Emx1_Control=79, Nestin_Control=275) -> dge_Control_cond_Nestin_vs_Emx1_Immature_GC_volcano.png
# ---
#   Skipping volcano plot for Control Cond - VLMC: Not enough cells in one or both groups (< 50). Emx1_Control=27, Nestin_Control=46.
#   Generating volcano plot for: Control Cond - Endothelial (Counts: Emx1_Control=60, Nestin_Control=84) -> dge_Control_cond_Nestin_vs_Emx1_Endothelial_volcano.png
# ---
#   Skipping volcano plot for Control Cond - Lamp5 (DG): Not enough cells in one or both groups (< 50). Emx1_Control=19, Nestin_Control=27.
#   Skipping volcano plot for Control Cond - nIPC: Not enough cells in one or both groups (< 50). Emx1_Control=4, Nestin_Control=22.
#   Skipping volcano plot for Control Cond - Pericytes: Not enough cells in one or both groups (< 50). Emx1_Control=12, Nestin_Control=70.
#   Skipping volcano plot for Control Cond - Car3: Not enough cells in one or both groups (< 50). Emx1_Control=21, Nestin_Control=23.
#   Skipping volcano plot for Control Cond - VIP (DG): Not enough cells in one or both groups (< 50). Emx1_Control=14, Nestin_Control=24.
#   Skipping volcano plot for Control Cond - Mossy cells: Not enough cells in one or both groups (< 50). Emx1_Control=11, Nestin_Control=4.
#   Skipping volcano plot for Control Cond - Neuroblast: Not enough cells in one or both groups (< 50). Emx1_Control=11, Nestin_Control=94.
#   Skipping volcano plot for Control Cond - Cajal-Retzius: Not enough cells in one or both groups (< 50). Emx1_Control=2, Nestin_Control=23.
#
# --- Visualizing for Condition: Mutant (Nestin vs Emx1) ---
#   Generating volcano plot for: Mutant Cond - Astrocytes (Counts: Emx1_Mutant=212, Nestin_Mutant=159) -> dge_Mutant_cond_Nestin_vs_Emx1_Astrocytes_volcano.png
# ---
#   Generating volcano plot for: Mutant Cond - Unknown (Counts: Emx1_Mutant=841, Nestin_Mutant=558) -> dge_Mutant_cond_Nestin_vs_Emx1_Unknown_volcano.png
# ---
#   Generating volcano plot for: Mutant Cond - CA3 (Counts: Emx1_Mutant=336, Nestin_Mutant=337) -> dge_Mutant_cond_Nestin_vs_Emx1_CA3_volcano.png
# ---
#   Generating volcano plot for: Mutant Cond - ENT (Counts: Emx1_Mutant=1841, Nestin_Mutant=2980) -> dge_Mutant_cond_Nestin_vs_Emx1_ENT_volcano.png
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# ---
#   Generating volcano plot for: Mutant Cond - PPP (Counts: Emx1_Mutant=323, Nestin_Mutant=385) -> dge_Mutant_cond_Nestin_vs_Emx1_PPP_volcano.png
# ---
#   Generating volcano plot for: Mutant Cond - CA1 (Counts: Emx1_Mutant=493, Nestin_Mutant=788) -> dge_Mutant_cond_Nestin_vs_Emx1_CA1_volcano.png
# ---
#   Generating volcano plot for: Mutant Cond - MGE-derived (Counts: Emx1_Mutant=112, Nestin_Mutant=226) -> dge_Mutant_cond_Nestin_vs_Emx1_MGE-derived_volcano.png
# ---
#   Generating volcano plot for: Mutant Cond - Mature GC (Counts: Emx1_Mutant=268, Nestin_Mutant=540) -> dge_Mutant_cond_Nestin_vs_Emx1_Mature_GC_volcano.png
# ---
#   Generating volcano plot for: Mutant Cond - MOL (Counts: Emx1_Mutant=91, Nestin_Mutant=668) -> dge_Mutant_cond_Nestin_vs_Emx1_MOL_volcano.png
# ---
#   Generating volcano plot for: Mutant Cond - ProS (Counts: Emx1_Mutant=122, Nestin_Mutant=119) -> dge_Mutant_cond_Nestin_vs_Emx1_ProS_volcano.png
# ---
#   Skipping volcano plot for Mutant Cond - Microglia: Not enough cells in one or both groups (< 50). Emx1_Mutant=32, Nestin_Mutant=671.
#   Generating volcano plot for: Mutant Cond - Subiculum (Counts: Emx1_Mutant=102, Nestin_Mutant=170) -> dge_Mutant_cond_Nestin_vs_Emx1_Subiculum_volcano.png
# ---
#   Generating volcano plot for: Mutant Cond - CGE-derived (Counts: Emx1_Mutant=130, Nestin_Mutant=291) -> dge_Mutant_cond_Nestin_vs_Emx1_CGE-derived_volcano.png
# ---
#   Generating volcano plot for: Mutant Cond - VIP (Counts: Emx1_Mutant=50, Nestin_Mutant=114) -> dge_Mutant_cond_Nestin_vs_Emx1_VIP_volcano.png
# ---
#   Skipping volcano plot for Mutant Cond - CA2: Not enough cells in one or both groups (< 50). Emx1_Mutant=40, Nestin_Mutant=33.
#   Generating volcano plot for: Mutant Cond - Sncg (Counts: Emx1_Mutant=115, Nestin_Mutant=57) -> dge_Mutant_cond_Nestin_vs_Emx1_Sncg_volcano.png
# ---
#   Generating volcano plot for: Mutant Cond - OPC (Counts: Emx1_Mutant=73, Nestin_Mutant=368) -> dge_Mutant_cond_Nestin_vs_Emx1_OPC_volcano.png
# ---
#   Skipping volcano plot for Mutant Cond - ABC: Not enough cells in one or both groups (< 50). Emx1_Mutant=30, Nestin_Mutant=19.
#   Skipping volcano plot for Mutant Cond - NFOL: Not enough cells in one or both groups (< 50). Emx1_Mutant=16, Nestin_Mutant=79.
#   Generating volcano plot for: Mutant Cond - Lamp5 (Counts: Emx1_Mutant=75, Nestin_Mutant=123) -> dge_Mutant_cond_Nestin_vs_Emx1_Lamp5_volcano.png
# ---
#   Generating volcano plot for: Mutant Cond - SST (Counts: Emx1_Mutant=131, Nestin_Mutant=173) -> dge_Mutant_cond_Nestin_vs_Emx1_SST_volcano.png
# ---
#   Generating volcano plot for: Mutant Cond - PV (Counts: Emx1_Mutant=162, Nestin_Mutant=151) -> dge_Mutant_cond_Nestin_vs_Emx1_PV_volcano.png
# ---
#   Skipping volcano plot for Mutant Cond - Immature GC: Not enough cells in one or both groups (< 50). Emx1_Mutant=32, Nestin_Mutant=117.
#   Skipping volcano plot for Mutant Cond - VLMC: Not enough cells in one or both groups (< 50). Emx1_Mutant=55, Nestin_Mutant=16.
#   Skipping volcano plot for Mutant Cond - Endothelial: Not enough cells in one or both groups (< 50). Emx1_Mutant=61, Nestin_Mutant=26.
#   Skipping volcano plot for Mutant Cond - Lamp5 (DG): Not enough cells in one or both groups (< 50). Emx1_Mutant=15, Nestin_Mutant=24.
#   Skipping volcano plot for Mutant Cond - nIPC: Not enough cells in one or both groups (< 50). Emx1_Mutant=14, Nestin_Mutant=23.
#   Skipping volcano plot for Mutant Cond - Pericytes: Not enough cells in one or both groups (< 50). Emx1_Mutant=11, Nestin_Mutant=20.
#   Skipping volcano plot for Mutant Cond - Car3: Not enough cells in one or both groups (< 50). Emx1_Mutant=10, Nestin_Mutant=19.
#   Skipping volcano plot for Mutant Cond - VIP (DG): Not enough cells in one or both groups (< 50). Emx1_Mutant=19, Nestin_Mutant=32.
#   Skipping volcano plot for Mutant Cond - Mossy cells: Not enough cells in one or both groups (< 50). Emx1_Mutant=15, Nestin_Mutant=17.
#   Skipping volcano plot for Mutant Cond - Neuroblast: Not enough cells in one or both groups (< 50). Emx1_Mutant=5, Nestin_Mutant=32.
#   Skipping volcano plot for Mutant Cond - Cajal-Retzius: Not enough cells in one or both groups (< 50). Emx1_Mutant=4, Nestin_Mutant=36.
#
# DGE visualization (Genotype comparison within conditions) finished.

# %%
# Cell Type Comparison DGE (Each cell type vs Rest) using the 'for_DEGs' layer, using the DEG_BY
print(f"\nRunning Cell Type Comparison DGE (Markers for {DEG_BY})...")
dge_markers = functions_degs.run_cluster_comparison_dge(
    adata,
    grouping_key=DEG_BY, 
    dge_output_dir=BIOMARKER_OUTPUT_DIR, 
    plot_output_dir=BIOMARKER_OUTPUT_DIR,
    layer='for_DEGs' if 'for_DEGs' in adata.layers else None,
    method='wilcoxon' # or 't-test'
)
# Out:
# Running Cell Type Comparison DGE (Markers for cell_type_L2)...
#
# Starting Cluster Comparison DGE analysis (Markers for 'cell_type_L2') into D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers...
#   Initial genes: 26870
#   Filtering genes globally: Requiring expression in >= 3 cells...
#   Genes after global filtering: 26870
#   Proceeding with DGE for 33 groups. Removed groups: []
#   Running sc.tl.rank_genes_groups (groupby='cell_type_L2', method='wilcoxon')...
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:456: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:458: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:461: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:471: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:482: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:456: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:458: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:461: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:471: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:482: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:456: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:458: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:461: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:471: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:482: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:456: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:458: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:461: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:471: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:482: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:456: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:458: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:461: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:471: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:482: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:456: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:458: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:461: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:471: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:482: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:456: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:458: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:461: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:471: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:482: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:456: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:458: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:461: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:471: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:482: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:456: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:458: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:461: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:471: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:482: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:456: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:458: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:461: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:471: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:482: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:456: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:458: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:461: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:471: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:482: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:456: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:458: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:461: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:471: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:482: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:456: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "names"] = self.var_names[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:458: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "scores"] = scores[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:461: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals"] = pvals[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:471: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "pvals_adj"] = pvals_adj[global_indices]
# c:\Users\janku\miniforge3\envs\bioinf\lib\site-packages\scanpy\tools\_rank_genes_groups.py:482: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, "logfoldchanges"] = np.log2(
#   rank_genes_groups finished.
#     Calculating mean expression for Cluster ABC vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster ABC.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\dge_cluster_comparison_ABC_vs_Rest_top50.csv
#     Warning (Cluster ABC): 'openpyxl' not installed. Cannot save Top 50 to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\ABC'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\ABC'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\ABC' is writable.
#     Saved 782 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\ABC\Cluster_ABC_vs_Rest_up_significant.csv
#     Saved 1428 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\ABC\Cluster_ABC_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster Astrocytes vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster Astrocytes.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\dge_cluster_comparison_Astrocytes_vs_Rest_top50.csv
#     Warning (Cluster Astrocytes): 'openpyxl' not installed. Cannot save Top 50 to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Astrocytes'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Astrocytes'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Astrocytes' is writable.
#     Saved 1425 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Astrocytes\Cluster_Astrocytes_vs_Rest_up_significant.csv
#     Saved 6572 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Astrocytes\Cluster_Astrocytes_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster CA1 vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster CA1.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\dge_cluster_comparison_CA1_vs_Rest_top50.csv
#     Warning (Cluster CA1): 'openpyxl' not installed. Cannot save Top 50 to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\CA1'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\CA1'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\CA1' is writable.
#     Saved 3091 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\CA1\Cluster_CA1_vs_Rest_up_significant.csv
#     Saved 1360 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\CA1\Cluster_CA1_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster CA2 vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster CA2.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\dge_cluster_comparison_CA2_vs_Rest_top50.csv
#     Warning (Cluster CA2): 'openpyxl' not installed. Cannot save Top 50 to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\CA2'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\CA2'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\CA2' is writable.
#     Saved 2475 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\CA2\Cluster_CA2_vs_Rest_up_significant.csv
#     Saved 377 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\CA2\Cluster_CA2_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster CA3 vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster CA3.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\dge_cluster_comparison_CA3_vs_Rest_top50.csv
#     Warning (Cluster CA3): 'openpyxl' not installed. Cannot save Top 50 to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\CA3'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\CA3'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\CA3' is writable.
#     Saved 5390 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\CA3\Cluster_CA3_vs_Rest_up_significant.csv
#     Saved 935 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\CA3\Cluster_CA3_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster CGE-derived vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster CGE-derived.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\dge_cluster_comparison_CGE-derived_vs_Rest_top50.csv
#     Warning (Cluster CGE-derived): 'openpyxl' not installed. Cannot save Top 50 to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\CGE-derived'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\CGE-derived'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\CGE-derived' is writable.
#     Saved 8082 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\CGE-derived\Cluster_CGE-derived_vs_Rest_up_significant.csv
#     Saved 786 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\CGE-derived\Cluster_CGE-derived_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster Cajal-Retzius vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster Cajal-Retzius.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\dge_cluster_comparison_Cajal-Retzius_vs_Rest_top50.csv
#     Warning (Cluster Cajal-Retzius): 'openpyxl' not installed. Cannot save Top 50 to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Cajal-Retzius'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Cajal-Retzius'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Cajal-Retzius' is writable.
#     Saved 195 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Cajal-Retzius\Cluster_Cajal-Retzius_vs_Rest_up_significant.csv
#     Saved 2329 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Cajal-Retzius\Cluster_Cajal-Retzius_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster Car3 vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster Car3.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\dge_cluster_comparison_Car3_vs_Rest_top50.csv
#     Warning (Cluster Car3): 'openpyxl' not installed. Cannot save Top 50 to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Car3'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Car3'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Car3' is writable.
#     Saved 1073 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Car3\Cluster_Car3_vs_Rest_up_significant.csv
#     Saved 113 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Car3\Cluster_Car3_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster ENT vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster ENT.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\dge_cluster_comparison_ENT_vs_Rest_top50.csv
#     Warning (Cluster ENT): 'openpyxl' not installed. Cannot save Top 50 to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\ENT'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\ENT'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\ENT' is writable.
#     Saved 8899 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\ENT\Cluster_ENT_vs_Rest_up_significant.csv
#     Saved 1726 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\ENT\Cluster_ENT_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster Endothelial vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster Endothelial.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\dge_cluster_comparison_Endothelial_vs_Rest_top50.csv
#     Warning (Cluster Endothelial): 'openpyxl' not installed. Cannot save Top 50 to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Endothelial'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Endothelial'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Endothelial' is writable.
#     Saved 947 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Endothelial\Cluster_Endothelial_vs_Rest_up_significant.csv
#     Saved 4112 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Endothelial\Cluster_Endothelial_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster Immature GC vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster Immature GC.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\dge_cluster_comparison_Immature_GC_vs_Rest_top50.csv
#     Warning (Cluster Immature GC): 'openpyxl' not installed. Cannot save Top 50 to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Immature_GC'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Immature_GC'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Immature_GC' is writable.
#     Saved 4296 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Immature_GC\Cluster_Immature GC_vs_Rest_up_significant.csv
#     Saved 491 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Immature_GC\Cluster_Immature GC_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster Lamp5 vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster Lamp5.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\dge_cluster_comparison_Lamp5_vs_Rest_top50.csv
#     Warning (Cluster Lamp5): 'openpyxl' not installed. Cannot save Top 50 to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Lamp5'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Lamp5'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Lamp5' is writable.
#     Saved 1672 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Lamp5\Cluster_Lamp5_vs_Rest_up_significant.csv
#     Saved 907 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Lamp5\Cluster_Lamp5_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster Lamp5 (DG) vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster Lamp5 (DG).
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\dge_cluster_comparison_Lamp5_DG_vs_Rest_top50.csv
#     Warning (Cluster Lamp5 (DG)): 'openpyxl' not installed. Cannot save Top 50 to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Lamp5_DG'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Lamp5_DG'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Lamp5_DG' is writable.
#     Saved 4896 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Lamp5_DG\Cluster_Lamp5 (DG)_vs_Rest_up_significant.csv
#     Saved 7 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Lamp5_DG\Cluster_Lamp5 (DG)_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster MGE-derived vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster MGE-derived.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\dge_cluster_comparison_MGE-derived_vs_Rest_top50.csv
#     Warning (Cluster MGE-derived): 'openpyxl' not installed. Cannot save Top 50 to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\MGE-derived'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\MGE-derived'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\MGE-derived' is writable.
#     Saved 7052 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\MGE-derived\Cluster_MGE-derived_vs_Rest_up_significant.csv
#     Saved 321 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\MGE-derived\Cluster_MGE-derived_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster MOL vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster MOL.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\dge_cluster_comparison_MOL_vs_Rest_top50.csv
#     Warning (Cluster MOL): 'openpyxl' not installed. Cannot save Top 50 to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\MOL'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\MOL'
# ...
#     Calculating mean expression for Cluster PPP vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster PPP.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\dge_cluster_comparison_PPP_vs_Rest_top50.csv
#     Warning (Cluster PPP): 'openpyxl' not installed. Cannot save Top 50 to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\PPP'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\PPP'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\PPP' is writable.
#     Saved 1707 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\PPP\Cluster_PPP_vs_Rest_up_significant.csv
#     Saved 1038 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\PPP\Cluster_PPP_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster PV vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster PV.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\dge_cluster_comparison_PV_vs_Rest_top50.csv
#     Warning (Cluster PV): 'openpyxl' not installed. Cannot save Top 50 to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\PV'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\PV'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\PV' is writable.
#     Saved 2462 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\PV\Cluster_PV_vs_Rest_up_significant.csv
#     Saved 1445 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\PV\Cluster_PV_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster Pericytes vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster Pericytes.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\dge_cluster_comparison_Pericytes_vs_Rest_top50.csv
#     Warning (Cluster Pericytes): 'openpyxl' not installed. Cannot save Top 50 to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Pericytes'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Pericytes'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Pericytes' is writable.
#     Saved 113 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Pericytes\Cluster_Pericytes_vs_Rest_up_significant.csv
#     Saved 5250 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Pericytes\Cluster_Pericytes_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster ProS vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster ProS.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\dge_cluster_comparison_ProS_vs_Rest_top50.csv
#     Warning (Cluster ProS): 'openpyxl' not installed. Cannot save Top 50 to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\ProS'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\ProS'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\ProS' is writable.
#     Saved 3163 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\ProS\Cluster_ProS_vs_Rest_up_significant.csv
#     Saved 603 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\ProS\Cluster_ProS_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster SST vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster SST.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\dge_cluster_comparison_SST_vs_Rest_top50.csv
#     Warning (Cluster SST): 'openpyxl' not installed. Cannot save Top 50 to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\SST'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\SST'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\SST' is writable.
#     Saved 2350 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\SST\Cluster_SST_vs_Rest_up_significant.csv
#     Saved 1090 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\SST\Cluster_SST_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster Sncg vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster Sncg.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\dge_cluster_comparison_Sncg_vs_Rest_top50.csv
#     Warning (Cluster Sncg): 'openpyxl' not installed. Cannot save Top 50 to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Sncg'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Sncg'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Sncg' is writable.
#     Saved 2097 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Sncg\Cluster_Sncg_vs_Rest_up_significant.csv
#     Saved 959 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Sncg\Cluster_Sncg_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster Subiculum vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster Subiculum.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\dge_cluster_comparison_Subiculum_vs_Rest_top50.csv
#     Warning (Cluster Subiculum): 'openpyxl' not installed. Cannot save Top 50 to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Subiculum'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Subiculum'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Subiculum' is writable.
#     Saved 2109 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Subiculum\Cluster_Subiculum_vs_Rest_up_significant.csv
#     Saved 730 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Subiculum\Cluster_Subiculum_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster Unknown vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster Unknown.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\dge_cluster_comparison_Unknown_vs_Rest_top50.csv
#     Warning (Cluster Unknown): 'openpyxl' not installed. Cannot save Top 50 to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Unknown'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Unknown'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Unknown' is writable.
#     Saved 1475 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Unknown\Cluster_Unknown_vs_Rest_up_significant.csv
#     Saved 11128 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Unknown\Cluster_Unknown_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster VIP vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster VIP.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\dge_cluster_comparison_VIP_vs_Rest_top50.csv
#     Warning (Cluster VIP): 'openpyxl' not installed. Cannot save Top 50 to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\VIP'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\VIP'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\VIP' is writable.
#     Saved 622 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\VIP\Cluster_VIP_vs_Rest_up_significant.csv
#     Saved 2395 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\VIP\Cluster_VIP_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster VIP (DG) vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster VIP (DG).
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\dge_cluster_comparison_VIP_DG_vs_Rest_top50.csv
#     Warning (Cluster VIP (DG)): 'openpyxl' not installed. Cannot save Top 50 to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\VIP_DG'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\VIP_DG'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\VIP_DG' is writable.
#     Saved 4356 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\VIP_DG\Cluster_VIP (DG)_vs_Rest_up_significant.csv
#     Saved 6 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\VIP_DG\Cluster_VIP (DG)_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster VLMC vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster VLMC.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\dge_cluster_comparison_VLMC_vs_Rest_top50.csv
#     Warning (Cluster VLMC): 'openpyxl' not installed. Cannot save Top 50 to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\VLMC'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\VLMC'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\VLMC' is writable.
#     Saved 509 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\VLMC\Cluster_VLMC_vs_Rest_up_significant.csv
#     Saved 3799 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\VLMC\Cluster_VLMC_vs_Rest_down_significant.csv
#     Calculating mean expression for Cluster nIPC vs Rest...
#       Using data from layer: for_DEGs
#       Added mean expression columns for Cluster nIPC.
#     Top 50 Cluster marker results saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\dge_cluster_comparison_nIPC_vs_Rest_top50.csv
#     Warning (Cluster nIPC): 'openpyxl' not installed. Cannot save Top 50 to .xlsx.
#     DEBUG: Attempting to create list_output_dir: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\nIPC'
#     DEBUG: Successfully created/confirmed directory: 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\nIPC'
#     DEBUG: Directory 'D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\nIPC' is writable.
#     Saved 783 significant UP genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\nIPC\Cluster_nIPC_vs_Rest_up_significant.csv
#     Saved 80 significant DOWN genes with stats to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\nIPC\Cluster_nIPC_vs_Rest_down_significant.csv
#
# Cluster Comparison DGE analysis (Marker identification) finished.
#
# Generating marker plot for 'cell_type_L2' clusters...
# WARNING: saving figure to file D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\rank_genes_groups_cell_type_L2_cluster_markers_cell_type_L2.png
#   Marker plot saved to D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\rank_genes_groups_cluster_markers_cell_type_L2.png

# %%
print("\nAll analysis and output generation complete.")
print(f"Overall/Genotype DGE outputs saved in: {DGE_OUTPUT_DIR}")
print(f"Biomarker DGE outputs saved in: {BIOMARKER_OUTPUT_DIR}")
# Out:
# All analysis and output generation complete.
# Overall/Genotype DGE outputs saved in: D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\dge_res
# Biomarker DGE outputs saved in: D:/Github/SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers
