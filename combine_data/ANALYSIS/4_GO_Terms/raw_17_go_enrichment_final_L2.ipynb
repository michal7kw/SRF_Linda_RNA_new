# %%
import scanpy as sc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import sys
import pathlib
import gseapy as gp

# --- Configuration ---
PROJECT_DIR = "D:/Github/SRF_Linda_RNA"
WORKING_DIR = f"{PROJECT_DIR}/combine_data"
os.chdir(WORKING_DIR)
sys.path.insert(0, WORKING_DIR)

ORGANISM = 'Mouse'

# Set up directories
# REMOVE_DOUBLETS = True
REMOVE_DOUBLETS = False

FIX_TRESHOLD = True
# FIX_TRESHOLD = False

if FIX_TRESHOLD:
    BASE_RESULTS_DIR = os.path.join(WORKING_DIR, "results_from_raw")
else:
    if REMOVE_DOUBLETS:
        BASE_RESULTS_DIR = os.path.join(WORKING_DIR, "results_from_raw_percentile_threshold", "doublets_removed")
    else:
        BASE_RESULTS_DIR = os.path.join(WORKING_DIR, "results_from_raw_percentile_threshold")

INPUT_DIR = BASE_RESULTS_DIR
ADATA_PATH = os.path.join(INPUT_DIR, "annotation_final.h5ad")

DGE_RESULTS_DIR = os.path.join(INPUT_DIR,"DEGs_cell_type_L2")

# CUSTOM_ANALYSIS =  None
CUSTOM_ANALYSIS =  "FC_0_25"

DEG_BY = "cell_type_L2"
DEGs_folder = "DEGs_cell_type_L2FC_0_25"

if CUSTOM_ANALYSIS is not None:
    DGE_RESULTS_DIR = DGE_RESULTS_DIR + CUSTOM_ANALYSIS

DGE_RESULTS_DIR = os.path.join(DGE_RESULTS_DIR,"biomarkers")
GO_OUTPUT_DIR = os.path.join(DGE_RESULTS_DIR, 'go_enrichment')
GENE_SETS = ['GO_Biological_Process_2023', 'GO_Cellular_Component_2023', 'GO_Molecular_Function_2023']

N_TOP_TERMS_PLOT = 10
GO_PADJ_THRESHOLD = 0.05

# --- End Configuration ---

# Create base output directory if it doesn't exist
GO_OUTPUT_DIR = pathlib.Path(GO_OUTPUT_DIR)
GO_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
print(f"DGE results input directory: {DGE_RESULTS_DIR}")
print(f"GO results output directory: {GO_OUTPUT_DIR}")
print(f"Organism: {ORGANISM}")
print(f"Gene sets: {GENE_SETS}")
# Out:
# DGE results input directory: D:/Github/SRF_Linda_RNA/combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers
# GO results output directory: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment
# Organism: Mouse
# Gene sets: ['GO_Biological_Process_2023', 'GO_Cellular_Component_2023', 'GO_Molecular_Function_2023']

# %%
# Check available gene sets for the organism
try:
    print(f"Checking available Enrichr libraries for organism: {ORGANISM}...")
    available_sets = gp.get_library_name(organism=ORGANISM)
    print(f"Found {len(available_sets)} libraries.")
    # You can optionally print all available_sets if needed for debugging:
    # print(available_sets) 
    for gs in GENE_SETS:
        if gs not in available_sets:
            print(f"WARNING: Specified gene set '{gs}' not found in available Enrichr libraries for {ORGANISM}!")
except Exception as e:
    print(f"Could not retrieve available gene sets from Enrichr: {e}")
# Out:
# Checking available Enrichr libraries for organism: Mouse...
# Found 216 libraries.

# %%
# Load the AnnData object to get the full list of genes (gene universe)
print(f"Loading AnnData from {ADATA_PATH} to get gene universe...")
try:
    adata = sc.read_h5ad(ADATA_PATH)
    print(adata)
    gene_universe = adata.var_names.tolist()
    print(f"Using {len(gene_universe)} genes as the background universe.")
    del adata
except FileNotFoundError:
    print(f"Error: AnnData file not found at {ADATA_PATH}. Cannot determine gene universe.")
    sys.exit(1)
except Exception as e:
    print(f"Error loading AnnData file: {e}")
    sys.exit(1)
# Out:
# Loading AnnData from D:/Github/SRF_Linda_RNA/combine_data\results_from_raw\annotation_final.h5ad to get gene universe...
# AnnData object with n_obs × n_vars = 28026 × 26870
#     obs: 'sample', 'condition', 'genotype', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden_0.4', 'ISO_majority_voting', 'ISO_conf_score', 'DG_majority_voting', 'DG_conf_score', 'mapmycells_first_layer', 'mapmycells_second_layer', 'cell_type_L1', 'cell_type_L2', 'highlight'
#     var: 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'mean', 'std'
#     uns: 'DG_majority_voting_colors', 'ISO_majority_voting_colors', 'cell_type_L1_colors', 'cell_type_L2_colors', 'condition_colors', 'genotype_colors', 'highlight_colors', 'hvg', 'leiden_0.4', 'leiden_0.4_colors', 'log1p', 'neighbors', 'pca', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# Using 26870 genes as the background universe.

# %%
# Find all significant DEG list files recursively
deg_list_files = list(pathlib.Path(DGE_RESULTS_DIR).rglob('*_significant.csv'))
print(f"Found {len(deg_list_files)} significant DEG list files to process.")

if not deg_list_files:
    print(f"Error: No significant DEG list files found matching '*_significant.csv' within {DGE_RESULTS_DIR}")
    sys.exit(1)
# Out:
# Found 66 significant DEG list files to process.

# %%
# Process each DEG list file
for deg_file_path in deg_list_files:
    print(f"\n--- Processing {deg_file_path.name} ---")
    print(f"Full path: {deg_file_path}")

    try:
        # --- Parse file path to get context ---
        parts = deg_file_path.parts
        # Find the index of the 'biomarkers' directory within the path
        try:
            # Find the index of DEG_BY first
            base_index = parts.index(DEGs_folder)
            # Check if 'biomarkers' is the next part
            if base_index + 1 < len(parts) and parts[base_index + 1] == 'biomarkers':
                biomarkers_index = base_index + 1
            else:
                print(f"Warning: Could not find 'biomarkers' directory after f'{DEGs_folder}' in path {deg_file_path}. Skipping.")
                continue
        except ValueError:
            print(f"Warning: Could not find f'{DEGs_folder}' in path {deg_file_path}. Skipping.")
            continue

        # Check for 'sig_deg_lists' after 'biomarkers'
        if biomarkers_index + 1 >= len(parts) or parts[biomarkers_index + 1] != 'sig_deg_lists':
            print(f"Warning: Expected 'sig_deg_lists' directory after 'biomarkers' not found in path {deg_file_path}. Skipping.")
            continue

        # Extract context based on the biomarker structure
        # Example path: .../*/biomarkers/sig_deg_lists/Astro/Cluster_Astro_vs_Rest_up_significant.csv
        context_start_index = biomarkers_index + 2 # Start after 'sig_deg_lists'
        sub_path_parts = parts[context_start_index:] # Parts after sig_deg_lists

        # Expected structure: <cell_type>/<filename> -> 2 parts minimum
        if len(sub_path_parts) < 2:
            print(f"Warning: Unexpected path structure after 'sig_deg_lists' for {deg_file_path}. Parts: {sub_path_parts}. Skipping.")
            continue

        analysis_type = 'biomarkers' # This is specifically for biomarkers
        cell_type_name = sub_path_parts[0] # The directory name is the cell type
        comparison_details = 'Marker Genes' # Implicitly marker genes

        filename = deg_file_path.name
        direction = 'up' if '_up_' in filename else 'down' if '_down_' in filename else 'unknown'
        # Extract comparison name from filename (e.g., Cluster_Astro_vs_Rest)
        comparison_name = filename.replace(f'_{direction}_significant.csv', '')

        # Basic validation for extracted cell_type_name
        if not cell_type_name:
            print(f"Warning: Could not extract cell type name for {deg_file_path}. Skipping.")
            continue

        print(f"  Context: Type={analysis_type}, Details={comparison_details or 'N/A'}, CellType={cell_type_name}, Comparison={comparison_name}, Direction={direction}")

        # --- Read DEG list ---
        df = pd.read_csv(deg_file_path)
        print(f"  Read {len(df)} genes from {deg_file_path.name}")

        if 'names' not in df.columns:
            print(f"  Error: 'names' column not found in {deg_file_path.name}. Skipping.")
            continue

        gene_list = df['names'].dropna().astype(str).tolist()

        if not gene_list:
            print("  Gene list is empty. Skipping enrichment analysis.")
            continue

        # --- Prepare Output ---
        # Create specific output directory for this result
        # Structure: GO_OUTPUT_DIR / <sanitized_cell_type> / ...
        sanitized_cell_type = cell_type_name.replace('/', '_') # Sanitize cell type name for path
        specific_go_output_dir = pathlib.Path(os.path.join(GO_OUTPUT_DIR, sanitized_cell_type))

        specific_go_output_dir.mkdir(parents=True, exist_ok=True)

        # Define output file names (using sanitized cell_type_name)
        output_file_base = f"{comparison_name}_{direction}" # Keep original comparison name here
        excel_output = os.path.join(specific_go_output_dir, f"{output_file_base}_go_enrichment.xlsx")
        
        # Define visualization output files - only keep bubble plots and dotplots
        dotplot_output_file = os.path.join(specific_go_output_dir, f"{output_file_base}_go_enrichment_dotplot.png")
        
        # Construct a more informative title for biomarkers
        plot_title = f"GO Enrichment: {sanitized_cell_type} Biomarkers\n{comparison_name} ({direction.upper()})"

        # --- Run Enrichment ---
        print(f"  Running GO enrichment for {len(gene_list)} genes...")
        try:
            enr = gp.enrichr(gene_list=gene_list,
                             gene_sets=GENE_SETS,
                             organism=ORGANISM,
                             background=gene_universe, # Provide the background gene list
                             outdir=None, # Prevent gseapy from creating its own directory structure
                             cutoff=0.1, # Use a slightly less stringent cutoff for enrichr, filter later
                             verbose=False)
        except Exception as enrich_err:
             print(f"  Error during gseapy.enrichr execution: {enrich_err}")
             continue # Skip to next file if enrichment fails

        # --- Process and Save Results ---
        if enr and hasattr(enr, 'results') and isinstance(enr.results, pd.DataFrame) and not enr.results.empty:
            print("Filtering and saving enrichment results...")
            # Filter results based on adjusted p-value
            filtered_results = enr.results[enr.results['Adjusted P-value'] < GO_PADJ_THRESHOLD].copy() # Use .copy()

            if not filtered_results.empty:
                 print(f"  Found {len(filtered_results)} significant terms (Adj P < {GO_PADJ_THRESHOLD}).")
                 # Calculate gene count from 'Genes' column for size mapping
                 if 'Genes' in filtered_results.columns:
                     # Ensure robust splitting even if genes are missing or format varies
                     filtered_results['Gene_Count'] = filtered_results['Genes'].apply(
                         lambda x: len(str(x).split(';')) if pd.notna(x) and str(x) else 0
                     )
                     # Immediately convert to float to ensure numeric type from the start
                     filtered_results['Gene_Count'] = pd.to_numeric(filtered_results['Gene_Count'], errors='coerce').fillna(1.0)
                 else:
                     print("  Warning: 'Genes' column not found. Using default size.")
                     filtered_results['Gene_Count'] = 1.0  # Assign a default size as float

                 # Save filtered results to Excel
                 try:
                     filtered_results.to_excel(excel_output, index=False)
                     print(f"  Saved significant results to {excel_output}")
                 except Exception as excel_err:
                     print(f"  Error saving Excel file: {excel_err}")


                 # Generate visualizations for top terms
                 try:
                     # Sort by Adj P-value for plotting top terms
                     plot_data = filtered_results.sort_values("Adjusted P-value").head(N_TOP_TERMS_PLOT * len(GENE_SETS)).copy() # Use .copy()

                     if not plot_data.empty:
                         # Ensure relevant columns are numeric before plotting
                         for col in ['P-value', 'Adjusted P-value', 'Odds Ratio', 'Combined Score', 'Gene_Count']:
                             if col in plot_data.columns:
                                 plot_data[col] = pd.to_numeric(plot_data[col], errors='coerce')
                         
                         # Drop rows where conversion failed (NaN values)
                         plot_data.dropna(subset=['Adjusted P-value'], inplace=True)

                         if not plot_data.empty:
                             print("  Data types before plotting:")
                             print(plot_data.dtypes)
                             print(f"  Generating visualizations for {len(plot_data)} enriched terms...")
                             
                             # 1. Create a dotplot (similar to second example)
                             try:
                                 print(f"  Creating dotplot visualization: {dotplot_output_file}")
                                 
                                 # Get top terms across all categories (most significant)
                                 top_overall = plot_data.sort_values('Adjusted P-value').head(15)
                                 
                                 if not top_overall.empty:
                                     # Process the terms
                                     top_overall['Clean_Term'] = top_overall['Term'].str.replace(r' \(GO:[0-9]+\)', '', regex=True)
                                     top_overall['Clean_Term'] = top_overall['Clean_Term'].str.replace('_', ' ')
                                     
                                     # Calculate gene ratio for x-axis
                                     top_overall['GeneRatio'] = top_overall['Gene_Count'] / top_overall['Gene_Count'].max()
                                     
                                     # Sort by p-value for intuitive display
                                     top_overall = top_overall.sort_values('Adjusted P-value', ascending=False)
                                     
                                     # Plot
                                     plt.figure(figsize=(10, max(6, len(top_overall) * 0.4))) # Dynamic height
                                     
                                     # Create a scatter plot with constant dot size
                                     scatter = plt.scatter(
                                         top_overall['GeneRatio'],
                                         top_overall['Clean_Term'],
                                         s=100,  # Constant dot size
                                         c=-np.log10(top_overall['Adjusted P-value']),  # Color by p-value
                                         cmap='Reds',  # Red colormap
                                         alpha=0.8
                                     )
                                     
                                     # Add gene count text next to each dot
                                     for idx, row in top_overall.iterrows():
                                         plt.text(row['GeneRatio'] + 0.02, row['Clean_Term'], 
                                                 f"({int(row['Gene_Count'])})", 
                                                 va='center', ha='left', fontsize=9)
                                     
                                     # Customize
                                     plt.xlabel('GeneRatio')
                                     plt.ylabel('')
                                     plt.title(f"{plot_title}\nTop GO Terms")
                                     plt.grid(True, alpha=0.3, axis='x')
                                     
                                     # Add colorbar
                                     cbar = plt.colorbar(scatter)
                                     cbar.set_label('-log10(Adj. P-value)') # Updated label
                                     
                                     plt.tight_layout()
                                     plt.savefig(dotplot_output_file, dpi=150, bbox_inches='tight')
                                     plt.close()
                                     
                                     print(f"  Dotplot saved to {dotplot_output_file}")
                             except Exception as dotplot_err:
                                 print(f"  Error generating dotplot: {dotplot_err}")
                         else:
                             print("  No significant terms left after filtering for visualization.")
                     else:
                         print("  No significant terms left after filtering for visualization.")
                 except Exception as viz_err:
                     print(f"  Warning: Could not generate visualizations. Error: {viz_err}")
            else:
                print(f"  No significantly enriched terms found after filtering (Adj P < {GO_PADJ_THRESHOLD}). No Excel file or visualizations saved.")
        else:
             print("  Enrichment analysis did not return results or results table was empty.")
    except FileNotFoundError:
        print(f"Error: DEG list file not found (should not happen with glob): {deg_file_path}")
    except pd.errors.EmptyDataError:
        print(f"Error: DEG list file is empty: {deg_file_path.name}")
    except KeyError as e:
        print(f"Error: Missing expected column in {deg_file_path.name}: {e}. Ensure 'names' column exists.")
    except Exception as e:
        print(f"An unexpected error occurred processing {deg_file_path.name}: {e}")
        import traceback
        traceback.print_exc() # Print detailed traceback for debugging

print("\nGO enrichment analysis for DEG lists complete.")
print(f"Results saved in subdirectories under: {GO_OUTPUT_DIR}")
# Out:
# --- Processing Cluster_ABC_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\ABC\Cluster_ABC_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=ABC, Comparison=Cluster_ABC_vs_Rest, Direction=down
#   Read 1428 genes from Cluster_ABC_vs_Rest_down_significant.csv
#   Running GO enrichment for 1428 genes...
# Filtering and saving enrichment results...
#   Found 698 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\ABC\Cluster_ABC_vs_Rest_down_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\ABC\Cluster_ABC_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\ABC\Cluster_ABC_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_ABC_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\ABC\Cluster_ABC_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=ABC, Comparison=Cluster_ABC_vs_Rest, Direction=up
#   Read 782 genes from Cluster_ABC_vs_Rest_up_significant.csv
#   Running GO enrichment for 782 genes...
# Filtering and saving enrichment results...
#   Found 670 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\ABC\Cluster_ABC_vs_Rest_up_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\ABC\Cluster_ABC_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\ABC\Cluster_ABC_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_Astrocytes_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Astrocytes\Cluster_Astrocytes_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Astrocytes, Comparison=Cluster_Astrocytes_vs_Rest, Direction=down
#   Read 6572 genes from Cluster_Astrocytes_vs_Rest_down_significant.csv
#   Running GO enrichment for 6572 genes...
# Filtering and saving enrichment results...
#   Found 1240 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Astrocytes\Cluster_Astrocytes_vs_Rest_down_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Astrocytes\Cluster_Astrocytes_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Astrocytes\Cluster_Astrocytes_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_Astrocytes_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Astrocytes\Cluster_Astrocytes_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Astrocytes, Comparison=Cluster_Astrocytes_vs_Rest, Direction=up
#   Read 1425 genes from Cluster_Astrocytes_vs_Rest_up_significant.csv
#   Running GO enrichment for 1425 genes...
# Filtering and saving enrichment results...
#   Found 621 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Astrocytes\Cluster_Astrocytes_vs_Rest_up_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Astrocytes\Cluster_Astrocytes_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Astrocytes\Cluster_Astrocytes_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_CA1_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\CA1\Cluster_CA1_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=CA1, Comparison=Cluster_CA1_vs_Rest, Direction=down
#   Read 1360 genes from Cluster_CA1_vs_Rest_down_significant.csv
#   Running GO enrichment for 1360 genes...
# Filtering and saving enrichment results...
#   Found 798 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\CA1\Cluster_CA1_vs_Rest_down_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\CA1\Cluster_CA1_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\CA1\Cluster_CA1_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_CA1_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\CA1\Cluster_CA1_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=CA1, Comparison=Cluster_CA1_vs_Rest, Direction=up
#   Read 3091 genes from Cluster_CA1_vs_Rest_up_significant.csv
#   Running GO enrichment for 3091 genes...
# Filtering and saving enrichment results...
#   Found 544 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\CA1\Cluster_CA1_vs_Rest_up_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\CA1\Cluster_CA1_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\CA1\Cluster_CA1_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_CA2_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\CA2\Cluster_CA2_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=CA2, Comparison=Cluster_CA2_vs_Rest, Direction=down
#   Read 377 genes from Cluster_CA2_vs_Rest_down_significant.csv
#   Running GO enrichment for 377 genes...
# Filtering and saving enrichment results...
#   Found 327 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\CA2\Cluster_CA2_vs_Rest_down_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\CA2\Cluster_CA2_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\CA2\Cluster_CA2_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_CA2_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\CA2\Cluster_CA2_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=CA2, Comparison=Cluster_CA2_vs_Rest, Direction=up
#   Read 2475 genes from Cluster_CA2_vs_Rest_up_significant.csv
#   Running GO enrichment for 2475 genes...
#   Error during gseapy.enrichr execution: HTTPSConnectionPool(host='maayanlab.cloud', port=443): Max retries exceeded with url: /speedrichr/api/backgroundenrich (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000029418839210>, 'Connection to maayanlab.cloud timed out. (connect timeout=None)'))
#
# --- Processing Cluster_CA3_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\CA3\Cluster_CA3_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=CA3, Comparison=Cluster_CA3_vs_Rest, Direction=down
#   Read 935 genes from Cluster_CA3_vs_Rest_down_significant.csv
#   Running GO enrichment for 935 genes...
# Filtering and saving enrichment results...
#   Found 456 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\CA3\Cluster_CA3_vs_Rest_down_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\CA3\Cluster_CA3_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\CA3\Cluster_CA3_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_CA3_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\CA3\Cluster_CA3_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=CA3, Comparison=Cluster_CA3_vs_Rest, Direction=up
#   Read 5390 genes from Cluster_CA3_vs_Rest_up_significant.csv
#   Running GO enrichment for 5390 genes...
# Filtering and saving enrichment results...
#   Found 836 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\CA3\Cluster_CA3_vs_Rest_up_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\CA3\Cluster_CA3_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\CA3\Cluster_CA3_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_Cajal-Retzius_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Cajal-Retzius\Cluster_Cajal-Retzius_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Cajal-Retzius, Comparison=Cluster_Cajal-Retzius_vs_Rest, Direction=down
#   Read 2329 genes from Cluster_Cajal-Retzius_vs_Rest_down_significant.csv
#   Running GO enrichment for 2329 genes...
# Filtering and saving enrichment results...
#   Found 876 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Cajal-Retzius\Cluster_Cajal-Retzius_vs_Rest_down_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Cajal-Retzius\Cluster_Cajal-Retzius_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Cajal-Retzius\Cluster_Cajal-Retzius_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_Cajal-Retzius_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Cajal-Retzius\Cluster_Cajal-Retzius_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Cajal-Retzius, Comparison=Cluster_Cajal-Retzius_vs_Rest, Direction=up
#   Read 195 genes from Cluster_Cajal-Retzius_vs_Rest_up_significant.csv
#   Running GO enrichment for 195 genes...
# Filtering and saving enrichment results...
#   Found 146 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Cajal-Retzius\Cluster_Cajal-Retzius_vs_Rest_up_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Cajal-Retzius\Cluster_Cajal-Retzius_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Cajal-Retzius\Cluster_Cajal-Retzius_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_Car3_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Car3\Cluster_Car3_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Car3, Comparison=Cluster_Car3_vs_Rest, Direction=down
#   Read 113 genes from Cluster_Car3_vs_Rest_down_significant.csv
#   Running GO enrichment for 113 genes...
# Filtering and saving enrichment results...
#   Found 121 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Car3\Cluster_Car3_vs_Rest_down_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Car3\Cluster_Car3_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Car3\Cluster_Car3_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_Car3_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Car3\Cluster_Car3_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Car3, Comparison=Cluster_Car3_vs_Rest, Direction=up
#   Read 1073 genes from Cluster_Car3_vs_Rest_up_significant.csv
#   Running GO enrichment for 1073 genes...
# Filtering and saving enrichment results...
#   Found 456 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Car3\Cluster_Car3_vs_Rest_up_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Car3\Cluster_Car3_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Car3\Cluster_Car3_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_CGE-derived_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\CGE-derived\Cluster_CGE-derived_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=CGE-derived, Comparison=Cluster_CGE-derived_vs_Rest, Direction=down
#   Read 786 genes from Cluster_CGE-derived_vs_Rest_down_significant.csv
#   Running GO enrichment for 786 genes...
# Filtering and saving enrichment results...
#   Found 492 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\CGE-derived\Cluster_CGE-derived_vs_Rest_down_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\CGE-derived\Cluster_CGE-derived_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\CGE-derived\Cluster_CGE-derived_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_CGE-derived_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\CGE-derived\Cluster_CGE-derived_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=CGE-derived, Comparison=Cluster_CGE-derived_vs_Rest, Direction=up
#   Read 8082 genes from Cluster_CGE-derived_vs_Rest_up_significant.csv
#   Running GO enrichment for 8082 genes...
# Filtering and saving enrichment results...
#   Found 1276 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\CGE-derived\Cluster_CGE-derived_vs_Rest_up_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\CGE-derived\Cluster_CGE-derived_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\CGE-derived\Cluster_CGE-derived_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_Endothelial_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Endothelial\Cluster_Endothelial_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Endothelial, Comparison=Cluster_Endothelial_vs_Rest, Direction=down
#   Read 4112 genes from Cluster_Endothelial_vs_Rest_down_significant.csv
#   Running GO enrichment for 4112 genes...
# Filtering and saving enrichment results...
#   Found 992 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Endothelial\Cluster_Endothelial_vs_Rest_down_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Endothelial\Cluster_Endothelial_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Endothelial\Cluster_Endothelial_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_Endothelial_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Endothelial\Cluster_Endothelial_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Endothelial, Comparison=Cluster_Endothelial_vs_Rest, Direction=up
#   Read 947 genes from Cluster_Endothelial_vs_Rest_up_significant.csv
#   Running GO enrichment for 947 genes...
# Filtering and saving enrichment results...
#   Found 897 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Endothelial\Cluster_Endothelial_vs_Rest_up_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Endothelial\Cluster_Endothelial_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Endothelial\Cluster_Endothelial_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_ENT_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\ENT\Cluster_ENT_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=ENT, Comparison=Cluster_ENT_vs_Rest, Direction=down
#   Read 1726 genes from Cluster_ENT_vs_Rest_down_significant.csv
#   Running GO enrichment for 1726 genes...
# Filtering and saving enrichment results...
#   Found 460 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\ENT\Cluster_ENT_vs_Rest_down_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\ENT\Cluster_ENT_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\ENT\Cluster_ENT_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_ENT_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\ENT\Cluster_ENT_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=ENT, Comparison=Cluster_ENT_vs_Rest, Direction=up
#   Read 8899 genes from Cluster_ENT_vs_Rest_up_significant.csv
#   Running GO enrichment for 8899 genes...
# Filtering and saving enrichment results...
#   Found 816 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\ENT\Cluster_ENT_vs_Rest_up_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\ENT\Cluster_ENT_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\ENT\Cluster_ENT_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_Immature GC_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Immature_GC\Cluster_Immature GC_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Immature_GC, Comparison=Cluster_Immature GC_vs_Rest, Direction=down
#   Read 491 genes from Cluster_Immature GC_vs_Rest_down_significant.csv
#   Running GO enrichment for 491 genes...
# Filtering and saving enrichment results...
#   Found 203 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Immature_GC\Cluster_Immature GC_vs_Rest_down_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Immature_GC\Cluster_Immature GC_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Immature_GC\Cluster_Immature GC_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_Immature GC_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Immature_GC\Cluster_Immature GC_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Immature_GC, Comparison=Cluster_Immature GC_vs_Rest, Direction=up
#   Read 4296 genes from Cluster_Immature GC_vs_Rest_up_significant.csv
#   Running GO enrichment for 4296 genes...
# Filtering and saving enrichment results...
#   Found 1715 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Immature_GC\Cluster_Immature GC_vs_Rest_up_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Immature_GC\Cluster_Immature GC_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Immature_GC\Cluster_Immature GC_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_Lamp5_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Lamp5\Cluster_Lamp5_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Lamp5, Comparison=Cluster_Lamp5_vs_Rest, Direction=down
#   Read 907 genes from Cluster_Lamp5_vs_Rest_down_significant.csv
#   Running GO enrichment for 907 genes...
# Filtering and saving enrichment results...
#   Found 572 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Lamp5\Cluster_Lamp5_vs_Rest_down_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Lamp5\Cluster_Lamp5_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Lamp5\Cluster_Lamp5_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_Lamp5_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Lamp5\Cluster_Lamp5_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Lamp5, Comparison=Cluster_Lamp5_vs_Rest, Direction=up
#   Read 1672 genes from Cluster_Lamp5_vs_Rest_up_significant.csv
#   Running GO enrichment for 1672 genes...
# Filtering and saving enrichment results...
#   Found 573 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Lamp5\Cluster_Lamp5_vs_Rest_up_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Lamp5\Cluster_Lamp5_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Lamp5\Cluster_Lamp5_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_Lamp5 (DG)_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Lamp5_DG\Cluster_Lamp5 (DG)_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Lamp5_DG, Comparison=Cluster_Lamp5 (DG)_vs_Rest, Direction=down
#   Read 7 genes from Cluster_Lamp5 (DG)_vs_Rest_down_significant.csv
#   Running GO enrichment for 7 genes...
# Filtering and saving enrichment results...
#   Found 43 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Lamp5_DG\Cluster_Lamp5 (DG)_vs_Rest_down_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Lamp5_DG\Cluster_Lamp5 (DG)_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Lamp5_DG\Cluster_Lamp5 (DG)_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_Lamp5 (DG)_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Lamp5_DG\Cluster_Lamp5 (DG)_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Lamp5_DG, Comparison=Cluster_Lamp5 (DG)_vs_Rest, Direction=up
#   Read 4896 genes from Cluster_Lamp5 (DG)_vs_Rest_up_significant.csv
#   Running GO enrichment for 4896 genes...
# Filtering and saving enrichment results...
#   Found 1179 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Lamp5_DG\Cluster_Lamp5 (DG)_vs_Rest_up_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Lamp5_DG\Cluster_Lamp5 (DG)_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Lamp5_DG\Cluster_Lamp5 (DG)_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_Mature GC_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Mature_GC\Cluster_Mature GC_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Mature_GC, Comparison=Cluster_Mature GC_vs_Rest, Direction=down
#   Read 2941 genes from Cluster_Mature GC_vs_Rest_down_significant.csv
#   Running GO enrichment for 2941 genes...
# Filtering and saving enrichment results...
#   Found 817 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Mature_GC\Cluster_Mature GC_vs_Rest_down_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Mature_GC\Cluster_Mature GC_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Mature_GC\Cluster_Mature GC_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_Mature GC_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Mature_GC\Cluster_Mature GC_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Mature_GC, Comparison=Cluster_Mature GC_vs_Rest, Direction=up
#   Read 2702 genes from Cluster_Mature GC_vs_Rest_up_significant.csv
#   Running GO enrichment for 2702 genes...
# Filtering and saving enrichment results...
#   Found 979 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Mature_GC\Cluster_Mature GC_vs_Rest_up_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Mature_GC\Cluster_Mature GC_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Mature_GC\Cluster_Mature GC_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_MGE-derived_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\MGE-derived\Cluster_MGE-derived_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=MGE-derived, Comparison=Cluster_MGE-derived_vs_Rest, Direction=down
#   Read 321 genes from Cluster_MGE-derived_vs_Rest_down_significant.csv
#   Running GO enrichment for 321 genes...
# Filtering and saving enrichment results...
#   Found 327 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\MGE-derived\Cluster_MGE-derived_vs_Rest_down_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\MGE-derived\Cluster_MGE-derived_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\MGE-derived\Cluster_MGE-derived_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_MGE-derived_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\MGE-derived\Cluster_MGE-derived_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=MGE-derived, Comparison=Cluster_MGE-derived_vs_Rest, Direction=up
#   Read 7052 genes from Cluster_MGE-derived_vs_Rest_up_significant.csv
#   Running GO enrichment for 7052 genes...
# Filtering and saving enrichment results...
#   Found 1270 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\MGE-derived\Cluster_MGE-derived_vs_Rest_up_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\MGE-derived\Cluster_MGE-derived_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\MGE-derived\Cluster_MGE-derived_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_Microglia_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Microglia\Cluster_Microglia_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Microglia, Comparison=Cluster_Microglia_vs_Rest, Direction=down
#   Read 9025 genes from Cluster_Microglia_vs_Rest_down_significant.csv
#   Running GO enrichment for 9025 genes...
# Filtering and saving enrichment results...
#   Found 1546 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Microglia\Cluster_Microglia_vs_Rest_down_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Microglia\Cluster_Microglia_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Microglia\Cluster_Microglia_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_Microglia_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Microglia\Cluster_Microglia_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Microglia, Comparison=Cluster_Microglia_vs_Rest, Direction=up
#   Read 1384 genes from Cluster_Microglia_vs_Rest_up_significant.csv
#   Running GO enrichment for 1384 genes...
# Filtering and saving enrichment results...
#   Found 1064 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Microglia\Cluster_Microglia_vs_Rest_up_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# ...
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\SST\Cluster_SST_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\SST\Cluster_SST_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_Subiculum_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Subiculum\Cluster_Subiculum_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Subiculum, Comparison=Cluster_Subiculum_vs_Rest, Direction=down
#   Read 730 genes from Cluster_Subiculum_vs_Rest_down_significant.csv
#   Running GO enrichment for 730 genes...
# Filtering and saving enrichment results...
#   Found 460 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Subiculum\Cluster_Subiculum_vs_Rest_down_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Subiculum\Cluster_Subiculum_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Subiculum\Cluster_Subiculum_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_Subiculum_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Subiculum\Cluster_Subiculum_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Subiculum, Comparison=Cluster_Subiculum_vs_Rest, Direction=up
#   Read 2109 genes from Cluster_Subiculum_vs_Rest_up_significant.csv
#   Running GO enrichment for 2109 genes...
# Filtering and saving enrichment results...
#   Found 609 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Subiculum\Cluster_Subiculum_vs_Rest_up_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Subiculum\Cluster_Subiculum_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Subiculum\Cluster_Subiculum_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_Unknown_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Unknown\Cluster_Unknown_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Unknown, Comparison=Cluster_Unknown_vs_Rest, Direction=down
#   Read 11128 genes from Cluster_Unknown_vs_Rest_down_significant.csv
#   Running GO enrichment for 11128 genes...
# Filtering and saving enrichment results...
#   Found 1752 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Unknown\Cluster_Unknown_vs_Rest_down_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Unknown\Cluster_Unknown_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Unknown\Cluster_Unknown_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_Unknown_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\Unknown\Cluster_Unknown_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Unknown, Comparison=Cluster_Unknown_vs_Rest, Direction=up
#   Read 1475 genes from Cluster_Unknown_vs_Rest_up_significant.csv
#   Running GO enrichment for 1475 genes...
# Filtering and saving enrichment results...
#   Found 636 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Unknown\Cluster_Unknown_vs_Rest_up_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Unknown\Cluster_Unknown_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\Unknown\Cluster_Unknown_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_VIP_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\VIP\Cluster_VIP_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=VIP, Comparison=Cluster_VIP_vs_Rest, Direction=down
#   Read 2395 genes from Cluster_VIP_vs_Rest_down_significant.csv
#   Running GO enrichment for 2395 genes...
# Filtering and saving enrichment results...
#   Found 857 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\VIP\Cluster_VIP_vs_Rest_down_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\VIP\Cluster_VIP_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\VIP\Cluster_VIP_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_VIP_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\VIP\Cluster_VIP_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=VIP, Comparison=Cluster_VIP_vs_Rest, Direction=up
#   Read 622 genes from Cluster_VIP_vs_Rest_up_significant.csv
#   Running GO enrichment for 622 genes...
# Filtering and saving enrichment results...
#   Found 290 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\VIP\Cluster_VIP_vs_Rest_up_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\VIP\Cluster_VIP_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\VIP\Cluster_VIP_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_VIP (DG)_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\VIP_DG\Cluster_VIP (DG)_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=VIP_DG, Comparison=Cluster_VIP (DG)_vs_Rest, Direction=down
#   Read 6 genes from Cluster_VIP (DG)_vs_Rest_down_significant.csv
#   Running GO enrichment for 6 genes...
# Filtering and saving enrichment results...
#   Found 258 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\VIP_DG\Cluster_VIP (DG)_vs_Rest_down_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\VIP_DG\Cluster_VIP (DG)_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\VIP_DG\Cluster_VIP (DG)_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_VIP (DG)_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\VIP_DG\Cluster_VIP (DG)_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=VIP_DG, Comparison=Cluster_VIP (DG)_vs_Rest, Direction=up
#   Read 4356 genes from Cluster_VIP (DG)_vs_Rest_up_significant.csv
#   Running GO enrichment for 4356 genes...
# Filtering and saving enrichment results...
#   Found 1185 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\VIP_DG\Cluster_VIP (DG)_vs_Rest_up_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\VIP_DG\Cluster_VIP (DG)_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\VIP_DG\Cluster_VIP (DG)_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_VLMC_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\VLMC\Cluster_VLMC_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=VLMC, Comparison=Cluster_VLMC_vs_Rest, Direction=down
#   Read 3799 genes from Cluster_VLMC_vs_Rest_down_significant.csv
#   Running GO enrichment for 3799 genes...
# Filtering and saving enrichment results...
#   Found 958 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\VLMC\Cluster_VLMC_vs_Rest_down_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\VLMC\Cluster_VLMC_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\VLMC\Cluster_VLMC_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_VLMC_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\sig_deg_lists\VLMC\Cluster_VLMC_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=VLMC, Comparison=Cluster_VLMC_vs_Rest, Direction=up
#   Read 509 genes from Cluster_VLMC_vs_Rest_up_significant.csv
#   Running GO enrichment for 509 genes...
# Filtering and saving enrichment results...
#   Found 652 significant terms (Adj P < 0.05).
#   Saved significant results to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\VLMC\Cluster_VLMC_vs_Rest_up_go_enrichment.xlsx
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\VLMC\Cluster_VLMC_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment\VLMC\Cluster_VLMC_vs_Rest_up_go_enrichment_dotplot.png
#
# GO enrichment analysis for DEG lists complete.
# Results saved in subdirectories under: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_cell_type_L2FC_0_25\biomarkers\go_enrichment
