# %%
import scanpy as sc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import sys
import pathlib
import gseapy as gp

# --- Configuration ---
PROJECT_DIR = "D:/Github/SRF_Linda_RNA"
WORKING_DIR = f"{PROJECT_DIR}/combine_data"
os.chdir(WORKING_DIR)
sys.path.insert(0, WORKING_DIR)

ORGANISM = 'Mouse'

# Set up directories
# REMOVE_DOUBLETS = True
REMOVE_DOUBLETS = False

FIX_TRESHOLD = True
# FIX_TRESHOLD = False

if FIX_TRESHOLD:
    BASE_RESULTS_DIR = os.path.join(WORKING_DIR, "results_from_raw")
else:
    if REMOVE_DOUBLETS:
        BASE_RESULTS_DIR = os.path.join(WORKING_DIR, "results_from_raw_percentile_threshold", "doublets_removed")
    else:
        BASE_RESULTS_DIR = os.path.join(WORKING_DIR, "results_from_raw_percentile_threshold")

INPUT_DIR = BASE_RESULTS_DIR
ADATA_PATH = os.path.join(INPUT_DIR, "annotation_final.h5ad")

DGE_RESULTS_DIR = os.path.join(INPUT_DIR,"DEGs_mapmycells_L2")

# CUSTOM_ANALYSIS =  None
CUSTOM_ANALYSIS =  "FC_0_25"

DEG_BY = "mapmycells_second_layer"
DEGs_folder = "DEGs_mapmycells_L2FC_0_25"

if CUSTOM_ANALYSIS is not None:
    DGE_RESULTS_DIR = DGE_RESULTS_DIR + CUSTOM_ANALYSIS

DGE_RESULTS_DIR = os.path.join(DGE_RESULTS_DIR,"biomarkers")
GO_OUTPUT_DIR = os.path.join(DGE_RESULTS_DIR, 'go_enrichment')
GENE_SETS = ['GO_Biological_Process_2023', 'GO_Cellular_Component_2023', 'GO_Molecular_Function_2023']

N_TOP_TERMS_PLOT = 10
GO_PADJ_THRESHOLD = 0.05

# --- End Configuration ---

# Create base output directory if it doesn't exist
GO_OUTPUT_DIR = pathlib.Path(GO_OUTPUT_DIR)
GO_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
print(f"DGE results input directory: {DGE_RESULTS_DIR}")
print(f"GO results output directory: {GO_OUTPUT_DIR}")
print(f"Organism: {ORGANISM}")
print(f"Gene sets: {GENE_SETS}")
# Out:
# DGE results input directory: D:/Github/SRF_Linda_RNA/combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers
# GO results output directory: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment
# Organism: Mouse
# Gene sets: ['GO_Biological_Process_2023', 'GO_Cellular_Component_2023', 'GO_Molecular_Function_2023']

# %%
# Check available gene sets for the organism
try:
    print(f"Checking available Enrichr libraries for organism: {ORGANISM}...")
    available_sets = gp.get_library_name(organism=ORGANISM)
    print(f"Found {len(available_sets)} libraries.")
    # You can optionally print all available_sets if needed for debugging:
    # print(available_sets) 
    for gs in GENE_SETS:
        if gs not in available_sets:
            print(f"WARNING: Specified gene set '{gs}' not found in available Enrichr libraries for {ORGANISM}!")
except Exception as e:
    print(f"Could not retrieve available gene sets from Enrichr: {e}")
# Out:
# Checking available Enrichr libraries for organism: Mouse...
# Found 216 libraries.

# %%
# Load the AnnData object to get the full list of genes (gene universe)
print(f"Loading AnnData from {ADATA_PATH} to get gene universe...")
try:
    adata = sc.read_h5ad(ADATA_PATH)
    print(adata)
    gene_universe = adata.var_names.tolist()
    print(f"Using {len(gene_universe)} genes as the background universe.")
    del adata
except FileNotFoundError:
    print(f"Error: AnnData file not found at {ADATA_PATH}. Cannot determine gene universe.")
    sys.exit(1)
except Exception as e:
    print(f"Error loading AnnData file: {e}")
    sys.exit(1)
# Out:
# Loading AnnData from D:/Github/SRF_Linda_RNA/combine_data\results_from_raw\annotation_final.h5ad to get gene universe...
# AnnData object with n_obs × n_vars = 28026 × 26870
#     obs: 'sample', 'condition', 'genotype', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden_0.4', 'ISO_majority_voting', 'ISO_conf_score', 'DG_majority_voting', 'DG_conf_score', 'mapmycells_first_layer', 'mapmycells_second_layer', 'cell_type', 'highlight'
#     var: 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'mean', 'std'
#     uns: 'DG_majority_voting_colors', 'ISO_majority_voting_colors', 'cell_type_colors', 'condition_colors', 'genotype_colors', 'highlight_colors', 'hvg', 'leiden_0.4', 'leiden_0.4_colors', 'log1p', 'neighbors', 'pca', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# Using 26870 genes as the background universe.

# %%
# Find all significant DEG list files recursively
deg_list_files = list(pathlib.Path(DGE_RESULTS_DIR).rglob('*_significant.csv'))
print(f"Found {len(deg_list_files)} significant DEG list files to process.")

if not deg_list_files:
    print(f"Error: No significant DEG list files found matching '*_significant.csv' within {DGE_RESULTS_DIR}")
    sys.exit(1)
# Out:
# Found 258 significant DEG list files to process.

# %%
# Process each DEG list file
for deg_file_path in deg_list_files:
    print(f"\n--- Processing {deg_file_path.name} ---")
    print(f"Full path: {deg_file_path}")

    try:
        # --- Parse file path to get context ---
        parts = deg_file_path.parts
        # Find the index of the 'biomarkers' directory within the path
        try:
            # Find the index of DEG_BY first
            base_index = parts.index(DEGs_folder)
            # Check if 'biomarkers' is the next part
            if base_index + 1 < len(parts) and parts[base_index + 1] == 'biomarkers':
                biomarkers_index = base_index + 1
            else:
                print(f"Warning: Could not find 'biomarkers' directory after f'{DEGs_folder}' in path {deg_file_path}. Skipping.")
                continue
        except ValueError:
            print(f"Warning: Could not find f'{DEGs_folder}' in path {deg_file_path}. Skipping.")
            continue

        # Check for 'sig_deg_lists' after 'biomarkers'
        if biomarkers_index + 1 >= len(parts) or parts[biomarkers_index + 1] != 'sig_deg_lists':
            print(f"Warning: Expected 'sig_deg_lists' directory after 'biomarkers' not found in path {deg_file_path}. Skipping.")
            continue

        # Extract context based on the biomarker structure
        # Example path: .../DEGs_mapmycells_first_layer/biomarkers/sig_deg_lists/Astro/Cluster_Astro_vs_Rest_up_significant.csv
        context_start_index = biomarkers_index + 2 # Start after 'sig_deg_lists'
        sub_path_parts = parts[context_start_index:] # Parts after sig_deg_lists

        # Expected structure: <cell_type>/<filename> -> 2 parts minimum
        if len(sub_path_parts) < 2:
            print(f"Warning: Unexpected path structure after 'sig_deg_lists' for {deg_file_path}. Parts: {sub_path_parts}. Skipping.")
            continue

        analysis_type = 'biomarkers' # This is specifically for biomarkers
        cell_type_name = sub_path_parts[0] # The directory name is the cell type
        comparison_details = 'Marker Genes' # Implicitly marker genes

        filename = deg_file_path.name
        direction = 'up' if '_up_' in filename else 'down' if '_down_' in filename else 'unknown'
        # Extract comparison name from filename (e.g., Cluster_Astro_vs_Rest)
        comparison_name = filename.replace(f'_{direction}_significant.csv', '')

        # Basic validation for extracted cell_type_name
        if not cell_type_name:
            print(f"Warning: Could not extract cell type name for {deg_file_path}. Skipping.")
            continue

        print(f"  Context: Type={analysis_type}, Details={comparison_details or 'N/A'}, CellType={cell_type_name}, Comparison={comparison_name}, Direction={direction}")

        # --- Read DEG list ---
        df = pd.read_csv(deg_file_path)
        print(f"  Read {len(df)} genes from {deg_file_path.name}")

        if 'names' not in df.columns:
            print(f"  Error: 'names' column not found in {deg_file_path.name}. Skipping.")
            continue

        gene_list = df['names'].dropna().astype(str).tolist()

        if not gene_list:
            print("  Gene list is empty. Skipping enrichment analysis.")
            continue

        # --- Prepare Output ---
        # Create specific output directory for this result
        # Structure: GO_OUTPUT_DIR / <sanitized_cell_type> / ...
        sanitized_cell_type = cell_type_name.replace('/', '_') # Sanitize cell type name for path
        specific_go_output_dir = pathlib.Path(os.path.join(GO_OUTPUT_DIR, sanitized_cell_type))

        specific_go_output_dir.mkdir(parents=True, exist_ok=True)

        # Define output file names (using sanitized cell_type_name)
        output_file_base = f"{comparison_name}_{direction}" # Keep original comparison name here
        excel_output = os.path.join(specific_go_output_dir, f"{output_file_base}_go_enrichment.xlsx")
        
        # Define visualization output files - only keep bubble plots and dotplots
        dotplot_output_file = os.path.join(specific_go_output_dir, f"{output_file_base}_go_enrichment_dotplot.png")
        
        # Construct a more informative title for biomarkers
        plot_title = f"GO Enrichment: {sanitized_cell_type} Biomarkers\n{comparison_name} ({direction.upper()})"

        # --- Run Enrichment ---
        print(f"  Running GO enrichment for {len(gene_list)} genes...")
        try:
            enr = gp.enrichr(gene_list=gene_list,
                             gene_sets=GENE_SETS,
                             organism=ORGANISM,
                             background=gene_universe, # Provide the background gene list
                             outdir=None, # Prevent gseapy from creating its own directory structure
                             cutoff=0.1, # Use a slightly less stringent cutoff for enrichr, filter later
                             verbose=False)
        except Exception as enrich_err:
             print(f"  Error during gseapy.enrichr execution: {enrich_err}")
             continue # Skip to next file if enrichment fails

        # --- Process and Save Results ---
        if enr and hasattr(enr, 'results') and isinstance(enr.results, pd.DataFrame) and not enr.results.empty:
            print("Filtering and saving enrichment results...")
            # Filter results based on adjusted p-value
            filtered_results = enr.results[enr.results['Adjusted P-value'] < GO_PADJ_THRESHOLD].copy() # Use .copy()

            if not filtered_results.empty:
                 print(f"  Found {len(filtered_results)} significant terms (Adj P < {GO_PADJ_THRESHOLD}).")
                 # Calculate gene count from 'Genes' column for size mapping
                 if 'Genes' in filtered_results.columns:
                     # Ensure robust splitting even if genes are missing or format varies
                     filtered_results['Gene_Count'] = filtered_results['Genes'].apply(
                         lambda x: len(str(x).split(';')) if pd.notna(x) and str(x) else 0
                     )
                     # Immediately convert to float to ensure numeric type from the start
                     filtered_results['Gene_Count'] = pd.to_numeric(filtered_results['Gene_Count'], errors='coerce').fillna(1.0)
                 else:
                     print("  Warning: 'Genes' column not found. Using default size.")
                     filtered_results['Gene_Count'] = 1.0  # Assign a default size as float

                 # Save filtered results to Excel
                 try:
                     filtered_results.to_excel(excel_output, index=False)
                     print(f"  Saved significant results to {excel_output}")
                 except Exception as excel_err:
                     print(f"  Error saving Excel file: {excel_err}")


                 # Generate visualizations for top terms
                 try:
                     # Sort by Adj P-value for plotting top terms
                     plot_data = filtered_results.sort_values("Adjusted P-value").head(N_TOP_TERMS_PLOT * len(GENE_SETS)).copy() # Use .copy()

                     if not plot_data.empty:
                         # Ensure relevant columns are numeric before plotting
                         for col in ['P-value', 'Adjusted P-value', 'Odds Ratio', 'Combined Score', 'Gene_Count']:
                             if col in plot_data.columns:
                                 plot_data[col] = pd.to_numeric(plot_data[col], errors='coerce')
                         
                         # Drop rows where conversion failed (NaN values)
                         plot_data.dropna(subset=['Adjusted P-value'], inplace=True)

                         if not plot_data.empty:
                             print("  Data types before plotting:")
                             print(plot_data.dtypes)
                             print(f"  Generating visualizations for {len(plot_data)} enriched terms...")
                             
                             # 1. Create a dotplot (similar to second example)
                             try:
                                 print(f"  Creating dotplot visualization: {dotplot_output_file}")
                                 
                                 # Get top terms across all categories (most significant)
                                 top_overall = plot_data.sort_values('Adjusted P-value').head(15)
                                 
                                 if not top_overall.empty:
                                     # Process the terms
                                     top_overall['Clean_Term'] = top_overall['Term'].str.replace(r' \(GO:[0-9]+\)', '', regex=True)
                                     top_overall['Clean_Term'] = top_overall['Clean_Term'].str.replace('_', ' ')
                                     
                                     # Calculate gene ratio for x-axis
                                     top_overall['GeneRatio'] = top_overall['Gene_Count'] / top_overall['Gene_Count'].max()
                                     
                                     # Sort by p-value for intuitive display
                                     top_overall = top_overall.sort_values('Adjusted P-value', ascending=False)
                                     
                                     # Plot
                                     plt.figure(figsize=(10, max(6, len(top_overall) * 0.4))) # Dynamic height
                                     
                                     # Create a scatter plot
                                     scatter = plt.scatter(
                                         top_overall['GeneRatio'],
                                         top_overall['Clean_Term'],
                                         s=top_overall['Gene_Count'] * 5,  # Size by gene count
                                         c=-np.log10(top_overall['Adjusted P-value']),  # Color by p-value
                                         cmap='Reds',  # Red colormap
                                         alpha=0.8
                                     )
                                     
                                     # Customize
                                     plt.xlabel('GeneRatio')
                                     plt.ylabel('')
                                     plt.title(f"{plot_title}\nTop GO Terms")
                                     plt.grid(True, alpha=0.3, axis='x')
                                     
                                     # Add colorbar
                                     cbar = plt.colorbar(scatter)
                                     cbar.set_label('-log10(Adj. P-value)') # Updated label
                                     
                                     # Add size legend
                                     valid_counts = top_overall['Gene_Count'].dropna().unique()
                                     if len(valid_counts) > 0:
                                         sizes = sorted(list(valid_counts))
                                         if len(sizes) > 3:
                                             size_steps = [min(sizes), 
                                                         np.percentile(sizes, 50), # Use median
                                                         max(sizes)]
                                         else:
                                             size_steps = sizes
                                     
                                     for count in size_steps:
                                         plt.scatter([], [], s=count*5, c='black', 
                                                   label=f'{int(count)}')
                                     
                                     plt.legend(title="Gene Count", loc='lower right', frameon=True) # Updated title, added frame
                                     
                                     plt.tight_layout()
                                     plt.savefig(dotplot_output_file, dpi=150, bbox_inches='tight')
                                     plt.close()
                                     
                                     print(f"  Dotplot saved to {dotplot_output_file}")
                             except Exception as dotplot_err:
                                 print(f"  Error generating dotplot: {dotplot_err}")
                         else:
                             print("  No significant terms left after filtering for visualization.")
                     else:
                         print("  No significant terms left after filtering for visualization.")
                 except Exception as viz_err:
                     print(f"  Warning: Could not generate visualizations. Error: {viz_err}")
            else:
                print(f"  No significantly enriched terms found after filtering (Adj P < {GO_PADJ_THRESHOLD}). No Excel file or visualizations saved.")
        else:
             print("  Enrichment analysis did not return results or results table was empty.")
    except FileNotFoundError:
        print(f"Error: DEG list file not found (should not happen with glob): {deg_file_path}")
    except pd.errors.EmptyDataError:
        print(f"Error: DEG list file is empty: {deg_file_path.name}")
    except KeyError as e:
        print(f"Error: Missing expected column in {deg_file_path.name}: {e}. Ensure 'names' column exists.")
    except Exception as e:
        print(f"An unexpected error occurred processing {deg_file_path.name}: {e}")
        import traceback
        traceback.print_exc() # Print detailed traceback for debugging

print("\nGO enrichment analysis for DEG lists complete.")
print(f"Results saved in subdirectories under: {GO_OUTPUT_DIR}")
# Out:
# --- Processing Cluster_ABC NN_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\ABC_NN\Cluster_ABC NN_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=ABC_NN, Comparison=Cluster_ABC NN_vs_Rest, Direction=down
#   Read 3109 genes from Cluster_ABC NN_vs_Rest_down_significant.csv
#   Running GO enrichment for 3109 genes...
# Filtering and saving enrichment results...
#   Found 949 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\ABC_NN\Cluster_ABC NN_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\ABC_NN\Cluster_ABC NN_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_ABC NN_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\ABC_NN\Cluster_ABC NN_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=ABC_NN, Comparison=Cluster_ABC NN_vs_Rest, Direction=up
#   Read 591 genes from Cluster_ABC NN_vs_Rest_up_significant.csv
#   Running GO enrichment for 591 genes...
# Filtering and saving enrichment results...
#   Found 614 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\ABC_NN\Cluster_ABC NN_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\ABC_NN\Cluster_ABC NN_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_ADP-MPO Trp73 Glut_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\ADP-MPO_Trp73_Glut\Cluster_ADP-MPO Trp73 Glut_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=ADP-MPO_Trp73_Glut, Comparison=Cluster_ADP-MPO Trp73 Glut_vs_Rest, Direction=down
#   Read 0 genes from Cluster_ADP-MPO Trp73 Glut_vs_Rest_down_significant.csv
#   Gene list is empty. Skipping enrichment analysis.
#
# --- Processing Cluster_ADP-MPO Trp73 Glut_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\ADP-MPO_Trp73_Glut\Cluster_ADP-MPO Trp73 Glut_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=ADP-MPO_Trp73_Glut, Comparison=Cluster_ADP-MPO Trp73 Glut_vs_Rest, Direction=up
#   Read 0 genes from Cluster_ADP-MPO Trp73 Glut_vs_Rest_up_significant.csv
#   Gene list is empty. Skipping enrichment analysis.
#
# --- Processing Cluster_Astro-NT NN_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\Astro-NT_NN\Cluster_Astro-NT NN_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Astro-NT_NN, Comparison=Cluster_Astro-NT NN_vs_Rest, Direction=down
#   Read 1964 genes from Cluster_Astro-NT NN_vs_Rest_down_significant.csv
#   Running GO enrichment for 1964 genes...
# Filtering and saving enrichment results...
#   Found 715 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\Astro-NT_NN\Cluster_Astro-NT NN_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\Astro-NT_NN\Cluster_Astro-NT NN_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_Astro-NT NN_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\Astro-NT_NN\Cluster_Astro-NT NN_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Astro-NT_NN, Comparison=Cluster_Astro-NT NN_vs_Rest, Direction=up
#   Read 180 genes from Cluster_Astro-NT NN_vs_Rest_up_significant.csv
#   Running GO enrichment for 180 genes...
# Filtering and saving enrichment results...
#   Found 245 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\Astro-NT_NN\Cluster_Astro-NT NN_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\Astro-NT_NN\Cluster_Astro-NT NN_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_Astro-OLF NN_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\Astro-OLF_NN\Cluster_Astro-OLF NN_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Astro-OLF_NN, Comparison=Cluster_Astro-OLF NN_vs_Rest, Direction=down
#   Read 0 genes from Cluster_Astro-OLF NN_vs_Rest_down_significant.csv
#   Gene list is empty. Skipping enrichment analysis.
#
# --- Processing Cluster_Astro-OLF NN_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\Astro-OLF_NN\Cluster_Astro-OLF NN_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Astro-OLF_NN, Comparison=Cluster_Astro-OLF NN_vs_Rest, Direction=up
#   Read 0 genes from Cluster_Astro-OLF NN_vs_Rest_up_significant.csv
#   Gene list is empty. Skipping enrichment analysis.
#
# --- Processing Cluster_Astro-TE NN_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\Astro-TE_NN\Cluster_Astro-TE NN_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Astro-TE_NN, Comparison=Cluster_Astro-TE NN_vs_Rest, Direction=down
#   Read 6245 genes from Cluster_Astro-TE NN_vs_Rest_down_significant.csv
#   Running GO enrichment for 6245 genes...
# Filtering and saving enrichment results...
#   Found 1164 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\Astro-TE_NN\Cluster_Astro-TE NN_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\Astro-TE_NN\Cluster_Astro-TE NN_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_Astro-TE NN_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\Astro-TE_NN\Cluster_Astro-TE NN_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Astro-TE_NN, Comparison=Cluster_Astro-TE NN_vs_Rest, Direction=up
#   Read 1519 genes from Cluster_Astro-TE NN_vs_Rest_up_significant.csv
#   Running GO enrichment for 1519 genes...
# Filtering and saving enrichment results...
#   Found 621 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\Astro-TE_NN\Cluster_Astro-TE NN_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\Astro-TE_NN\Cluster_Astro-TE NN_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_BAM NN_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\BAM_NN\Cluster_BAM NN_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=BAM_NN, Comparison=Cluster_BAM NN_vs_Rest, Direction=down
#   Read 1559 genes from Cluster_BAM NN_vs_Rest_down_significant.csv
#   Running GO enrichment for 1559 genes...
# Filtering and saving enrichment results...
#   Found 692 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\BAM_NN\Cluster_BAM NN_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\BAM_NN\Cluster_BAM NN_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_BAM NN_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\BAM_NN\Cluster_BAM NN_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=BAM_NN, Comparison=Cluster_BAM NN_vs_Rest, Direction=up
#   Read 165 genes from Cluster_BAM NN_vs_Rest_up_significant.csv
#   Running GO enrichment for 165 genes...
# Filtering and saving enrichment results...
#   Found 340 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\BAM_NN\Cluster_BAM NN_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\BAM_NN\Cluster_BAM NN_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_CA1-ProS Glut_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\CA1-ProS_Glut\Cluster_CA1-ProS Glut_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=CA1-ProS_Glut, Comparison=Cluster_CA1-ProS Glut_vs_Rest, Direction=down
#   Read 926 genes from Cluster_CA1-ProS Glut_vs_Rest_down_significant.csv
#   Running GO enrichment for 926 genes...
# Filtering and saving enrichment results...
#   Found 629 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\CA1-ProS_Glut\Cluster_CA1-ProS Glut_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\CA1-ProS_Glut\Cluster_CA1-ProS Glut_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_CA1-ProS Glut_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\CA1-ProS_Glut\Cluster_CA1-ProS Glut_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=CA1-ProS_Glut, Comparison=Cluster_CA1-ProS Glut_vs_Rest, Direction=up
#   Read 2840 genes from Cluster_CA1-ProS Glut_vs_Rest_up_significant.csv
#   Running GO enrichment for 2840 genes...
# Filtering and saving enrichment results...
#   Found 391 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\CA1-ProS_Glut\Cluster_CA1-ProS Glut_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\CA1-ProS_Glut\Cluster_CA1-ProS Glut_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_CA2-FC-IG Glut_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\CA2-FC-IG_Glut\Cluster_CA2-FC-IG Glut_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=CA2-FC-IG_Glut, Comparison=Cluster_CA2-FC-IG Glut_vs_Rest, Direction=down
#   Read 1078 genes from Cluster_CA2-FC-IG Glut_vs_Rest_down_significant.csv
#   Running GO enrichment for 1078 genes...
# Filtering and saving enrichment results...
#   Found 573 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\CA2-FC-IG_Glut\Cluster_CA2-FC-IG Glut_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\CA2-FC-IG_Glut\Cluster_CA2-FC-IG Glut_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_CA2-FC-IG Glut_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\CA2-FC-IG_Glut\Cluster_CA2-FC-IG Glut_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=CA2-FC-IG_Glut, Comparison=Cluster_CA2-FC-IG Glut_vs_Rest, Direction=up
#   Read 752 genes from Cluster_CA2-FC-IG Glut_vs_Rest_up_significant.csv
#   Running GO enrichment for 752 genes...
# Filtering and saving enrichment results...
#   Found 511 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\CA2-FC-IG_Glut\Cluster_CA2-FC-IG Glut_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\CA2-FC-IG_Glut\Cluster_CA2-FC-IG Glut_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_CA3 Glut_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\CA3_Glut\Cluster_CA3 Glut_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=CA3_Glut, Comparison=Cluster_CA3 Glut_vs_Rest, Direction=down
#   Read 951 genes from Cluster_CA3 Glut_vs_Rest_down_significant.csv
#   Running GO enrichment for 951 genes...
# Filtering and saving enrichment results...
#   Found 545 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\CA3_Glut\Cluster_CA3 Glut_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\CA3_Glut\Cluster_CA3 Glut_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_CA3 Glut_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\CA3_Glut\Cluster_CA3 Glut_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=CA3_Glut, Comparison=Cluster_CA3 Glut_vs_Rest, Direction=up
#   Read 3451 genes from Cluster_CA3 Glut_vs_Rest_up_significant.csv
#   Running GO enrichment for 3451 genes...
# Filtering and saving enrichment results...
#   Found 623 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\CA3_Glut\Cluster_CA3 Glut_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\CA3_Glut\Cluster_CA3 Glut_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_CB Granule Glut_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\CB_Granule_Glut\Cluster_CB Granule Glut_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=CB_Granule_Glut, Comparison=Cluster_CB Granule Glut_vs_Rest, Direction=down
#   Read 0 genes from Cluster_CB Granule Glut_vs_Rest_down_significant.csv
#   Gene list is empty. Skipping enrichment analysis.
#
# --- Processing Cluster_CB Granule Glut_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\CB_Granule_Glut\Cluster_CB Granule Glut_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=CB_Granule_Glut, Comparison=Cluster_CB Granule Glut_vs_Rest, Direction=up
#   Read 0 genes from Cluster_CB Granule Glut_vs_Rest_up_significant.csv
#   Gene list is empty. Skipping enrichment analysis.
#
# --- Processing Cluster_CB PLI Gly-Gaba_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\CB_PLI_Gly-Gaba\Cluster_CB PLI Gly-Gaba_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=CB_PLI_Gly-Gaba, Comparison=Cluster_CB PLI Gly-Gaba_vs_Rest, Direction=down
#   Read 0 genes from Cluster_CB PLI Gly-Gaba_vs_Rest_down_significant.csv
#   Gene list is empty. Skipping enrichment analysis.
#
# --- Processing Cluster_CB PLI Gly-Gaba_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\CB_PLI_Gly-Gaba\Cluster_CB PLI Gly-Gaba_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=CB_PLI_Gly-Gaba, Comparison=Cluster_CB PLI Gly-Gaba_vs_Rest, Direction=up
#   Read 0 genes from Cluster_CB PLI Gly-Gaba_vs_Rest_up_significant.csv
#   Gene list is empty. Skipping enrichment analysis.
#
# --- Processing Cluster_CEA-BST Ebf1 Pdyn Gaba_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\CEA-BST_Ebf1_Pdyn_Gaba\Cluster_CEA-BST Ebf1 Pdyn Gaba_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=CEA-BST_Ebf1_Pdyn_Gaba, Comparison=Cluster_CEA-BST Ebf1 Pdyn Gaba_vs_Rest, Direction=down
#   Read 0 genes from Cluster_CEA-BST Ebf1 Pdyn Gaba_vs_Rest_down_significant.csv
#   Gene list is empty. Skipping enrichment analysis.
#
# --- Processing Cluster_CEA-BST Ebf1 Pdyn Gaba_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\CEA-BST_Ebf1_Pdyn_Gaba\Cluster_CEA-BST Ebf1 Pdyn Gaba_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=CEA-BST_Ebf1_Pdyn_Gaba, Comparison=Cluster_CEA-BST Ebf1 Pdyn Gaba_vs_Rest, Direction=up
#   Read 0 genes from Cluster_CEA-BST Ebf1 Pdyn Gaba_vs_Rest_up_significant.csv
#   Gene list is empty. Skipping enrichment analysis.
#
# --- Processing Cluster_CEA-BST Six3 Cyp26b1 Gaba_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\CEA-BST_Six3_Cyp26b1_Gaba\Cluster_CEA-BST Six3 Cyp26b1 Gaba_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=CEA-BST_Six3_Cyp26b1_Gaba, Comparison=Cluster_CEA-BST Six3 Cyp26b1 Gaba_vs_Rest, Direction=down
#   Read 8 genes from Cluster_CEA-BST Six3 Cyp26b1 Gaba_vs_Rest_down_significant.csv
#   Running GO enrichment for 8 genes...
# Filtering and saving enrichment results...
#   Found 72 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\CEA-BST_Six3_Cyp26b1_Gaba\Cluster_CEA-BST Six3 Cyp26b1 Gaba_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\CEA-BST_Six3_Cyp26b1_Gaba\Cluster_CEA-BST Six3 Cyp26b1 Gaba_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_CEA-BST Six3 Cyp26b1 Gaba_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\CEA-BST_Six3_Cyp26b1_Gaba\Cluster_CEA-BST Six3 Cyp26b1 Gaba_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=CEA-BST_Six3_Cyp26b1_Gaba, Comparison=Cluster_CEA-BST Six3 Cyp26b1 Gaba_vs_Rest, Direction=up
#   Read 46 genes from Cluster_CEA-BST Six3 Cyp26b1 Gaba_vs_Rest_up_significant.csv
#   Running GO enrichment for 46 genes...
# Filtering and saving enrichment results...
#   Found 92 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\CEA-BST_Six3_Cyp26b1_Gaba\Cluster_CEA-BST Six3 Cyp26b1 Gaba_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\CEA-BST_Six3_Cyp26b1_Gaba\Cluster_CEA-BST Six3 Cyp26b1 Gaba_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_CHOR NN_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\CHOR_NN\Cluster_CHOR NN_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=CHOR_NN, Comparison=Cluster_CHOR NN_vs_Rest, Direction=down
#   Read 67 genes from Cluster_CHOR NN_vs_Rest_down_significant.csv
#   Running GO enrichment for 67 genes...
# Filtering and saving enrichment results...
#   Found 218 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\CHOR_NN\Cluster_CHOR NN_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\CHOR_NN\Cluster_CHOR NN_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_CHOR NN_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\CHOR_NN\Cluster_CHOR NN_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=CHOR_NN, Comparison=Cluster_CHOR NN_vs_Rest, Direction=up
#   Read 51 genes from Cluster_CHOR NN_vs_Rest_up_significant.csv
#   Running GO enrichment for 51 genes...
# Filtering and saving enrichment results...
#   Found 13 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 13 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\CHOR_NN\Cluster_CHOR NN_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\CHOR_NN\Cluster_CHOR NN_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_CLA-EPd-CTX Car3 Glut_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\CLA-EPd-CTX_Car3_Glut\Cluster_CLA-EPd-CTX Car3 Glut_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=CLA-EPd-CTX_Car3_Glut, Comparison=Cluster_CLA-EPd-CTX Car3 Glut_vs_Rest, Direction=down
#   Read 88 genes from Cluster_CLA-EPd-CTX Car3 Glut_vs_Rest_down_significant.csv
#   Running GO enrichment for 88 genes...
# Filtering and saving enrichment results...
#   Found 78 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\CLA-EPd-CTX_Car3_Glut\Cluster_CLA-EPd-CTX Car3 Glut_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\CLA-EPd-CTX_Car3_Glut\Cluster_CLA-EPd-CTX Car3 Glut_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_CLA-EPd-CTX Car3 Glut_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\CLA-EPd-CTX_Car3_Glut\Cluster_CLA-EPd-CTX Car3 Glut_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=CLA-EPd-CTX_Car3_Glut, Comparison=Cluster_CLA-EPd-CTX Car3 Glut_vs_Rest, Direction=up
#   Read 1256 genes from Cluster_CLA-EPd-CTX Car3 Glut_vs_Rest_up_significant.csv
#   Running GO enrichment for 1256 genes...
# Filtering and saving enrichment results...
#   Found 524 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\CLA-EPd-CTX_Car3_Glut\Cluster_CLA-EPd-CTX Car3 Glut_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\CLA-EPd-CTX_Car3_Glut\Cluster_CLA-EPd-CTX Car3 Glut_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_COAa-PAA-MEA Barhl2 Glut_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\COAa-PAA-MEA_Barhl2_Glut\Cluster_COAa-PAA-MEA Barhl2 Glut_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=COAa-PAA-MEA_Barhl2_Glut, Comparison=Cluster_COAa-PAA-MEA Barhl2 Glut_vs_Rest, Direction=down
#   Read 278 genes from Cluster_COAa-PAA-MEA Barhl2 Glut_vs_Rest_down_significant.csv
#   Running GO enrichment for 278 genes...
# Filtering and saving enrichment results...
#   Found 178 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\COAa-PAA-MEA_Barhl2_Glut\Cluster_COAa-PAA-MEA Barhl2 Glut_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\COAa-PAA-MEA_Barhl2_Glut\Cluster_COAa-PAA-MEA Barhl2 Glut_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_COAa-PAA-MEA Barhl2 Glut_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\COAa-PAA-MEA_Barhl2_Glut\Cluster_COAa-PAA-MEA Barhl2 Glut_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=COAa-PAA-MEA_Barhl2_Glut, Comparison=Cluster_COAa-PAA-MEA Barhl2 Glut_vs_Rest, Direction=up
#   Read 14 genes from Cluster_COAa-PAA-MEA Barhl2 Glut_vs_Rest_up_significant.csv
#   Running GO enrichment for 14 genes...
# Filtering and saving enrichment results...
#   Found 224 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\COAa-PAA-MEA_Barhl2_Glut\Cluster_COAa-PAA-MEA Barhl2 Glut_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\COAa-PAA-MEA_Barhl2_Glut\Cluster_COAa-PAA-MEA Barhl2 Glut_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_COAp Grxcr2 Glut_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\COAp_Grxcr2_Glut\Cluster_COAp Grxcr2 Glut_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=COAp_Grxcr2_Glut, Comparison=Cluster_COAp Grxcr2 Glut_vs_Rest, Direction=down
#   Read 368 genes from Cluster_COAp Grxcr2 Glut_vs_Rest_down_significant.csv
#   Running GO enrichment for 368 genes...
# Filtering and saving enrichment results...
#   Found 234 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\COAp_Grxcr2_Glut\Cluster_COAp Grxcr2 Glut_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\COAp_Grxcr2_Glut\Cluster_COAp Grxcr2 Glut_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_COAp Grxcr2 Glut_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\COAp_Grxcr2_Glut\Cluster_COAp Grxcr2 Glut_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=COAp_Grxcr2_Glut, Comparison=Cluster_COAp Grxcr2 Glut_vs_Rest, Direction=up
#   Read 43 genes from Cluster_COAp Grxcr2 Glut_vs_Rest_up_significant.csv
#   Running GO enrichment for 43 genes...
# Filtering and saving enrichment results...
#   Found 226 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\COAp_Grxcr2_Glut\Cluster_COAp Grxcr2 Glut_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\COAp_Grxcr2_Glut\Cluster_COAp Grxcr2 Glut_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_CT SUB Glut_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\CT_SUB_Glut\Cluster_CT SUB Glut_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=CT_SUB_Glut, Comparison=Cluster_CT SUB Glut_vs_Rest, Direction=down
#   Read 479 genes from Cluster_CT SUB Glut_vs_Rest_down_significant.csv
#   Running GO enrichment for 479 genes...
# Filtering and saving enrichment results...
#   Found 389 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\CT_SUB_Glut\Cluster_CT SUB Glut_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\CT_SUB_Glut\Cluster_CT SUB Glut_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_CT SUB Glut_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\CT_SUB_Glut\Cluster_CT SUB Glut_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=CT_SUB_Glut, Comparison=Cluster_CT SUB Glut_vs_Rest, Direction=up
#   Read 1049 genes from Cluster_CT SUB Glut_vs_Rest_up_significant.csv
#   Running GO enrichment for 1049 genes...
# Filtering and saving enrichment results...
#   Found 351 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\CT_SUB_Glut\Cluster_CT SUB Glut_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\CT_SUB_Glut\Cluster_CT SUB Glut_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_DC NN_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\DC_NN\Cluster_DC NN_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=DC_NN, Comparison=Cluster_DC NN_vs_Rest, Direction=down
#   Read 535 genes from Cluster_DC NN_vs_Rest_down_significant.csv
#   Running GO enrichment for 535 genes...
# Filtering and saving enrichment results...
#   Found 288 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\DC_NN\Cluster_DC NN_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\DC_NN\Cluster_DC NN_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_DC NN_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\DC_NN\Cluster_DC NN_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=DC_NN, Comparison=Cluster_DC NN_vs_Rest, Direction=up
#   Read 7 genes from Cluster_DC NN_vs_Rest_up_significant.csv
#   Running GO enrichment for 7 genes...
# Filtering and saving enrichment results...
#   Found 179 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\DC_NN\Cluster_DC NN_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\DC_NN\Cluster_DC NN_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_DG-PIR Ex IMN_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\DG-PIR_Ex_IMN\Cluster_DG-PIR Ex IMN_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=DG-PIR_Ex_IMN, Comparison=Cluster_DG-PIR Ex IMN_vs_Rest, Direction=down
#   Read 3643 genes from Cluster_DG-PIR Ex IMN_vs_Rest_down_significant.csv
#   Running GO enrichment for 3643 genes...
# Filtering and saving enrichment results...
#   Found 1087 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\DG-PIR_Ex_IMN\Cluster_DG-PIR Ex IMN_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\DG-PIR_Ex_IMN\Cluster_DG-PIR Ex IMN_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_DG-PIR Ex IMN_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\DG-PIR_Ex_IMN\Cluster_DG-PIR Ex IMN_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=DG-PIR_Ex_IMN, Comparison=Cluster_DG-PIR Ex IMN_vs_Rest, Direction=up
# ...
#   Running GO enrichment for 33 genes...
# Filtering and saving enrichment results...
#   Found 47 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\STR_Prox1_Lhx6_Gaba\Cluster_STR Prox1 Lhx6 Gaba_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\STR_Prox1_Lhx6_Gaba\Cluster_STR Prox1 Lhx6 Gaba_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_SUB-ProS Glut_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\SUB-ProS_Glut\Cluster_SUB-ProS Glut_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=SUB-ProS_Glut, Comparison=Cluster_SUB-ProS Glut_vs_Rest, Direction=down
#   Read 371 genes from Cluster_SUB-ProS Glut_vs_Rest_down_significant.csv
#   Running GO enrichment for 371 genes...
# Filtering and saving enrichment results...
#   Found 289 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\SUB-ProS_Glut\Cluster_SUB-ProS Glut_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\SUB-ProS_Glut\Cluster_SUB-ProS Glut_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_SUB-ProS Glut_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\SUB-ProS_Glut\Cluster_SUB-ProS Glut_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=SUB-ProS_Glut, Comparison=Cluster_SUB-ProS Glut_vs_Rest, Direction=up
#   Read 4792 genes from Cluster_SUB-ProS Glut_vs_Rest_up_significant.csv
#   Running GO enrichment for 4792 genes...
# Filtering and saving enrichment results...
#   Found 685 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\SUB-ProS_Glut\Cluster_SUB-ProS Glut_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\SUB-ProS_Glut\Cluster_SUB-ProS Glut_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_Tanycyte NN_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\Tanycyte_NN\Cluster_Tanycyte NN_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Tanycyte_NN, Comparison=Cluster_Tanycyte NN_vs_Rest, Direction=down
#   Read 0 genes from Cluster_Tanycyte NN_vs_Rest_down_significant.csv
#   Gene list is empty. Skipping enrichment analysis.
#
# --- Processing Cluster_Tanycyte NN_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\Tanycyte_NN\Cluster_Tanycyte NN_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Tanycyte_NN, Comparison=Cluster_Tanycyte NN_vs_Rest, Direction=up
#   Read 0 genes from Cluster_Tanycyte NN_vs_Rest_up_significant.csv
#   Gene list is empty. Skipping enrichment analysis.
#
# --- Processing Cluster_TH Prkcd Grin2c Glut_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\TH_Prkcd_Grin2c_Glut\Cluster_TH Prkcd Grin2c Glut_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=TH_Prkcd_Grin2c_Glut, Comparison=Cluster_TH Prkcd Grin2c Glut_vs_Rest, Direction=down
#   Read 0 genes from Cluster_TH Prkcd Grin2c Glut_vs_Rest_down_significant.csv
#   Gene list is empty. Skipping enrichment analysis.
#
# --- Processing Cluster_TH Prkcd Grin2c Glut_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\TH_Prkcd_Grin2c_Glut\Cluster_TH Prkcd Grin2c Glut_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=TH_Prkcd_Grin2c_Glut, Comparison=Cluster_TH Prkcd Grin2c Glut_vs_Rest, Direction=up
#   Read 4 genes from Cluster_TH Prkcd Grin2c Glut_vs_Rest_up_significant.csv
#   Running GO enrichment for 4 genes...
# Filtering and saving enrichment results...
#   Found 85 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\TH_Prkcd_Grin2c_Glut\Cluster_TH Prkcd Grin2c Glut_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\TH_Prkcd_Grin2c_Glut\Cluster_TH Prkcd Grin2c Glut_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_TRS-BAC Sln Glut_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\TRS-BAC_Sln_Glut\Cluster_TRS-BAC Sln Glut_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=TRS-BAC_Sln_Glut, Comparison=Cluster_TRS-BAC Sln Glut_vs_Rest, Direction=down
#   Read 0 genes from Cluster_TRS-BAC Sln Glut_vs_Rest_down_significant.csv
#   Gene list is empty. Skipping enrichment analysis.
#
# --- Processing Cluster_TRS-BAC Sln Glut_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\TRS-BAC_Sln_Glut\Cluster_TRS-BAC Sln Glut_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=TRS-BAC_Sln_Glut, Comparison=Cluster_TRS-BAC Sln Glut_vs_Rest, Direction=up
#   Read 0 genes from Cluster_TRS-BAC Sln Glut_vs_Rest_up_significant.csv
#   Gene list is empty. Skipping enrichment analysis.
#
# --- Processing Cluster_VCO Mafa Meis2 Glut_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\VCO_Mafa_Meis2_Glut\Cluster_VCO Mafa Meis2 Glut_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=VCO_Mafa_Meis2_Glut, Comparison=Cluster_VCO Mafa Meis2 Glut_vs_Rest, Direction=down
#   Read 0 genes from Cluster_VCO Mafa Meis2 Glut_vs_Rest_down_significant.csv
#   Gene list is empty. Skipping enrichment analysis.
#
# --- Processing Cluster_VCO Mafa Meis2 Glut_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\VCO_Mafa_Meis2_Glut\Cluster_VCO Mafa Meis2 Glut_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=VCO_Mafa_Meis2_Glut, Comparison=Cluster_VCO Mafa Meis2 Glut_vs_Rest, Direction=up
#   Read 0 genes from Cluster_VCO Mafa Meis2 Glut_vs_Rest_up_significant.csv
#   Gene list is empty. Skipping enrichment analysis.
#
# --- Processing Cluster_Vip Gaba_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\Vip_Gaba\Cluster_Vip Gaba_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Vip_Gaba, Comparison=Cluster_Vip Gaba_vs_Rest, Direction=down
#   Read 2632 genes from Cluster_Vip Gaba_vs_Rest_down_significant.csv
#   Running GO enrichment for 2632 genes...
# Filtering and saving enrichment results...
#   Found 883 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\Vip_Gaba\Cluster_Vip Gaba_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\Vip_Gaba\Cluster_Vip Gaba_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_Vip Gaba_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\Vip_Gaba\Cluster_Vip Gaba_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=Vip_Gaba, Comparison=Cluster_Vip Gaba_vs_Rest, Direction=up
#   Read 594 genes from Cluster_Vip Gaba_vs_Rest_up_significant.csv
#   Running GO enrichment for 594 genes...
# Filtering and saving enrichment results...
#   Found 324 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\Vip_Gaba\Cluster_Vip Gaba_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\Vip_Gaba\Cluster_Vip Gaba_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_VLMC NN_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\VLMC_NN\Cluster_VLMC NN_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=VLMC_NN, Comparison=Cluster_VLMC NN_vs_Rest, Direction=down
#   Read 4305 genes from Cluster_VLMC NN_vs_Rest_down_significant.csv
#   Running GO enrichment for 4305 genes...
# Filtering and saving enrichment results...
#   Found 1199 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\VLMC_NN\Cluster_VLMC NN_vs_Rest_down_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\VLMC_NN\Cluster_VLMC NN_vs_Rest_down_go_enrichment_dotplot.png
#
# --- Processing Cluster_VLMC NN_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\VLMC_NN\Cluster_VLMC NN_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=VLMC_NN, Comparison=Cluster_VLMC NN_vs_Rest, Direction=up
#   Read 442 genes from Cluster_VLMC NN_vs_Rest_up_significant.csv
#   Running GO enrichment for 442 genes...
# Filtering and saving enrichment results...
#   Found 546 significant terms (Adj P < 0.05).
#   Error saving Excel file: No module named 'openpyxl'
#   Data types before plotting:
# Gene_set                 object
# Term                     object
# P-value                 float64
# Adjusted P-value        float64
# Old P-value               int64
# Old adjusted P-value      int64
# Odds Ratio              float64
# Combined Score          float64
# Genes                    object
# Gene_Count                int64
# dtype: object
#   Generating visualizations for 30 enriched terms...
#   Creating dotplot visualization: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\VLMC_NN\Cluster_VLMC NN_vs_Rest_up_go_enrichment_dotplot.png
#   Dotplot saved to D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment\VLMC_NN\Cluster_VLMC NN_vs_Rest_up_go_enrichment_dotplot.png
#
# --- Processing Cluster_ZI Pax6 Gaba_vs_Rest_down_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\ZI_Pax6_Gaba\Cluster_ZI Pax6 Gaba_vs_Rest_down_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=ZI_Pax6_Gaba, Comparison=Cluster_ZI Pax6 Gaba_vs_Rest, Direction=down
#   Read 0 genes from Cluster_ZI Pax6 Gaba_vs_Rest_down_significant.csv
#   Gene list is empty. Skipping enrichment analysis.
#
# --- Processing Cluster_ZI Pax6 Gaba_vs_Rest_up_significant.csv ---
# Full path: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\sig_deg_lists\ZI_Pax6_Gaba\Cluster_ZI Pax6 Gaba_vs_Rest_up_significant.csv
#   Context: Type=biomarkers, Details=Marker Genes, CellType=ZI_Pax6_Gaba, Comparison=Cluster_ZI Pax6 Gaba_vs_Rest, Direction=up
#   Read 0 genes from Cluster_ZI Pax6 Gaba_vs_Rest_up_significant.csv
#   Gene list is empty. Skipping enrichment analysis.
#
# GO enrichment analysis for DEG lists complete.
# Results saved in subdirectories under: D:\Github\SRF_Linda_RNA\combine_data\results_from_raw\DEGs_mapmycells_L2FC_0_25\biomarkers\go_enrichment
